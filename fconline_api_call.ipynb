# %% [markdown]
# # FC온라인 API 연결

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. 데이터 설명

# %% [markdown]
# #### 매치 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **matchId**                | string     | 64f0000c00007210005f0000  | 매치 고유 식별자                                   |
# | **matchDate**              | string     | 2023-10-29T12:22:48       | 매치 일자 (UTC0)                                 |
# | **matchType**              | integer    | 52                        | 매치 종류 (/metadata/matchtype API 참고)          |
#
#
# #### matchDetails : 매치 참여 플레이어별 매치 상세
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **ouid**       | string     |                           | 계정 식별자                                        |
# | **nickname**   | string     | 닉네임                    | 유저 닉네임                                        |
#
# #### matchDetail : 매치 결과 상세 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **seasonId**          | integer  | 202311               | 시즌 ID                                            |
# | **matchResult**       | string   | 승                  | 매치 결과 (“승”, “무”, “패”)                      |
# | **matchEndType**      | integer  | 0                   | 매치 종료 타입 (0 정상종료, 1 몰수승, 2 몰수패)   |
# | **systemPause**       | integer  | 0                   | 게임 일시정지 수                                   |
# | **foul**              | integer  | 0                   | 파울 수                                            |
# | **injury**            | integer  | 1                   | 부상 수                                            |
# | **redCards**          | integer  | 0                   | 받은 레드카드 수                                   |
# | **yellowCards**       | integer  | 0                   | 받은 옐로카드 수                                   |
# | **dribble**           | integer  | 78                  | 드리블 거리(야드)                                  |
# | **cornerKick**        | integer  | 0                   | 코너킥 수                                          |
# | **possession**        | integer  | 46                  | 점유율                                             |
# | **offsideCount**      | integer  | 1                   | 오프사이드 수                                      |
# | **averageRating**     | number   | 1.18889             | 경기 평점                                          |
# | **controller**        | string   | keyboard            | 사용한 컨트롤러 타입 (keyboard / pad / etc 중 1)  |
#
#
# #### shoot : 슈팅 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **shoot**                 | object      |                           | 슈팅 정보                                          |
# | **shootTotal**                 | integer  | 3                   | 총 슛 수                                           |
# | **effectiveShootTotal**         | integer  | 3                   | 총 유효슛 수                                       |
# | **shootOutScore**              | integer  | 0                   | 승부차기 슛 수                                     |
# | **goalTotal**                  | integer  | 2                   | 총 골 수                                           |
# | **goalTotalDisplay**           | integer  | 2                   | 게임 종료 후 유저에게 노출되는 골 수              |
# | **ownGoal**                    | integer  | 0                   | 자책 골 수                                         |
# | **shootHeading**               | integer  | 2                   | 헤딩 슛 수                                         |
# | **goalHeading**                | integer  | 1                   | 헤딩 골 수                                         |
# | **shootFreekick**              | integer  | 0                   | 프리킥 슛 수                                       |
# | **goalFreekick**               | integer  | 0                   | 프리킥 골 수                                       |
# | **shootInPenalty**             | integer  | 3                   | 인패널티 슛 수                                     |
# | **goalInPenalty**              | integer  | 2                   | 인패널티 골 수                                     |
# | **shootOutPenalty**            | integer  | 0                   | 아웃패널티 슛 수                                   |
# | **goalOutPenalty**             | integer  | 0                   | 아웃패널티 골 수                                   |
# | **shootPenaltyKick**           | integer  | 0                   | 패널티킥 슛 수                                     |
# | **goalPenaltyKick**            | integer  | 0                   | 패널티킥 골 수                                     |
#
# #### pass : 패스 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **passTry**                    | integer  | 92                  | 패스 시도 수                                       |
# | **passSuccess**                | integer  | 83                  | 패스 성공 수                                       |
# | **shortPassTry**               | integer  | 55                  | 숏 패스 시도 수                                    |
# | **shortPassSuccess**           | integer  | 55                  | 숏 패스 성공 수                                    |
# | **longPassTry**                | integer  | 3                   | 롱 패스 시도 수                                    |
# | **longPassSuccess**            | integer  | 3                   | 롱 패스 성공 수                                    |
# | **bouncingLobPassTry**         | integer  | 1                   | 바운싱 롭 패스 시도 수                             |
# | **bouncingLobPassSuccess**     | integer  | 0                   | 바운싱 롭 패스 성공 수                             |
# | **drivenGroundPassTry**        | integer  | 10                  | 드리븐 땅볼 패스 시도 수                           |
# | **drivenGroundPassSuccess**    | integer  | 10                  | 드리븐 땅볼 패스 성공 수                           |
# | **throughPassTry**             | integer  | 19                  | 스루 패스 시도 수                                  |
# | **throughPassSuccess**         | integer  | 14                  | 스루 패스 성공 수                                  |
# | **lobbedThroughPassTry**       | integer  | 4                   | 로빙 스루 패스 시도 수                             |
# | **lobbedThroughPassSuccess**   | integer  | 1                   | 로빙 스루 패스 성공 수                             |
#
# #### defence : 수비 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **blockTry**                  | integer  | 3                   | 블락 시도 수                                       |
# | **blockSuccess**              | integer  | 0                   | 블락 성공 수                                       |
# | **tackleTry**                 | integer  | 11                  | 태클 시도 수                                       |
# | **tackleSuccess**             | integer  | 9                   | 태클 성공 수                                       |

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 데이터 분석 환경 조성

# %% [markdown]
# ### 라이브러리 호출

# %%
import requests
import pandas as pd

# %% [markdown]
# ### 매치 메타데이터 확인
# - 매치 타입 확인

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/static/fconline/meta/matchtype.json"
response = requests.get(urlString, headers = headers)

match_type = response.json()
match_type
# Out:
# [{'matchtype': 30, 'desc': '리그 친선'},
#  {'matchtype': 40, 'desc': '클래식 1on1'},
#  {'matchtype': 50, 'desc': '공식경기'},
#  {'matchtype': 52, 'desc': '감독모드'},
#  {'matchtype': 60, 'desc': '공식 친선'},
#  {'matchtype': 204, 'desc': '볼타 친선'},
#  {'matchtype': 214, 'desc': '볼타 공식'},
#  {'matchtype': 224, 'desc': '볼타 AI대전'},
#  {'matchtype': 234, 'desc': '볼타 커스텀'}]

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 데이터 프레임 생성

# %% [markdown]
# ### 1) 내 매치 기록

# %% [markdown]
# - 계정 식별자 정보 저장
#     - 추후 다른 데이터와의 연결 고리 역할 수행
#     - ouid = `56f931578b228109e8e44599da41ea64`

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}
  
characterName = "Ithas"
urlString = "https://open.api.nexon.com/fconline/v1/id?nickname=" + characterName
response = requests.get(urlString, headers = headers)

ouid = response.json()['ouid']
ouid
# Out:
# '56f931578b228109e8e44599da41ea64'

# %% [markdown]
# #### ㄴ 매치 ID 리스트 생성
# - 매치 상세 정보를 조회하는 API에 연동하기 위해 매치 ID 리스트 생성

# %%
# 매치 기록 조회(최근 매치 ID 리스트 생성)
urlString = "https://open.api.nexon.com/fconline/v1/user/match?ouid=56f931578b228109e8e44599da41ea64&matchtype=50&offset=0&limit=100"
response = requests.get(urlString, headers = headers)

# 매치 ID 리스트 생성
match_id_list = response.json()
match_id_list
# Out:
# ['67dfd655a90c32a27f4a1e0f',
#  '67dd8645ec70212298a55f7b',
#  '67dd8231dda981e2e4199dc0',
#  '67dd7e67c75c081c46ba90c3',
#  '67dd7b7c4f01878ae65bd76c',
#  '67dd78c9c3d42c6d9d886176',
#  '67dd7510b36edd0a5199b8de',
#  '67dd721c8afaaf18c7574daa',
#  '67dd6f48b23c74d8fd8b11d7',
#  '67dd6cc0632b415e80a9d58d',
#  '67dd6a476fb2bd6b95c4b63d',
#  '67dd67a24be0a1e397cec6dd',
#  '67dd650053e5e88154781b92',
#  '67dd625e1c27c154b533a0aa',
#  '67bde18ff7a57a50de59824f',
#  '67bddedacb7a0585fb3ec221',
#  '67bddc42b13d371b1b6b8499',
#  '67bdd9e2b4a4bc70f6b06af4']

# %%
# 내 경기 수
len(match_id_list)
# Out:
# 18

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
match_info_list = []
for match_id in match_id_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    match_info_list.append(res.json())

# 예시) 매치ID별 정보
match_info_list[0]
# Out:
# {'matchId': '67dfd655a90c32a27f4a1e0f',
#  'matchDate': '2025-03-23T09:40:18',
#  'matchType': 50,
#  'matchInfo': [{'ouid': 'c34cb1bfe8d9c99068f6bb94c44ceb24',
#    'nickname': '지구침공외계인',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 2,
#     'systemPause': None,
#     'foul': None,
#     'injury': None,
#     'redCards': None,
#     'yellowCards': None,
#     'dribble': None,
#     'cornerKick': None,
#     'possession': None,
#     'offsideCount': None,
#     'averageRating': None,
#     'controller': None},
#    'shoot': {'shootTotal': None,
#     'effectiveShootTotal': None,
#     'shootOutScore': None,
#     'goalTotal': None,
#     'goalTotalDisplay': 0,
#     'ownGoal': None,
#     'shootHeading': None,
#     'goalHeading': None,
#     'shootFreekick': None,
#     'goalFreekick': None,
#     'shootInPenalty': None,
#     'goalInPenalty': None,
#     'shootOutPenalty': None,
#     'goalOutPenalty': None,
#     'shootPenaltyKick': None,
#     'goalPenaltyKick': None},
#    'shootDetail': [],
#    'pass': {'passTry': None,
#     'passSuccess': None,
#     'shortPassTry': None,
#     'shortPassSuccess': None,
#     'longPassTry': None,
#     'longPassSuccess': None,
#     'bouncingLobPassTry': None,
#     'bouncingLobPassSuccess': None,
#     'drivenGroundPassTry': None,
#     'drivenGroundPassSuccess': None,
#     'throughPassTry': None,
#     'throughPassSuccess': None,
#     'lobbedThroughPassTry': None,
#     'lobbedThroughPassSuccess': None},
#    'defence': {'blockTry': None,
#     'blockSuccess': None,
#     'tackleTry': None,
#     'tackleSuccess': None},
#    'player': []},
#   {'ouid': '56f931578b228109e8e44599da41ea64',
#    'nickname': 'Ithas',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '승',
#     'matchEndType': 1,
#     'systemPause': 0,
#     'foul': 1,
#     'injury': 1,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 97,
#     'cornerKick': 2,
#     'possession': 63,
#     'offsideCount': 3,
#     'averageRating': 5.31111,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 23,
#     'effectiveShootTotal': 17,
#     'shootOutScore': 0,
#     'goalTotal': 11,
#     'goalTotalDisplay': 3,
#     'ownGoal': 0,
#     'shootHeading': 1,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 20,
#     'goalInPenalty': 11,
#     'shootOutPenalty': 3,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 16780103,
#      'x': 0.8846755027770996,
#      'y': 0.4484608173370361,
#      'type': 4,
#      'result': 2,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778907,
#      'x': 0.9349101185798644,
#      'y': 0.4453180432319641,
#      'type': 2,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.9201199412345886,
#      'assistY': 0.6473828554153442,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778042,
#      'x': 0.9078167080879213,
#      'y': 0.50694453716278,
#      'type': 6,
#      'result': 3,
#      'spId': 256192985,
#      'spGrade': 8,
#      'spLevel': 3,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.869403600692749,
#      'assistY': 0.3435972929000854,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2664,
#      'x': 0.9573287963867188,
#      'y': 0.4391169250011444,
#      'type': 2,
#      'result': 1,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 455,
#      'x': 0.833352267742157,
#      'y': 0.5123793482780457,
#      'type': 2,
#      'result': 1,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.6984274387359619,
#      'assistY': 0.520372748374939,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16778751,
#      'x': 0.8975286483764648,
#      'y': 0.45083075761795,
#      'type': 2,
#      'result': 3,
#      'spId': 256004833,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.7664544582366943,
#      'assistY': 0.4940182566642761,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779039,
#      'x': 0.78716504573822,
#      'y': 0.4700033366680145,
#      'type': 2,
#      'result': 2,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004231,
#      'assistX': 0.52048921585083,
#      'assistY': 0.7598427534103394,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16778324,
#      'x': 0.920162320137024,
#      'y': 0.3655575811862946,
#      'type': 3,
#      'result': 2,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778502,
#      'x': 0.932461678981781,
#      'y': 0.42125779390335,
#      'type': 2,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.903243362903595,
#      'assistY': 0.3302620947360992,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778255,
#      'x': 0.8773319125175476,
#      'y': 0.56567633152008,
#      'type': 1,
#      'result': 1,
#      'spId': 256004833,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.8089778423309326,
#      'assistY': 0.4751672446727753,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779452,
#      'x': 0.9397487044334412,
#      'y': 0.5617066025733948,
#      'type': 2,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.9285283088684082,
#      'assistY': 0.4130463600158691,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2014,
#      'x': 0.91922527551651,
#      'y': 0.4381535947322845,
#      'type': 2,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777633,
#      'x': 0.9826474785804749,
#      'y': 0.5882213115692139,
#      'type': 6,
#      'result': 3,
#      'spId': 256004231,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.9295862317085266,
#      'assistY': 0.3155115842819214,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2095,
#      'x': 0.8944694995880127,
#      'y': 0.5466709136962891,
#      'type': 6,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1703,
#      'x': 0.92251455783844,
#      'y': 0.4583349823951721,
#      'type': 2,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256215914,
#      'assistX': 0.82962292432785,
#      'assistY': 0.5742377638816833,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777406,
#      'x': 0.9018809199333192,
#      'y': 0.4071837067604065,
#      'type': 1,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256215914,
#      'assistX': 0.8718612194061279,
#      'assistY': 0.3444676399230957,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779263,
#      'x': 0.8958835601806641,
#      'y': 0.5532712936401367,
#      'type': 2,
#      'result': 2,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004231,
#      'assistX': 0.7633394002914429,
#      'assistY': 0.69512003660202,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 310,
#      'x': 0.9004387855529785,
#      'y': 0.631717324256897,
#      'type': 6,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779980,
#      'x': 0.9441914558410645,
#      'y': 0.53262847661972,
#      'type': 2,
#      'result': 3,
#      'spId': 256192985,
#      'spGrade': 8,
#      'spLevel': 3,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.9310775399208068,
#      'assistY': 0.3717216849327087,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2676,
#      'x': 0.96431165933609,
#      'y': 0.4753863215446472,
#      'type': 6,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.9491097331047058,
#      'assistY': 0.2709378004074097,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2404,
#      'x': 0.9479503035545348,
#      'y': 0.5677207112312317,
#      'type': 3,
#      'result': 2,
#      'spId': 256140601,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2336,
#      'x': 0.8310275077819824,
#      'y': 0.6243335008621216,
#      'type': 2,
#      'result': 1,
#      'spId': 256192985,
#      'spGrade': 8,
#      'spLevel': 3,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.73841768503189,
#      'assistY': 0.4761486649513245,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 334,
#      'x': 0.9693084359169,
#      'y': 0.3643764257431,
#      'type': 1,
#      'result': 2,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 152,
#     'passSuccess': 149,
#     'shortPassTry': 113,
#     'shortPassSuccess': 112,
#     'longPassTry': 3,
#     'longPassSuccess': 3,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 3,
#     'drivenGroundPassSuccess': 3,
#     'throughPassTry': 33,
#     'throughPassSuccess': 31,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 3,
#     'blockSuccess': 1,
#     'tackleTry': 10,
#     'tackleSuccess': 8},
#    'player': [{'spId': 256001041,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 82,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 5,
#       'passSuccess': 5,
#       'dribbleTry': 4,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 2,
#       'aerialSuccess': 1,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.3}},
#     {'spId': 256004833,
#      'spPosition': 27,
#      'spGrade': 8,
#      'status': {'shoot': 2,
#       'effectiveShoot': 2,
#       'assist': 4,
#       'goal': 1,
#       'dribble': 226,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 18,
#       'passSuccess': 18,
#       'dribbleTry': 10,
#       'dribbleSuccess': 10,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.9}},
#     {'spId': 256051539,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 4,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.2}},
#     {'spId': 234192119,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256215914,
#      'spPosition': 10,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 2,
#       'goal': 0,
#       'dribble': 70,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 19,
#       'passSuccess': 19,
#       'dribbleTry': 9,
#       'dribbleSuccess': 9,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.1}},
#     {'spId': 256001109,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 92,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'dribbleTry': 5,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 1,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.3}},
#     {'spId': 256004231,
#      'spPosition': 23,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 31,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.0}},
#     {'spId': 251005099,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256242519,
#      'spPosition': 25,
#      'spGrade': 8,
#      'status': {'shoot': 7,
#       'effectiveShoot': 5,
#       'assist': 2,
#       'goal': 3,
#       'dribble': 486,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 31,
#       'passSuccess': 31,
#       'dribbleTry': 25,
#       'dribbleSuccess': 24,
#       'ballPossesionTry': 13,
#       'ballPossesionSuccess': 8,
#       'aerialTry': 2,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.8}},
#     {'spId': 256140601,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 10,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 13,
#       'aerialSuccess': 1,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.7}},
#     {'spId': 256192985,
#      'spPosition': 13,
#      'spGrade': 8,
#      'status': {'shoot': 3,
#       'effectiveShoot': 3,
#       'assist': 1,
#       'goal': 2,
#       'dribble': 321,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 18,
#       'passSuccess': 17,
#       'dribbleTry': 11,
#       'dribbleSuccess': 11,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.9}},
#     {'spId': 274000250,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256007289,
#      'spPosition': 4,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 1,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.6}},
#     {'spId': 256001075,
#      'spPosition': 19,
#      'spGrade': 8,
#      'status': {'shoot': 9,
#       'effectiveShoot': 6,
#       'assist': 1,
#       'goal': 4,
#       'dribble': 703,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 37,
#       'passSuccess': 35,
#       'dribbleTry': 27,
#       'dribbleSuccess': 26,
#       'ballPossesionTry': 14,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.8}},
#     {'spId': 256214098,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 289261593,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 253188377,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 268192181,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
import pandas as pd

# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/2290921625.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67dfd655a90c32a27f4a1e0f  2025-03-23T09:40:18        50
# 1  67dfd655a90c32a27f4a1e0f  2025-03-23T09:40:18        50
# 2  67dfd655a90c32a27f4a1e0f  2025-03-23T09:40:18        50
# 3  67dfd655a90c32a27f4a1e0f  2025-03-23T09:40:18        50
# 4  67dfd655a90c32a27f4a1e0f  2025-03-23T09:40:18        50
#
#                                ouid nickname matchResult possession  \
# 0  56f931578b228109e8e44599da41ea64    Ithas           승         63
# 1  56f931578b228109e8e44599da41ea64    Ithas           승         63
# 2  56f931578b228109e8e44599da41ea64    Ithas           승         63
# 3  56f931578b228109e8e44599da41ea64    Ithas           승         63
# 4  56f931578b228109e8e44599da41ea64    Ithas           승         63
#
#    averageRating dribble cornerKick  ...  goalTime         x         y type  \
# 0        5.31111      97          2  ...  16780103  0.884676  0.448461    4
# 1        5.31111      97          2  ...  16778907  0.934910  0.445318    2
# 2        5.31111      97          2  ...  16778042  0.907817  0.506945    6
# 3        5.31111      97          2  ...      2664  0.957329  0.439117    2
# 4        5.31111      97          2  ...       455  0.833352  0.512379    2
#
#   result       spId assist assistSpId hitPost inPenalty
# 0      2  256242519  False         -1   False      True
# 1      3  256242519   True  256192985   False      True
# 2      3  256192985   True  256001075   False      True
# 3      1  256001075  False         -1   False      True
# 4      1  256001075   True  256242519   False     False
#
# [5 rows x 38 columns]

# %%
match_df.T
# Out:
#                                                   0    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                     16780103
# x                                            0.884676
# y                                            0.448461
# type                                                4
# result                                              2
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   1    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                     16778907
# x                                             0.93491
# y                                            0.445318
# type                                                2
# result                                              3
# spId                                        256242519
# assist                                           True
# assistSpId                                  256192985
# hitPost                                         False
# inPenalty                                        True
#
#                                                   2    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                     16778042
# x                                            0.907817
# y                                            0.506945
# type                                                6
# result                                              3
# spId                                        256192985
# assist                                           True
# assistSpId                                  256001075
# hitPost                                         False
# inPenalty                                        True
#
#                                                   3    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                         2664
# x                                            0.957329
# y                                            0.439117
# type                                                2
# result                                              1
# spId                                        256001075
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   4    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                          455
# x                                            0.833352
# y                                            0.512379
# type                                                2
# result                                              1
# spId                                        256001075
# assist                                           True
# assistSpId                                  256242519
# hitPost                                         False
# inPenalty                                       False
#
#                                                   5    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                     16778751
# x                                            0.897529
# y                                            0.450831
# type                                                2
# result                                              3
# spId                                        256004833
# assist                                           True
# assistSpId                                  256242519
# hitPost                                         False
# inPenalty                                        True
#
#                                                   6    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                     16779039
# x                                            0.787165
# y                                            0.470003
# type                                                2
# result                                              2
# spId                                        256001075
# assist                                           True
# assistSpId                                  256004231
# hitPost                                         False
# inPenalty                                       False
#
#                                                   7    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                     16778324
# x                                            0.920162
# y                                            0.365558
# type                                                3
# result                                              2
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   8    \
# matchId                      67dfd655a90c32a27f4a1e0f
# matchDate                         2025-03-23T09:40:18
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         63
# averageRating                                 5.31111
# dribble                                            97
# cornerKick                                          2
# offsideCount                                        3
# shootTotal                                         23
# effectiveShootTotal                                17
# goalTotal                                          11
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           152
# passSuccess                                       149
# shortPassTry                                      113
# shortPassSuccess                                  112
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     33
# throughPassSuccess                                 31
# tackleTry                                          10
# tackleSuccess                                       8
# blockTry                                            3
# blockSuccess                                        1
# goalTime                                     16778502
# x                                            0.932462
# y                                            0.421258
# type                                                2
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                        True
#
#                                                   9    ...  \
# matchId                      67dfd655a90c32a27f4a1e0f  ...
# matchDate                         2025-03-23T09:40:18  ...
# matchType                                          50  ...
# ouid                 56f931578b228109e8e44599da41ea64  ...
# nickname                                        Ithas  ...
# matchResult                                         승  ...
# possession                                         63  ...
# averageRating                                 5.31111  ...
# dribble                                            97  ...
# cornerKick                                          2  ...
# offsideCount                                        3  ...
# shootTotal                                         23  ...
# effectiveShootTotal                                17  ...
# goalTotal                                          11  ...
# shootPenaltyKick                                    0  ...
# goalPenaltyKick                                     0  ...
# passTry                                           152  ...
# passSuccess                                       149  ...
# shortPassTry                                      113  ...
# shortPassSuccess                                  112  ...
# longPassTry                                         3  ...
# longPassSuccess                                     3  ...
# throughPassTry                                     33  ...
# throughPassSuccess                                 31  ...
# tackleTry                                          10  ...
# tackleSuccess                                       8  ...
# blockTry                                            3  ...
# blockSuccess                                        1  ...
# goalTime                                     16778255  ...
# x                                            0.877332  ...
# y                                            0.565676  ...
# type                                                1  ...
# result                                              1  ...
# spId                                        256004833  ...
# assist                                           True  ...
# assistSpId                                  256001075  ...
# hitPost                                         False  ...
# inPenalty                                        True  ...
#
#                                                   155  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                         1375
# x                                            0.862332
# y                                            0.464629
# type                                                2
# result                                              3
# spId                                        825158023
# assist                                           True
# assistSpId                                  284189332
# hitPost                                         False
# inPenalty                                        True
#
#                                                   156  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                     16780055
# x                                            0.801025
# y                                            0.376337
# type                                                2
# result                                              2
# spId                                        832188545
# assist                                           True
# assistSpId                                  832194765
# hitPost                                         False
# inPenalty                                       False
#
#                                                   157  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                     16779431
# x                                            0.890541
# y                                            0.678913
# type                                                2
# result                                              2
# spId                                        284189332
# assist                                           True
# assistSpId                                  825158023
# hitPost                                         False
# inPenalty                                        True
#
#                                                   158  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                          332
# x                                             0.80485
# y                                            0.499665
# type                                                2
# result                                              2
# spId                                        832188545
# assist                                           True
# assistSpId                                  825190045
# hitPost                                         False
# inPenalty                                       False
#
#                                                   159  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# possession                                         55
# averageRating                                 3.28889
# dribble                                            86
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           118
# passSuccess                                       110
# shortPassTry                                       95
# shortPassSuccess                                   91
# longPassTry                                         5
# longPassSuccess                                     4
# throughPassTry                                     13
# throughPassSuccess                                 12
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                         1211
# x                                            0.830459
# y                                            0.502408
# type                                                1
# result                                              1
# spId                                        256242519
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                       False
#
#                                                   160  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# possession                                         55
# averageRating                                 3.28889
# dribble                                            86
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           118
# passSuccess                                       110
# shortPassTry                                       95
# shortPassSuccess                                   91
# longPassTry                                         5
# longPassSuccess                                     4
# throughPassTry                                     13
# throughPassSuccess                                 12
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16778062
# x                                             0.92192
# y                                            0.417734
# type                                                6
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256214098
# hitPost                                         False
# inPenalty                                        True
#
#                                                   161  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# possession                                         55
# averageRating                                 3.28889
# dribble                                            86
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           118
# passSuccess                                       110
# shortPassTry                                       95
# shortPassSuccess                                   91
# longPassTry                                         5
# longPassSuccess                                     4
# throughPassTry                                     13
# throughPassSuccess                                 12
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16778926
# x                                            0.932863
# y                                            0.453695
# type                                                2
# result                                              1
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   162  \
# matchId                      67bdd9e2b4a4bc70f6b06af4
# matchDate                         2025-02-25T15:05:26
# matchType                                          50
# ouid                 182bd52c7e7300b878962c93242b5255
# nickname                                     내가만든구역이야
# matchResult                                         무
# possession                                         45
# averageRating                                 3.92778
# dribble                                            75
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          2
# effectiveShootTotal                                 2
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           120
# passSuccess                                       109
# shortPassTry                                      102
# shortPassSuccess                                   96
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     13
# throughPassSuccess                                 10
# tackleTry                                          15
# tackleSuccess                                      10
# blockTry                                            6
# blockSuccess                                        0
# goalTime                                     16777402
# x                                            0.776818
# y                                            0.421705
# type                                               12
# result                                              3
# spId                                        810210514
# assist                                           True
# assistSpId                                  820236499
# hitPost                                         False
# inPenalty                                       False
#
#                                                   163  \
# matchId                      67bdd9e2b4a4bc70f6b06af4
# matchDate                         2025-02-25T15:05:26
# matchType                                          50
# ouid                 182bd52c7e7300b878962c93242b5255
# nickname                                     내가만든구역이야
# matchResult                                         무
# possession                                         45
# averageRating                                 3.92778
# dribble                                            75
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          2
# effectiveShootTotal                                 2
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           120
# passSuccess                                       109
# shortPassTry                                      102
# shortPassSuccess                                   96
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     13
# throughPassSuccess                                 10
# tackleTry                                          15
# tackleSuccess                                      10
# blockTry                                            6
# blockSuccess                                        0
# goalTime                                     16779042
# x                                            0.809854
# y                                            0.513962
# type                                                2
# result                                              1
# spId                                        825247703
# assist                                           True
# assistSpId                                  801001397
# hitPost                                         False
# inPenalty                                       False
#
#                                                   164
# matchId                      67bdd9e2b4a4bc70f6b06af4
# matchDate                         2025-02-25T15:05:26
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# possession                                         55
# averageRating                                 3.98889
# dribble                                            96
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          1
# effectiveShootTotal                                 1
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           143
# passSuccess                                       131
# shortPassTry                                      117
# shortPassSuccess                                  112
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     20
# throughPassSuccess                                 15
# tackleTry                                           5
# tackleSuccess                                       2
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16778384
# x                                            0.915684
# y                                            0.442534
# type                                                6
# result                                              3
# spId                                        256215914
# assist                                           True
# assistSpId                                  256001075
# hitPost                                         False
# inPenalty                                        True
#
# [38 rows x 165 columns]

# %% [markdown]
# ### 2) 최근 100경기 매치 기록(전체 유저)
# - 내 기록과 비교 분석할 전체 유저의 최근 100경기 매치 기록 불러오기
# - 공식경기 기준 100경기

# %% [markdown]
# #### ㄴ 최근 100경기 매치 ID 불러오기

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/fconline/v1/match?matchtype=50&offset=0&limit=100&orderby=desc"
response = requests.get(urlString, headers = headers)

all_match_list = response.json()
all_match_list
# Out:
# ['67dfdb40bece66f76ebed311',
#  '67dfdb2cffc7b2223341cf28',
#  '67dfdb1d2e0db02a32027cf2',
#  '67dfdb1b3a38ac88cd1e1243',
#  '67dfdb1a8a1ee8788f3e6130',
#  '67dfdb17e795d740a68bdf08',
#  '67dfdb0533e4d096001a10e6',
#  '67dfdb01b6d0146f67028a3a',
#  '67dfdafef454c424ce55c458',
#  '67dfdafec8cc200951fc40ee',
#  '67dfdafdbce4b369126eb90a',
#  '67dfdaf89fd729062c25834a',
#  '67dfdaef17df42b46a55e903',
#  '67dfdaeae95864d2922bf987',
#  '67dfdaea8f28057e623fbaf9',
#  '67dfdae99a68ee5f389b12c8',
#  '67dfdadc511b0fb0f8a2e170',
#  '67dfdadbb159571a598f6c2e',
#  '67dfdadaa7af236335fbe595',
#  '67dfdad993695e071dfc2673',
#  '67dfdad7dfd8ebd3c5d74a82',
#  '67dfdad4b04ba085f08fcab6',
#  '67dfdacfcba669d45f0d2e2a',
#  '67dfdacb5ba99d2ba0238768',
#  '67dfdac967c353977ac6a5c8',
#  '67dfdac8c2a754d68edcc710',
#  '67dfdac2da6cf7c7866fdb67',
#  '67dfdac196b0fe9f723eaef9',
#  '67dfdac137f20e65c1ec6f49',
#  '67dfdac04637e34348ec22da',
#  '67dfdabf6fb8540a50b13007',
#  '67dfdabdc0f69b29b37a44d1',
#  '67dfdabc811724ebc8355d42',
#  '67dfdabc20e6e52b0536b159',
#  '67dfdabb646f960b3a307413',
#  '67dfdab95245b06894b0cc3a',
#  '67dfdab92c5f2f153bd74d00',
#  '67dfdab85301075aa3a6e1c3',
#  '67dfdab4d412d978b62257ff',
#  '67dfdaaec6a4f5415d797995',
#  '67dfdaaea7c7af16e8cb3f97',
#  '67dfdaa8bda05c80fb11a087',
#  '67dfdaa71a0c5f93d2a2c7bb',
#  '67dfdaa0218102a5de0be2fd',
#  '67dfda9d31f208d818454fbe',
#  '67dfda9cb24ec56f60c6bdd9',
#  '67dfda9c3562df1f8b87eea3',
#  '67dfda975cef564e265372bc',
#  '67dfda947d47bbc423ce4698',
#  '67dfda9452dd5432df890abe',
#  '67dfda91861093a10a7b98f1',
#  '67dfda9134bdadca25326b58',
#  '67dfda8fad4ca92420261e5b',
#  '67dfda8e6789ee5b175f6419',
#  '67dfda8e08aca580188818c2',
#  '67dfda8ded564cf2bf0567aa',
#  '67dfda8cb049e2e7ac224532',
#  '67dfda8c3511df45a292277e',
#  '67dfda89fa2a70570901657c',
#  '67dfda8883410b7bdc56c191',
#  '67dfda855873501716c4cd6c',
#  '67dfda836470145e54537d75',
#  '67dfda7f44f423a315ae98b6',
#  '67dfda7eb01426519a4df67e',
#  '67dfda7c5cb8816f18fab84b',
#  '67dfda790f1bef0fca8eb86b',
#  '67dfda784506cc191481b46f',
#  '67dfda7695009913f8ff6a2a',
#  '67dfda72cf458c993e02912a',
#  '67dfda698bb602e0127fb8ce',
#  '67dfda68882c53064772745e',
#  '67dfda68225cc5331a88f819',
#  '67dfda6723c667515a85925b',
#  '67dfda66528eb54537d24277',
#  '67dfda660845b1e8f70941f0',
#  '67dfda6313746266aaa2be77',
#  '67dfda62801ef7bf6187ee17',
#  '67dfda5fca658bd426dfd330',
#  '67dfda5d66109c21d9e67d0a',
#  '67dfda5a985b91307b63cebf',
#  '67dfda59406537c5518a87dc',
#  '67dfda57aff4969f1206f887',
#  '67dfda55e7f259634aa8d3b5',
#  '67dfda5514ad40765840d6b3',
#  '67dfda51df0c71efce237d24',
#  '67dfda50cb1410d166ed35a4',
#  '67dfda4efee7366fd73ada2f',
#  '67dfda4ef655fab1d0854716',
#  '67dfda46c09b9a35de3c33df',
#  '67dfda445ace51289670e97f',
#  '67dfda4355c01a39f03c9167',
#  '67dfda435572052837bf09be',
#  '67dfda3ff1e8be0f94c437ec',
#  '67dfda3fbb265b0d8b3eb772',
#  '67dfda3f5b48362869ec65fd',
#  '67dfda3f5b01d9796ba5dd92',
#  '67dfda3f3d6ca5efce52537c',
#  '67dfda3c98be383a27ad0afd',
#  '67dfda3c833c583a1d76ee83',
#  '67dfda37119f3bc174a0ca0f']

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
all_match_info_list = []
for match_id in all_match_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    all_match_info_list.append(res.json())

# 예시) 매치ID별 정보
all_match_info_list[0]
# Out:
# {'matchId': '67dfdb40bece66f76ebed311',
#  'matchDate': '2025-03-23T09:58:55',
#  'matchType': 50,
#  'matchInfo': [{'ouid': '668643b79a2d33d1aad84a7f1e4c62bb',
#    'nickname': '파리생텍쥐베르',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 2,
#     'systemPause': None,
#     'foul': None,
#     'injury': None,
#     'redCards': None,
#     'yellowCards': None,
#     'dribble': None,
#     'cornerKick': None,
#     'possession': None,
#     'offsideCount': None,
#     'averageRating': None,
#     'controller': None},
#    'shoot': {'shootTotal': None,
#     'effectiveShootTotal': None,
#     'shootOutScore': None,
#     'goalTotal': None,
#     'goalTotalDisplay': 0,
#     'ownGoal': None,
#     'shootHeading': None,
#     'goalHeading': None,
#     'shootFreekick': None,
#     'goalFreekick': None,
#     'shootInPenalty': None,
#     'goalInPenalty': None,
#     'shootOutPenalty': None,
#     'goalOutPenalty': None,
#     'shootPenaltyKick': None,
#     'goalPenaltyKick': None},
#    'shootDetail': [],
#    'pass': {'passTry': None,
#     'passSuccess': None,
#     'shortPassTry': None,
#     'shortPassSuccess': None,
#     'longPassTry': None,
#     'longPassSuccess': None,
#     'bouncingLobPassTry': None,
#     'bouncingLobPassSuccess': None,
#     'drivenGroundPassTry': None,
#     'drivenGroundPassSuccess': None,
#     'throughPassTry': None,
#     'throughPassSuccess': None,
#     'lobbedThroughPassTry': None,
#     'lobbedThroughPassSuccess': None},
#    'defence': {'blockTry': None,
#     'blockSuccess': None,
#     'tackleTry': None,
#     'tackleSuccess': None},
#    'player': []},
#   {'ouid': '7ee02bc735ebfe5389eb37e8f6822693',
#    'nickname': 'MUN박채영',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '승',
#     'matchEndType': 1,
#     'systemPause': 1,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 0,
#     'cornerKick': 0,
#     'possession': 0,
#     'offsideCount': 0,
#     'averageRating': 3.66667,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 0,
#     'effectiveShootTotal': 0,
#     'shootOutScore': 0,
#     'goalTotal': 0,
#     'goalTotalDisplay': 3,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 0,
#     'goalInPenalty': 0,
#     'shootOutPenalty': 0,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [],
#    'pass': {'passTry': 0,
#     'passSuccess': 0,
#     'shortPassTry': 0,
#     'shortPassSuccess': 0,
#     'longPassTry': 0,
#     'longPassSuccess': 0,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 0,
#     'drivenGroundPassSuccess': 0,
#     'throughPassTry': 0,
#     'throughPassSuccess': 0,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 0,
#     'blockSuccess': 0,
#     'tackleTry': 0,
#     'tackleSuccess': 0},
#    'player': [{'spId': 829200145,
#      'spPosition': 10,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 826234574,
#      'spPosition': 3,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 270239301,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 820269087,
#      'spPosition': 4,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 291205988,
#      'spPosition': 7,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 825233064,
#      'spPosition': 13,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 256005589,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 834260247,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 268001116,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 810204525,
#      'spPosition': 28,
#      'spGrade': 3,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 826268438,
#      'spPosition': 27,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 834241461,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 832212198,
#      'spPosition': 15,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 826226753,
#      'spPosition': 0,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 834210881,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 820250961,
#      'spPosition': 25,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 813167198,
#      'spPosition': 28,
#      'spGrade': 2,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 804254088,
#      'spPosition': 23,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}}]}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

all_match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in all_match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
all_match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_37859/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67dfdb2cffc7b2223341cf28  2025-03-23T09:59:42        50
# 1  67dfdb1a8a1ee8788f3e6130  2025-03-23T09:59:03        50
# 2  67dfdb17e795d740a68bdf08  2025-03-23T09:59:50        50
# 3  67dfdb17e795d740a68bdf08  2025-03-23T09:59:50        50
# 4  67dfdaea8f28057e623fbaf9  2025-03-23T09:58:53        50
#
#                                ouid nickname matchResult possession  \
# 0  11e680208c9d26a251023337fcf4e870     망고욱현           승         62
# 1  5403c8a5423a2c08696f68a32bc816c6  찌랭이0327           승         44
# 2  7e09a42b042a3ca88ba0d8214c61fc79   구단주댄스바           패         48
# 3  7e09a42b042a3ca88ba0d8214c61fc79   구단주댄스바           패         48
# 4  62ce1ea7553b9306f327702dfeaa0ba9   JEON영진           패         60
#
#    averageRating dribble cornerKick  ... goalTime         x         y type  \
# 0        4.38333       4          0  ...      232  0.906021  0.670537    2
# 1        3.98889       5          1  ...      573  0.839968  0.387843    2
# 2        3.49444       7          1  ...      475  0.783291  0.395553    4
# 3        3.49444       7          1  ...      135  0.908727  0.547382    1
# 4        3.71111      10          0  ...      490  0.928970  0.413836    6
#
#   result       spId assist assistSpId hitPost inPenalty
# 0      3  291240452   True  829227232   False      True
# 1      3  832256630   True  291240709   False     False
# 2      2  826225539  False         -1   False     False
# 3      1  826225539   True  270243702   False      True
# 4      1  832194765   True  825028130   False      True
#
# [5 rows x 38 columns]

# %%
# 파일로 저장
all_match_df.to_csv("250323_recent_matches.csv", index=False, encoding='utf-8-sig')
