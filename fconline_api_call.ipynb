# %% [markdown]
# # FC온라인 API 연결

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. 데이터 설명

# %% [markdown]
# #### 매치 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **matchId**                | string     | 64f0000c00007210005f0000  | 매치 고유 식별자                                   |
# | **matchDate**              | string     | 2023-10-29T12:22:48       | 매치 일자 (UTC0)                                 |
# | **matchType**              | integer    | 52                        | 매치 종류 (/metadata/matchtype API 참고)          |
#
#
# #### matchDetails : 매치 참여 플레이어별 매치 상세
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **ouid**       | string     |                           | 계정 식별자                                        |
# | **nickname**   | string     | 닉네임                    | 유저 닉네임                                        |
#
# #### matchDetail : 매치 결과 상세 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **seasonId**          | integer  | 202311               | 시즌 ID                                            |
# | **matchResult**       | string   | 승                  | 매치 결과 (“승”, “무”, “패”)                      |
# | **matchEndType**      | integer  | 0                   | 매치 종료 타입 (0 정상종료, 1 몰수승, 2 몰수패)   |
# | **systemPause**       | integer  | 0                   | 게임 일시정지 수                                   |
# | **foul**              | integer  | 0                   | 파울 수                                            |
# | **injury**            | integer  | 1                   | 부상 수                                            |
# | **redCards**          | integer  | 0                   | 받은 레드카드 수                                   |
# | **yellowCards**       | integer  | 0                   | 받은 옐로카드 수                                   |
# | **dribble**           | integer  | 78                  | 드리블 거리(야드)                                  |
# | **cornerKick**        | integer  | 0                   | 코너킥 수                                          |
# | **possession**        | integer  | 46                  | 점유율                                             |
# | **offsideCount**      | integer  | 1                   | 오프사이드 수                                      |
# | **averageRating**     | number   | 1.18889             | 경기 평점                                          |
# | **controller**        | string   | keyboard            | 사용한 컨트롤러 타입 (keyboard / pad / etc 중 1)  |
#
#
# #### shoot : 슈팅 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **shoot**                 | object      |                           | 슈팅 정보                                          |
# | **shootTotal**                 | integer  | 3                   | 총 슛 수                                           |
# | **effectiveShootTotal**         | integer  | 3                   | 총 유효슛 수                                       |
# | **shootOutScore**              | integer  | 0                   | 승부차기 슛 수                                     |
# | **goalTotal**                  | integer  | 2                   | 총 골 수                                           |
# | **goalTotalDisplay**           | integer  | 2                   | 게임 종료 후 유저에게 노출되는 골 수              |
# | **ownGoal**                    | integer  | 0                   | 자책 골 수                                         |
# | **shootHeading**               | integer  | 2                   | 헤딩 슛 수                                         |
# | **goalHeading**                | integer  | 1                   | 헤딩 골 수                                         |
# | **shootFreekick**              | integer  | 0                   | 프리킥 슛 수                                       |
# | **goalFreekick**               | integer  | 0                   | 프리킥 골 수                                       |
# | **shootInPenalty**             | integer  | 3                   | 인패널티 슛 수                                     |
# | **goalInPenalty**              | integer  | 2                   | 인패널티 골 수                                     |
# | **shootOutPenalty**            | integer  | 0                   | 아웃패널티 슛 수                                   |
# | **goalOutPenalty**             | integer  | 0                   | 아웃패널티 골 수                                   |
# | **shootPenaltyKick**           | integer  | 0                   | 패널티킥 슛 수                                     |
# | **goalPenaltyKick**            | integer  | 0                   | 패널티킥 골 수                                     |
#
# #### pass : 패스 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **passTry**                    | integer  | 92                  | 패스 시도 수                                       |
# | **passSuccess**                | integer  | 83                  | 패스 성공 수                                       |
# | **shortPassTry**               | integer  | 55                  | 숏 패스 시도 수                                    |
# | **shortPassSuccess**           | integer  | 55                  | 숏 패스 성공 수                                    |
# | **longPassTry**                | integer  | 3                   | 롱 패스 시도 수                                    |
# | **longPassSuccess**            | integer  | 3                   | 롱 패스 성공 수                                    |
# | **bouncingLobPassTry**         | integer  | 1                   | 바운싱 롭 패스 시도 수                             |
# | **bouncingLobPassSuccess**     | integer  | 0                   | 바운싱 롭 패스 성공 수                             |
# | **drivenGroundPassTry**        | integer  | 10                  | 드리븐 땅볼 패스 시도 수                           |
# | **drivenGroundPassSuccess**    | integer  | 10                  | 드리븐 땅볼 패스 성공 수                           |
# | **throughPassTry**             | integer  | 19                  | 스루 패스 시도 수                                  |
# | **throughPassSuccess**         | integer  | 14                  | 스루 패스 성공 수                                  |
# | **lobbedThroughPassTry**       | integer  | 4                   | 로빙 스루 패스 시도 수                             |
# | **lobbedThroughPassSuccess**   | integer  | 1                   | 로빙 스루 패스 성공 수                             |
#
# #### defence : 수비 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **blockTry**                  | integer  | 3                   | 블락 시도 수                                       |
# | **blockSuccess**              | integer  | 0                   | 블락 성공 수                                       |
# | **tackleTry**                 | integer  | 11                  | 태클 시도 수                                       |
# | **tackleSuccess**             | integer  | 9                   | 태클 성공 수                                       |

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 데이터 분석 환경 조성

# %% [markdown]
# ### 라이브러리 호출

# %%
import requests
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### 매치 메타데이터 확인
# - 매치 타입 확인

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/static/fconline/meta/matchtype.json"
response = requests.get(urlString, headers = headers)

match_type = response.json()
match_type
# Out:
# [{'matchtype': 30, 'desc': '리그 친선'},
#  {'matchtype': 40, 'desc': '클래식 1on1'},
#  {'matchtype': 50, 'desc': '공식경기'},
#  {'matchtype': 52, 'desc': '감독모드'},
#  {'matchtype': 60, 'desc': '공식 친선'},
#  {'matchtype': 204, 'desc': '볼타 친선'},
#  {'matchtype': 214, 'desc': '볼타 공식'},
#  {'matchtype': 224, 'desc': '볼타 AI대전'},
#  {'matchtype': 234, 'desc': '볼타 커스텀'}]

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 데이터 프레임 생성

# %% [markdown]
# ### 1) 내 매치 기록

# %% [markdown]
# - 계정 식별자 정보 저장
#     - 추후 다른 데이터와의 연결 고리 역할 수행
#     - ouid = `56f931578b228109e8e44599da41ea64`

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}
  
characterName = "Ithas"
urlString = "https://open.api.nexon.com/fconline/v1/id?nickname=" + characterName
response = requests.get(urlString, headers = headers)

ouid = response.json()['ouid']
ouid
# Out:
# '56f931578b228109e8e44599da41ea64'

# %% [markdown]
# #### ㄴ 매치 ID 리스트 생성
# - 매치 상세 정보를 조회하는 API에 연동하기 위해 매치 ID 리스트 생성

# %%
# 매치 기록 조회(최근 매치 ID 리스트 생성)
urlString = "https://open.api.nexon.com/fconline/v1/user/match?ouid=56f931578b228109e8e44599da41ea64&matchtype=50&offset=0&limit=100"
response = requests.get(urlString, headers = headers)

# 매치 ID 리스트 생성
match_id_list = response.json()
match_id_list
# Out:
# ['67e3f253c1b497470d9cd1bb',
#  '67e3ef640655e14cb4e9d0f5',
#  '67e3ec99b6507c4202201a8a',
#  '67e3ea10175f93134fa05d18',
#  '67e2bcb4e500faa9061aa7e4',
#  '67e2b9c26abb4d343d209538',
#  '67e2b73c50ccfd375480ac37',
#  '67e2b465cdcccb1fb7ae1b28',
#  '67e2b1da9b8f6affd996c84c',
#  '67e141ab64bc4aadd4478f83',
#  '67e13eb6178c8e338ece2279',
#  '67e13c081041581f21b29426',
#  '67e13959aa13375901b07450',
#  '67e11d51d56b0f431020a326',
#  '67e115e2d31f25263ab3e538',
#  '67e11349b6764f2767dbbd64',
#  '67e110769c505b95184aa6e8',
#  '67e10dd5556da0916f3eb359',
#  '67dfedbd5315c6036c5ffb04',
#  '67dfecd36f1f400054c67cc7',
#  '67dfe8820d8347e2847e0e76',
#  '67dfe4e05b2baccd90a79566',
#  '67dfe1f9b5f1228c927f8d7b',
#  '67dfde8d027d0a782967f2dd',
#  '67dfdbd7c3b20515db2b2aaa',
#  '67dfd91e6950fe6c38f73dbd',
#  '67dfd655a90c32a27f4a1e0f',
#  '67dd8645ec70212298a55f7b',
#  '67dd8231dda981e2e4199dc0',
#  '67dd7e67c75c081c46ba90c3',
#  '67dd7b7c4f01878ae65bd76c',
#  '67dd78c9c3d42c6d9d886176',
#  '67dd7510b36edd0a5199b8de',
#  '67dd721c8afaaf18c7574daa',
#  '67dd6f48b23c74d8fd8b11d7',
#  '67dd6cc0632b415e80a9d58d',
#  '67dd6a476fb2bd6b95c4b63d',
#  '67dd67a24be0a1e397cec6dd',
#  '67dd650053e5e88154781b92',
#  '67dd625e1c27c154b533a0aa',
#  '67bde18ff7a57a50de59824f',
#  '67bddedacb7a0585fb3ec221',
#  '67bddc42b13d371b1b6b8499',
#  '67bdd9e2b4a4bc70f6b06af4']

# %%
# 내 경기 수
len(match_id_list)
# Out:
# 44

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
match_info_list = []
for match_id in match_id_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    match_info_list.append(res.json())

# 예시) 매치ID별 정보
match_info_list[0]
# Out:
# {'matchId': '67e3f253c1b497470d9cd1bb',
#  'matchDate': '2025-03-26T12:36:21',
#  'matchType': 50,
#  'matchInfo': [{'ouid': '721a614ddf103a32a76e70fdf954a74c',
#    'nickname': '피온하는마라토너',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 3,
#     'injury': 0,
#     'redCards': 1,
#     'yellowCards': 1,
#     'dribble': 61,
#     'cornerKick': 2,
#     'possession': 47,
#     'offsideCount': 1,
#     'averageRating': 3.66667,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 3,
#     'effectiveShootTotal': 3,
#     'shootOutScore': 0,
#     'goalTotal': 0,
#     'goalTotalDisplay': 0,
#     'ownGoal': 0,
#     'shootHeading': 1,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 2,
#     'goalInPenalty': 0,
#     'shootOutPenalty': 1,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 2040,
#      'x': 0.8251655697822571,
#      'y': 0.4603453874588013,
#      'type': 2,
#      'result': 1,
#      'spId': 829252371,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 289045661,
#      'assistX': 0.7788890600204468,
#      'assistY': 0.4016550481319427,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16778401,
#      'x': 0.8470256924629211,
#      'y': 0.4946580231189728,
#      'type': 2,
#      'result': 1,
#      'spId': 291189513,
#      'spGrade': 7,
#      'spLevel': 4,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 289045661,
#      'assistX': 0.7940178513526917,
#      'assistY': 0.377715528011322,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1584,
#      'x': 0.9271011352539062,
#      'y': 0.5677430033683777,
#      'type': 3,
#      'result': 1,
#      'spId': 289045661,
#      'spGrade': 6,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 97,
#     'passSuccess': 79,
#     'shortPassTry': 50,
#     'shortPassSuccess': 49,
#     'longPassTry': 7,
#     'longPassSuccess': 2,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 2,
#     'drivenGroundPassSuccess': 1,
#     'throughPassTry': 38,
#     'throughPassSuccess': 27,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 8,
#     'blockSuccess': 0,
#     'tackleTry': 15,
#     'tackleSuccess': 12},
#    'player': [{'spId': 825208618,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 237001668,
#      'spPosition': 10,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 130,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 11,
#       'passSuccess': 10,
#       'dribbleTry': 5,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 5,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.9}},
#     {'spId': 287231747,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 289045661,
#      'spPosition': 25,
#      'spGrade': 6,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 109,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 7,
#       'dribbleTry': 4,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 10,
#       'aerialSuccess': 1,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.4}},
#     {'spId': 291189513,
#      'spPosition': 15,
#      'spGrade': 7,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 314,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 15,
#       'passSuccess': 12,
#       'dribbleTry': 12,
#       'dribbleSuccess': 11,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.5}},
#     {'spId': 802197445,
#      'spPosition': 4,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 33,
#       'intercept': 3,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 5,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 5,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 4,
#       'tackle': 3,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.9}},
#     {'spId': 283005419,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 290238794,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 274161840,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 2,
#       'intercept': 3,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 1,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 2,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 4,
#       'tackle': 3,
#       'yellowCards': 1,
#       'redCards': 1,
#       'spRating': 5.8}},
#     {'spId': 825228618,
#      'spPosition': 2,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 138,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.0}},
#     {'spId': 810206585,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 3,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.9}},
#     {'spId': 827001040,
#      'spPosition': 8,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 256,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 7,
#       'dribbleTry': 8,
#       'dribbleSuccess': 7,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.6}},
#     {'spId': 264005589,
#      'spPosition': 17,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 186,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 7,
#       'dribbleTry': 6,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 284001183,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 101166149,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 825173731,
#      'spPosition': 19,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 391,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 13,
#       'passSuccess': 11,
#       'dribbleTry': 8,
#       'dribbleSuccess': 7,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.3}},
#     {'spId': 829252371,
#      'spPosition': 18,
#      'spGrade': 5,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 325,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 14,
#       'passSuccess': 10,
#       'dribbleTry': 12,
#       'dribbleSuccess': 10,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.7}},
#     {'spId': 284204963,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]},
#   {'ouid': '56f931578b228109e8e44599da41ea64',
#    'nickname': 'Ithas',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '승',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 84,
#     'cornerKick': 0,
#     'possession': 53,
#     'offsideCount': 2,
#     'averageRating': 4.56667,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 5,
#     'effectiveShootTotal': 4,
#     'shootOutScore': 0,
#     'goalTotal': 2,
#     'goalTotalDisplay': 2,
#     'ownGoal': 0,
#     'shootHeading': 1,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 4,
#     'goalInPenalty': 2,
#     'shootOutPenalty': 1,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 16779135,
#      'x': 0.756261408329,
#      'y': 0.5391721725463867,
#      'type': 2,
#      'result': 1,
#      'spId': 256004833,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.7229273319244385,
#      'assistY': 0.5804996490478516,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16779847,
#      'x': 0.9298943877220154,
#      'y': 0.5756294131278992,
#      'type': 6,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.8687557578086853,
#      'assistY': 0.08195067942142487,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779540,
#      'x': 0.8769195675849915,
#      'y': 0.58001697063446,
#      'type': 2,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.4637594223022461,
#      'assistY': 0.5461459159851074,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2801,
#      'x': 0.956793248653412,
#      'y': 0.42789077758789,
#      'type': 3,
#      'result': 2,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777883,
#      'x': 0.8484712839126587,
#      'y': 0.4086909592151642,
#      'type': 4,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 137,
#     'passSuccess': 127,
#     'shortPassTry': 107,
#     'shortPassSuccess': 102,
#     'longPassTry': 4,
#     'longPassSuccess': 3,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 2,
#     'drivenGroundPassSuccess': 2,
#     'throughPassTry': 23,
#     'throughPassSuccess': 20,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 9,
#     'blockSuccess': 0,
#     'tackleTry': 7,
#     'tackleSuccess': 3},
#    'player': [{'spId': 268192181,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256242519,
#      'spPosition': 25,
#      'spGrade': 8,
#      'status': {'shoot': 3,
#       'effectiveShoot': 2,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 268,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 7,
#       'dribbleTry': 9,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 7,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 4,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.4}},
#     {'spId': 256215914,
#      'spPosition': 11,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 188,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 21,
#       'passSuccess': 20,
#       'dribbleTry': 11,
#       'dribbleSuccess': 10,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 3,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 3,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.9}},
#     {'spId': 256004231,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256051539,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 4,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.5}},
#     {'spId': 256004833,
#      'spPosition': 27,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 254,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 13,
#       'passSuccess': 11,
#       'dribbleTry': 11,
#       'dribbleSuccess': 9,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.0}},
#     {'spId': 274000250,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 289261593,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 253188377,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256192985,
#      'spPosition': 23,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 154,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 14,
#       'passSuccess': 12,
#       'dribbleTry': 7,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.8}},
#     {'spId': 256001041,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 99,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 9,
#       'dribbleTry': 6,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.1}},
#     {'spId': 256214098,
#      'spPosition': 9,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 202,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 17,
#       'passSuccess': 16,
#       'dribbleTry': 9,
#       'dribbleSuccess': 8,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.9}},
#     {'spId': 234192119,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256007289,
#      'spPosition': 4,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 131,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 12,
#       'passSuccess': 11,
#       'dribbleTry': 6,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 7,
#       'ballPossesionSuccess': 6,
#       'aerialTry': 5,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.9}},
#     {'spId': 256001109,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 60,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 9,
#       'dribbleTry': 4,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.8}},
#     {'spId': 256140601,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 7,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'dribbleTry': 1,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.3}},
#     {'spId': 251005099,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256001075,
#      'spPosition': 18,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 1,
#       'goal': 1,
#       'dribble': 318,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 24,
#       'passSuccess': 22,
#       'dribbleTry': 20,
#       'dribbleSuccess': 17,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.6}}]}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "matchEndType","foul", "injury", 
    "redCards", "yellowCards","possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "matchEndType": match_detail['matchEndType'],
                    "foul": match_detail['foul'],
                    "injury": match_detail['injury'],
                    "redCards": match_detail['redCards'],
                    "yellowCards": match_detail['yellowCards'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_91307/3420171123.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67e3f253c1b497470d9cd1bb  2025-03-26T12:36:21        50
# 1  67e3f253c1b497470d9cd1bb  2025-03-26T12:36:21        50
# 2  67e3f253c1b497470d9cd1bb  2025-03-26T12:36:21        50
# 3  67e3f253c1b497470d9cd1bb  2025-03-26T12:36:21        50
# 4  67e3f253c1b497470d9cd1bb  2025-03-26T12:36:21        50
#
#                                ouid  nickname matchResult matchEndType foul  \
# 0  721a614ddf103a32a76e70fdf954a74c  피온하는마라토너           패            0    3
# 1  721a614ddf103a32a76e70fdf954a74c  피온하는마라토너           패            0    3
# 2  721a614ddf103a32a76e70fdf954a74c  피온하는마라토너           패            0    3
# 3  56f931578b228109e8e44599da41ea64     Ithas           승            0    0
# 4  56f931578b228109e8e44599da41ea64     Ithas           승            0    0
#
#   injury redCards  ...  goalTime         x         y type result       spId  \
# 0      0        1  ...      2040  0.825166  0.460345    2      1  829252371
# 1      0        1  ...  16778401  0.847026  0.494658    2      1  291189513
# 2      0        1  ...      1584  0.927101  0.567743    3      1  289045661
# 3      0        0  ...  16779135  0.756261  0.539172    2      1  256004833
# 4      0        0  ...  16779847  0.929894  0.575629    6      3  256001075
#
#   assist assistSpId hitPost inPenalty
# 0   True  289045661   False     False
# 1   True  289045661   False      True
# 2  False         -1   False      True
# 3   True  256192985   False     False
# 4   True  256004833   False      True
#
# [5 rows x 43 columns]

# %%
match_df.T
# Out:
#                                                   0    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 721a614ddf103a32a76e70fdf954a74c
# nickname                                     피온하는마라토너
# matchResult                                         패
# matchEndType                                        0
# foul                                                3
# injury                                              0
# redCards                                            1
# yellowCards                                         1
# possession                                         47
# averageRating                                 3.66667
# dribble                                            61
# cornerKick                                          2
# offsideCount                                        1
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           0
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            97
# passSuccess                                        79
# shortPassTry                                       50
# shortPassSuccess                                   49
# longPassTry                                         7
# longPassSuccess                                     2
# throughPassTry                                     38
# throughPassSuccess                                 27
# tackleTry                                          15
# tackleSuccess                                      12
# blockTry                                            8
# blockSuccess                                        0
# goalTime                                         2040
# x                                            0.825166
# y                                            0.460345
# type                                                2
# result                                              1
# spId                                        829252371
# assist                                           True
# assistSpId                                  289045661
# hitPost                                         False
# inPenalty                                       False
#
#                                                   1    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 721a614ddf103a32a76e70fdf954a74c
# nickname                                     피온하는마라토너
# matchResult                                         패
# matchEndType                                        0
# foul                                                3
# injury                                              0
# redCards                                            1
# yellowCards                                         1
# possession                                         47
# averageRating                                 3.66667
# dribble                                            61
# cornerKick                                          2
# offsideCount                                        1
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           0
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            97
# passSuccess                                        79
# shortPassTry                                       50
# shortPassSuccess                                   49
# longPassTry                                         7
# longPassSuccess                                     2
# throughPassTry                                     38
# throughPassSuccess                                 27
# tackleTry                                          15
# tackleSuccess                                      12
# blockTry                                            8
# blockSuccess                                        0
# goalTime                                     16778401
# x                                            0.847026
# y                                            0.494658
# type                                                2
# result                                              1
# spId                                        291189513
# assist                                           True
# assistSpId                                  289045661
# hitPost                                         False
# inPenalty                                        True
#
#                                                   2    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 721a614ddf103a32a76e70fdf954a74c
# nickname                                     피온하는마라토너
# matchResult                                         패
# matchEndType                                        0
# foul                                                3
# injury                                              0
# redCards                                            1
# yellowCards                                         1
# possession                                         47
# averageRating                                 3.66667
# dribble                                            61
# cornerKick                                          2
# offsideCount                                        1
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           0
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            97
# passSuccess                                        79
# shortPassTry                                       50
# shortPassSuccess                                   49
# longPassTry                                         7
# longPassSuccess                                     2
# throughPassTry                                     38
# throughPassSuccess                                 27
# tackleTry                                          15
# tackleSuccess                                      12
# blockTry                                            8
# blockSuccess                                        0
# goalTime                                         1584
# x                                            0.927101
# y                                            0.567743
# type                                                3
# result                                              1
# spId                                        289045661
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   3    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         53
# averageRating                                 4.56667
# dribble                                            84
# cornerKick                                          0
# offsideCount                                        2
# shootTotal                                          5
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           137
# passSuccess                                       127
# shortPassTry                                      107
# shortPassSuccess                                  102
# longPassTry                                         4
# longPassSuccess                                     3
# throughPassTry                                     23
# throughPassSuccess                                 20
# tackleTry                                           7
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16779135
# x                                            0.756261
# y                                            0.539172
# type                                                2
# result                                              1
# spId                                        256004833
# assist                                           True
# assistSpId                                  256192985
# hitPost                                         False
# inPenalty                                       False
#
#                                                   4    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         53
# averageRating                                 4.56667
# dribble                                            84
# cornerKick                                          0
# offsideCount                                        2
# shootTotal                                          5
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           137
# passSuccess                                       127
# shortPassTry                                      107
# shortPassSuccess                                  102
# longPassTry                                         4
# longPassSuccess                                     3
# throughPassTry                                     23
# throughPassSuccess                                 20
# tackleTry                                           7
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16779847
# x                                            0.929894
# y                                            0.575629
# type                                                6
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                        True
#
#                                                   5    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         53
# averageRating                                 4.56667
# dribble                                            84
# cornerKick                                          0
# offsideCount                                        2
# shootTotal                                          5
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           137
# passSuccess                                       127
# shortPassTry                                      107
# shortPassSuccess                                  102
# longPassTry                                         4
# longPassSuccess                                     3
# throughPassTry                                     23
# throughPassSuccess                                 20
# tackleTry                                           7
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16779540
# x                                             0.87692
# y                                            0.580017
# type                                                2
# result                                              3
# spId                                        256242519
# assist                                           True
# assistSpId                                  256001075
# hitPost                                         False
# inPenalty                                        True
#
#                                                   6    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         53
# averageRating                                 4.56667
# dribble                                            84
# cornerKick                                          0
# offsideCount                                        2
# shootTotal                                          5
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           137
# passSuccess                                       127
# shortPassTry                                      107
# shortPassSuccess                                  102
# longPassTry                                         4
# longPassSuccess                                     3
# throughPassTry                                     23
# throughPassSuccess                                 20
# tackleTry                                           7
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                         2801
# x                                            0.956793
# y                                            0.427891
# type                                                3
# result                                              2
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   7    \
# matchId                      67e3f253c1b497470d9cd1bb
# matchDate                         2025-03-26T12:36:21
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         53
# averageRating                                 4.56667
# dribble                                            84
# cornerKick                                          0
# offsideCount                                        2
# shootTotal                                          5
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           137
# passSuccess                                       127
# shortPassTry                                      107
# shortPassSuccess                                  102
# longPassTry                                         4
# longPassSuccess                                     3
# throughPassTry                                     23
# throughPassSuccess                                 20
# tackleTry                                           7
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16777883
# x                                            0.848471
# y                                            0.408691
# type                                                4
# result                                              1
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   8    \
# matchId                      67e3ef640655e14cb4e9d0f5
# matchDate                         2025-03-26T12:23:43
# matchType                                          50
# ouid                 d27b010eae0e0c4e14ac34752fe29c5e
# nickname                                       드로그박보영
# matchResult                                         무
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         46
# averageRating                                 4.05556
# dribble                                            67
# cornerKick                                          1
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            87
# passSuccess                                        78
# shortPassTry                                       59
# shortPassSuccess                                   56
# longPassTry                                         4
# longPassSuccess                                     1
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                          15
# tackleSuccess                                       5
# blockTry                                            6
# blockSuccess                                        0
# goalTime                                     16778932
# x                                            0.778034
# y                                            0.548472
# type                                                2
# result                                              2
# spId                                        832158023
# assist                                           True
# assistSpId                                  828176580
# hitPost                                         False
# inPenalty                                       False
#
#                                                   9    ...  \
# matchId                      67e3ef640655e14cb4e9d0f5  ...
# matchDate                         2025-03-26T12:23:43  ...
# matchType                                          50  ...
# ouid                 d27b010eae0e0c4e14ac34752fe29c5e  ...
# nickname                                       드로그박보영  ...
# matchResult                                         무  ...
# matchEndType                                        0  ...
# foul                                                0  ...
# injury                                              0  ...
# redCards                                            0  ...
# yellowCards                                         0  ...
# possession                                         46  ...
# averageRating                                 4.05556  ...
# dribble                                            67  ...
# cornerKick                                          1  ...
# offsideCount                                        0  ...
# shootTotal                                          6  ...
# effectiveShootTotal                                 4  ...
# goalTotal                                           1  ...
# shootPenaltyKick                                    0  ...
# goalPenaltyKick                                     0  ...
# passTry                                            87  ...
# passSuccess                                        78  ...
# shortPassTry                                       59  ...
# shortPassSuccess                                   56  ...
# longPassTry                                         4  ...
# longPassSuccess                                     1  ...
# throughPassTry                                     23  ...
# throughPassSuccess                                 21  ...
# tackleTry                                          15  ...
# tackleSuccess                                       5  ...
# blockTry                                            6  ...
# blockSuccess                                        0  ...
# goalTime                                         2851  ...
# x                                            0.874682  ...
# y                                            0.401378  ...
# type                                                2  ...
# result                                              1  ...
# spId                                        279190871  ...
# assist                                           True  ...
# assistSpId                                  828176580  ...
# hitPost                                         False  ...
# inPenalty                                        True  ...
#
#                                                   348  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 462fc65306a363f4bb8d476d428c3637
# nickname                                        메시더풋볼
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         43
# averageRating                                 4.08889
# dribble                                            59
# cornerKick                                          3
# offsideCount                                        1
# shootTotal                                         10
# effectiveShootTotal                                 9
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           126
# passSuccess                                       115
# shortPassTry                                      103
# shortPassSuccess                                  100
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     18
# throughPassSuccess                                 10
# tackleTry                                          16
# tackleSuccess                                       8
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                         1866
# x                                            0.774217
# y                                            0.470212
# type                                                2
# result                                              3
# spId                                        820265695
# assist                                           True
# assistSpId                                  289180930
# hitPost                                         False
# inPenalty                                       False
#
#                                                   349  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         2248
# x                                            0.839312
# y                                            0.627562
# type                                                2
# result                                              1
# spId                                        256001075
# assist                                           True
# assistSpId                                  256215914
# hitPost                                         False
# inPenalty                                       False
#
#                                                   350  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16779413
# x                                            0.825106
# y                                             0.50894
# type                                                2
# result                                              2
# spId                                        256004231
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                       False
#
#                                                   351  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16779481
# x                                            0.918926
# y                                            0.477989
# type                                                3
# result                                              2
# spId                                        256001109
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   352  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         2436
# x                                             0.88588
# y                                            0.457237
# type                                                7
# result                                              2
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   353  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16780139
# x                                            0.753972
# y                                             0.67202
# type                                                2
# result                                              2
# spId                                        256004833
# assist                                           True
# assistSpId                                  256214098
# hitPost                                         False
# inPenalty                                       False
#
#                                                   354  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         1318
# x                                            0.955235
# y                                            0.456421
# type                                                3
# result                                              2
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   355  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16777812
# x                                            0.894049
# y                                            0.581159
# type                                                6
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256242519
# hitPost                                         False
# inPenalty                                        True
#
#                                                   356  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         2324
# x                                            0.868979
# y                                            0.539869
# type                                                1
# result                                              1
# spId                                        256242519
# assist                                           True
# assistSpId                                  256215914
# hitPost                                         False
# inPenalty                                        True
#
#                                                   357
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16779004
# x                                            0.940907
# y                                            0.392542
# type                                                2
# result                                              1
# spId                                        256242519
# assist                                           True
# assistSpId                                  256215914
# hitPost                                         False
# inPenalty                                        True
#
# [43 rows x 358 columns]

# %% [markdown]
# ### 2) 최근 100경기 매치 기록(전체 유저)
# - 내 기록과 비교 분석할 전체 유저의 최근 100경기 매치 기록 불러오기
# - 공식경기 기준 100경기

# %% [markdown]
# #### ㄴ 최근 100경기 매치 ID 불러오기

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/fconline/v1/match?matchtype=50&offset=0&limit=100&orderby=desc"
response = requests.get(urlString, headers = headers)

all_match_list = response.json()
print(len(all_match_list))
all_match_list
# Out:
# 100
# ['67e62c6f5fb3f920ec3abb09',
#  '67e62c61d0633515c1c976de',
#  '67e62c3da48af0cbabcf164d',
#  '67e62c2a684bd5f2cacd0dae',
#  '67e62c19a796f43245fd0af7',
#  '67e62c0d8f10ed7f58f45a24',
#  '67e62c0b10151c83dbe03da7',
#  '67e62c07a82f6f94d3f562cd',
#  '67e62bfeb129aa60e09a1554',
#  '67e62bfc7ebe3a684dea86c7',
#  '67e62bfac4f5582f0d223b53',
#  '67e62bf24d897f0903f3399c',
#  '67e62bec225564edbd9f34fb',
#  '67e62be630ba230e433b0e74',
#  '67e62bdf82554b966ac0c285',
#  '67e62bd7e3f6d62aed706b6f',
#  '67e62bd322bd091a899fd955',
#  '67e62bce3a94c485630b9f95',
#  '67e62bca5a990aff115f0057',
#  '67e62bc5db7d68353b18d6ff',
#  '67e62bbb6c11d74fc1469fe6',
#  '67e62bb9709464291a8005db',
#  '67e62bb42327521a9dc18868',
#  '67e62bb1299a253a9a40dad7',
#  '67e62bacbc374d18d5cc70f7',
#  '67e62ba79d79527756291e6d',
#  '67e62ba4aeb12cac67c39863',
#  '67e62ba2210180ba6ef7e3d3',
#  '67e62b9aeb7f96fd819cb947',
#  '67e62b91452e410c7d940df1',
#  '67e62b86a5b891262ddebcdb',
#  '67e62b83f32f1cc834f278d0',
#  '67e62b80b2ac447c5603eb26',
#  '67e62b804383b1308320315e',
#  '67e62b7ea5f04326e4003561',
#  '67e62b7bf73fa6ec09e2a11d',
#  '67e62b771cd5dc05bd7af3d3',
#  '67e62b6cc01d165dc140816d',
#  '67e62b6bbc0fbe3d739d3e56',
#  '67e62b6a1012b8242cceace8',
#  '67e62b653402975fee6cf970',
#  '67e62b63865622373099a675',
#  '67e62b6347fffd54e82f4551',
#  '67e62b5a7603e8571f4e9600',
#  '67e62b56d737424980553081',
#  '67e62b53e5a11005c9485821',
#  '67e62b4ebcb01543ed724cf5',
#  '67e62b4d0485936284783753',
#  '67e62b496ae114d4564ac4b6',
#  '67e62b48b636c4affd2732a3',
#  '67e62b48765742abc0d72aae',
#  '67e62b47e39d74fc741fe98b',
#  '67e62b45d2f1a639b7de4d1a',
#  '67e62b452d039b7ecafe727e',
#  '67e62b3c5a6f5502c2e409a4',
#  '67e62b39873a2c961a790833',
#  '67e62b380f6f0e7ac080f2fc',
#  '67e62b363ed78a1d5bdb1714',
#  '67e62b30780386111524dccc',
#  '67e62b2df5711fb1a87e335f',
#  '67e62b2de087ee819f00a680',
#  '67e62b2dc3395333600de7d6',
#  '67e62b29612f8d62761e7a8f',
#  '67e62b26ff408dbb542bf76c',
#  '67e62b26f113e8c8c2bfcde6',
#  '67e62b256b2f7c1c1703fc0a',
#  '67e62b250d0c74bf16c4542f',
#  '67e62b2225d0a2bd8260efb6',
#  '67e62b2179db3219ca151dd9',
#  '67e62b21475aa18999fb9f44',
#  '67e62b1df132700c947132f5',
#  '67e62b1d903a4f5750f305f5',
#  '67e62b1c89468c71754be05f',
#  '67e62b15f01580090794ef33',
#  '67e62b13b5477a837061a3ef',
#  '67e62b0e522254e17e5272e6',
#  '67e62b0a395b67db9aa13d9a',
#  '67e62b05477472af439a7727',
#  '67e62b05282277776348ad16',
#  '67e62b03f139cadd82eea558',
#  '67e62b0378f03882a5629518',
#  '67e62afc8b6a943cfdc21f2b',
#  '67e62afc013c62f0129b96d5',
#  '67e62afaa71da0d3161b552c',
#  '67e62afa96dbd08442159d97',
#  '67e62af75ccdd26c14d9bb8d',
#  '67e62af713d776067118d9e7',
#  '67e62af6340ad4c18056a728',
#  '67e62af587244d724921c74f',
#  '67e62af26c8757e6052741be',
#  '67e62aedcd30653d77881d5a',
#  '67e62ae91581ccc67d9b4be6',
#  '67e62ae7b46c9e4619f5f9e0',
#  '67e62ae73c5a83abef902fca',
#  '67e62ae66662887706ca5647',
#  '67e62ae491721d7f7feaa6b2',
#  '67e62ae41e9c401afdc3cef8',
#  '67e62ae2d0b98a5189fbe686',
#  '67e62adec1a7bd7740833a64',
#  '67e62add2c429e870dfef914']

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
all_match_info_list = []
for match_id in all_match_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    all_match_info_list.append(res.json())

# 예시) 매치ID별 정보
all_match_info_list[0]
# Out:
# {'matchId': '67e62c6f5fb3f920ec3abb09',
#  'matchDate': '2025-03-28T04:59:53',
#  'matchType': 50,
#  'matchInfo': [{'ouid': 'eafc972dc0e8f6fb492291fbafa7cb9c',
#    'nickname': '고고하시죠',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 2,
#     'systemPause': 1,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 3,
#     'cornerKick': 0,
#     'possession': 41,
#     'offsideCount': 0,
#     'averageRating': 3.40556,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 0,
#     'effectiveShootTotal': 0,
#     'shootOutScore': 0,
#     'goalTotal': 0,
#     'goalTotalDisplay': 0,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 0,
#     'goalInPenalty': 0,
#     'shootOutPenalty': 0,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [],
#    'pass': {'passTry': 9,
#     'passSuccess': 7,
#     'shortPassTry': 7,
#     'shortPassSuccess': 6,
#     'longPassTry': 0,
#     'longPassSuccess': 0,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 0,
#     'drivenGroundPassSuccess': 0,
#     'throughPassTry': 1,
#     'throughPassSuccess': 1,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 2,
#     'blockSuccess': 0,
#     'tackleTry': 0,
#     'tackleSuccess': 0},
#    'player': [{'spId': 291243812,
#      'spPosition': 27,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 1,
#       'passSuccess': 1,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.5}},
#     {'spId': 265245279,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 265235212,
#      'spPosition': 3,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 1,
#       'passSuccess': 1,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.6}},
#     {'spId': 815232656,
#      'spPosition': 6,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 32,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 2,
#       'passSuccess': 1,
#       'dribbleTry': 1,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.8}},
#     {'spId': 810231747,
#      'spPosition': 25,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 2,
#       'passSuccess': 2,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 802201535,
#      'spPosition': 4,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 289192119,
#      'spPosition': 0,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 810231410,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 289045661,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 289009676,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 810248243,
#      'spPosition': 10,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 825239053,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 808237681,
#      'spPosition': 23,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 1,
#       'passSuccess': 1,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.7}},
#     {'spId': 283191695,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 290252371,
#      'spPosition': 9,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 16,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 1,
#       'passSuccess': 1,
#       'dribbleTry': 1,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.7}},
#     {'spId': 810208618,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 289001397,
#      'spPosition': 18,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 4,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 1,
#       'passSuccess': 0,
#       'dribbleTry': 1,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 270241637,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "matchEndType","foul", "injury", 
    "redCards", "yellowCards","possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

all_match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in all_match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "matchEndType": match_detail['matchEndType'],
                    "foul": match_detail['foul'],
                    "injury": match_detail['injury'],
                    "redCards": match_detail['redCards'],
                    "yellowCards": match_detail['yellowCards'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
all_match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_91307/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_91307/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_91307/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_91307/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_91307/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_91307/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67e62c3da48af0cbabcf164d  2025-03-28T04:59:47        50
# 1  67e62c3da48af0cbabcf164d  2025-03-28T04:59:47        50
# 2  67e62c19a796f43245fd0af7  2025-03-28T04:59:53        50
# 3  67e62c19a796f43245fd0af7  2025-03-28T04:59:53        50
# 4  67e62c0d8f10ed7f58f45a24  2025-03-28T04:58:59        50
#
#                                ouid   nickname matchResult matchEndType foul  \
# 0  1eac9408a5027fdb0baf7b8628e05d18        띨구야           승            1    0
# 1  1eac9408a5027fdb0baf7b8628e05d18        띨구야           승            1    0
# 2  3c5a58b1923ef45f6e6b5130fb503b91  Apink0419           승            1    0
# 3  3c5a58b1923ef45f6e6b5130fb503b91  Apink0419           승            1    0
# 4  be0602ddd2a5cf663213bc462e69dc57       에베벡디           승            1    0
#
#   injury redCards  ... goalTime         x         y type result       spId  \
# 0      0        0  ...      169  0.891539  0.528568    1      3  252140053
# 1      0        0  ...      730  0.870451  0.514969    2      3  290200104
# 2      0        0  ...      248  0.902794  0.502957    9      3  807202126
# 3      0        0  ...      613  0.934293  0.468661    3      1  807202126
# 4      0        0  ...      248  0.773148  0.567662    1      2  283209989
#
#   assist assistSpId hitPost inPenalty
# 0   True  290200104   False      True
# 1   True  289191208   False      True
# 2  False         -1   False      True
# 3  False         -1   False      True
# 4   True  829222665   False     False
#
# [5 rows x 43 columns]

# %%
# 파일로 저장
today = str(datetime.today().strftime('%Y%m%d'))[2:]
all_match_df.to_csv(f"data/{today}_recent_matches.csv", index=False, encoding='utf-8-sig')
