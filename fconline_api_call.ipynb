# %% [markdown]
# # FC온라인 API 연결

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. 데이터 설명

# %% [markdown]
# #### 매치 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **matchId**                | string     | 64f0000c00007210005f0000  | 매치 고유 식별자                                   |
# | **matchDate**              | string     | 2023-10-29T12:22:48       | 매치 일자 (UTC0)                                 |
# | **matchType**              | integer    | 52                        | 매치 종류 (/metadata/matchtype API 참고)          |
#
#
# #### matchDetails : 매치 참여 플레이어별 매치 상세
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **ouid**       | string     |                           | 계정 식별자                                        |
# | **nickname**   | string     | 닉네임                    | 유저 닉네임                                        |
#
# #### matchDetail : 매치 결과 상세 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **seasonId**          | integer  | 202311               | 시즌 ID                                            |
# | **matchResult**       | string   | 승                  | 매치 결과 (“승”, “무”, “패”)                      |
# | **matchEndType**      | integer  | 0                   | 매치 종료 타입 (0 정상종료, 1 몰수승, 2 몰수패)   |
# | **systemPause**       | integer  | 0                   | 게임 일시정지 수                                   |
# | **foul**              | integer  | 0                   | 파울 수                                            |
# | **injury**            | integer  | 1                   | 부상 수                                            |
# | **redCards**          | integer  | 0                   | 받은 레드카드 수                                   |
# | **yellowCards**       | integer  | 0                   | 받은 옐로카드 수                                   |
# | **dribble**           | integer  | 78                  | 드리블 거리(야드)                                  |
# | **cornerKick**        | integer  | 0                   | 코너킥 수                                          |
# | **possession**        | integer  | 46                  | 점유율                                             |
# | **offsideCount**      | integer  | 1                   | 오프사이드 수                                      |
# | **averageRating**     | number   | 1.18889             | 경기 평점                                          |
# | **controller**        | string   | keyboard            | 사용한 컨트롤러 타입 (keyboard / pad / etc 중 1)  |
#
#
# #### shoot : 슈팅 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **shoot**                 | object      |                           | 슈팅 정보                                          |
# | **shootTotal**                 | integer  | 3                   | 총 슛 수                                           |
# | **effectiveShootTotal**         | integer  | 3                   | 총 유효슛 수                                       |
# | **shootOutScore**              | integer  | 0                   | 승부차기 슛 수                                     |
# | **goalTotal**                  | integer  | 2                   | 총 골 수                                           |
# | **goalTotalDisplay**           | integer  | 2                   | 게임 종료 후 유저에게 노출되는 골 수              |
# | **ownGoal**                    | integer  | 0                   | 자책 골 수                                         |
# | **shootHeading**               | integer  | 2                   | 헤딩 슛 수                                         |
# | **goalHeading**                | integer  | 1                   | 헤딩 골 수                                         |
# | **shootFreekick**              | integer  | 0                   | 프리킥 슛 수                                       |
# | **goalFreekick**               | integer  | 0                   | 프리킥 골 수                                       |
# | **shootInPenalty**             | integer  | 3                   | 인패널티 슛 수                                     |
# | **goalInPenalty**              | integer  | 2                   | 인패널티 골 수                                     |
# | **shootOutPenalty**            | integer  | 0                   | 아웃패널티 슛 수                                   |
# | **goalOutPenalty**             | integer  | 0                   | 아웃패널티 골 수                                   |
# | **shootPenaltyKick**           | integer  | 0                   | 패널티킥 슛 수                                     |
# | **goalPenaltyKick**            | integer  | 0                   | 패널티킥 골 수                                     |
#
# #### pass : 패스 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **passTry**                    | integer  | 92                  | 패스 시도 수                                       |
# | **passSuccess**                | integer  | 83                  | 패스 성공 수                                       |
# | **shortPassTry**               | integer  | 55                  | 숏 패스 시도 수                                    |
# | **shortPassSuccess**           | integer  | 55                  | 숏 패스 성공 수                                    |
# | **longPassTry**                | integer  | 3                   | 롱 패스 시도 수                                    |
# | **longPassSuccess**            | integer  | 3                   | 롱 패스 성공 수                                    |
# | **bouncingLobPassTry**         | integer  | 1                   | 바운싱 롭 패스 시도 수                             |
# | **bouncingLobPassSuccess**     | integer  | 0                   | 바운싱 롭 패스 성공 수                             |
# | **drivenGroundPassTry**        | integer  | 10                  | 드리븐 땅볼 패스 시도 수                           |
# | **drivenGroundPassSuccess**    | integer  | 10                  | 드리븐 땅볼 패스 성공 수                           |
# | **throughPassTry**             | integer  | 19                  | 스루 패스 시도 수                                  |
# | **throughPassSuccess**         | integer  | 14                  | 스루 패스 성공 수                                  |
# | **lobbedThroughPassTry**       | integer  | 4                   | 로빙 스루 패스 시도 수                             |
# | **lobbedThroughPassSuccess**   | integer  | 1                   | 로빙 스루 패스 성공 수                             |
#
# #### defence : 수비 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **blockTry**                  | integer  | 3                   | 블락 시도 수                                       |
# | **blockSuccess**              | integer  | 0                   | 블락 성공 수                                       |
# | **tackleTry**                 | integer  | 11                  | 태클 시도 수                                       |
# | **tackleSuccess**             | integer  | 9                   | 태클 성공 수                                       |

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 데이터 분석 환경 조성

# %% [markdown]
# ### 라이브러리 호출

# %%
import requests
import pandas as pd

# %% [markdown]
# ### 매치 메타데이터 확인
# - 매치 타입 확인

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/static/fconline/meta/matchtype.json"
response = requests.get(urlString, headers = headers)

match_type = response.json()
match_type
# Out:
# [{'matchtype': 30, 'desc': '리그 친선'},
#  {'matchtype': 40, 'desc': '클래식 1on1'},
#  {'matchtype': 50, 'desc': '공식경기'},
#  {'matchtype': 52, 'desc': '감독모드'},
#  {'matchtype': 60, 'desc': '공식 친선'},
#  {'matchtype': 204, 'desc': '볼타 친선'},
#  {'matchtype': 214, 'desc': '볼타 공식'},
#  {'matchtype': 224, 'desc': '볼타 AI대전'},
#  {'matchtype': 234, 'desc': '볼타 커스텀'}]

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 데이터 프레임 생성

# %% [markdown]
# ### 1) 내 매치 기록

# %% [markdown]
# - 계정 식별자 정보 저장
#     - 추후 다른 데이터와의 연결 고리 역할 수행
#     - ouid = `56f931578b228109e8e44599da41ea64`

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}
  
characterName = "Ithas"
urlString = "https://open.api.nexon.com/fconline/v1/id?nickname=" + characterName
response = requests.get(urlString, headers = headers)

ouid = response.json()['ouid']
ouid
# Out:
# '56f931578b228109e8e44599da41ea64'

# %% [markdown]
# #### ㄴ 매치 ID 리스트 생성
# - 매치 상세 정보를 조회하는 API에 연동하기 위해 매치 ID 리스트 생성

# %%
# 매치 기록 조회(최근 매치 ID 리스트 생성)
urlString = "https://open.api.nexon.com/fconline/v1/user/match?ouid=56f931578b228109e8e44599da41ea64&matchtype=50&offset=0&limit=100"
response = requests.get(urlString, headers = headers)

# 매치 ID 리스트 생성
match_id_list = response.json()
match_id_list
# Out:
# ['67e11d51d56b0f431020a326',
#  '67e115e2d31f25263ab3e538',
#  '67e11349b6764f2767dbbd64',
#  '67e110769c505b95184aa6e8',
#  '67e10dd5556da0916f3eb359',
#  '67dfedbd5315c6036c5ffb04',
#  '67dfecd36f1f400054c67cc7',
#  '67dfe8820d8347e2847e0e76',
#  '67dfe4e05b2baccd90a79566',
#  '67dfe1f9b5f1228c927f8d7b',
#  '67dfde8d027d0a782967f2dd',
#  '67dfdbd7c3b20515db2b2aaa',
#  '67dfd91e6950fe6c38f73dbd',
#  '67dfd655a90c32a27f4a1e0f',
#  '67dd8645ec70212298a55f7b',
#  '67dd8231dda981e2e4199dc0',
#  '67dd7e67c75c081c46ba90c3',
#  '67dd7b7c4f01878ae65bd76c',
#  '67dd78c9c3d42c6d9d886176',
#  '67dd7510b36edd0a5199b8de',
#  '67dd721c8afaaf18c7574daa',
#  '67dd6f48b23c74d8fd8b11d7',
#  '67dd6cc0632b415e80a9d58d',
#  '67dd6a476fb2bd6b95c4b63d',
#  '67dd67a24be0a1e397cec6dd',
#  '67dd650053e5e88154781b92',
#  '67dd625e1c27c154b533a0aa',
#  '67bde18ff7a57a50de59824f',
#  '67bddedacb7a0585fb3ec221',
#  '67bddc42b13d371b1b6b8499',
#  '67bdd9e2b4a4bc70f6b06af4']

# %%
# 내 경기 수
len(match_id_list)
# Out:
# 31

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
match_info_list = []
for match_id in match_id_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    match_info_list.append(res.json())

# 예시) 매치ID별 정보
match_info_list[0]
# Out:
# {'matchId': '67e11d51d56b0f431020a326',
#  'matchDate': '2025-03-24T09:03:10',
#  'matchType': 50,
#  'matchInfo': [{'ouid': '56f931578b228109e8e44599da41ea64',
#    'nickname': 'Ithas',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '승',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 87,
#     'cornerKick': 0,
#     'possession': 55,
#     'offsideCount': 1,
#     'averageRating': 4.32778,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 8,
#     'effectiveShootTotal': 6,
#     'shootOutScore': 0,
#     'goalTotal': 4,
#     'goalTotalDisplay': 4,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 6,
#     'goalInPenalty': 3,
#     'shootOutPenalty': 2,
#     'goalOutPenalty': 1,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 2839,
#      'x': 0.8833516836166382,
#      'y': 0.4910877346992493,
#      'type': 6,
#      'result': 1,
#      'spId': 256215914,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.6950247287750244,
#      'assistY': 0.5482724905014038,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777580,
#      'x': 0.9126812219619752,
#      'y': 0.4715189933776855,
#      'type': 6,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.8485284447669983,
#      'assistY': 0.5307864546775818,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777421,
#      'x': 0.8562493324279785,
#      'y': 0.5961534976959229,
#      'type': 2,
#      'result': 2,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.4655886292457581,
#      'assistY': 0.7007590532302856,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777822,
#      'x': 0.8891752362251282,
#      'y': 0.3960741460323334,
#      'type': 6,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.7007228136062622,
#      'assistY': 0.4265310168266296,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2525,
#      'x': 0.8272300362586975,
#      'y': 0.499516487121582,
#      'type': 2,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.5060260891914368,
#      'assistY': 0.5787526965141296,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 2255,
#      'x': 0.889826238155365,
#      'y': 0.5264807343482971,
#      'type': 2,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.75491052865982,
#      'assistY': 0.3917485475540161,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1646,
#      'x': 0.8387454152107239,
#      'y': 0.3928606510162354,
#      'type': 2,
#      'result': 2,
#      'spId': 256004833,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 1600,
#      'x': 0.8616541028022766,
#      'y': 0.6613717675209045,
#      'type': 2,
#      'result': 1,
#      'spId': 256004231,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.61064875125885,
#      'assistY': 0.5226289629936218,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 128,
#     'passSuccess': 119,
#     'shortPassTry': 102,
#     'shortPassSuccess': 97,
#     'longPassTry': 0,
#     'longPassSuccess': 0,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 1,
#     'drivenGroundPassSuccess': 1,
#     'throughPassTry': 23,
#     'throughPassSuccess': 21,
#     'lobbedThroughPassTry': 1,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 9,
#     'blockSuccess': 1,
#     'tackleTry': 9,
#     'tackleSuccess': 5},
#    'player': [{'spId': 289261593,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 234192119,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256004833,
#      'spPosition': 27,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 290,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 12,
#       'passSuccess': 12,
#       'dribbleTry': 13,
#       'dribbleSuccess': 11,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.6}},
#     {'spId': 256192985,
#      'spPosition': 13,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 55,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 18,
#       'passSuccess': 18,
#       'dribbleTry': 5,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.5}},
#     {'spId': 256001075,
#      'spPosition': 19,
#      'spGrade': 8,
#      'status': {'shoot': 2,
#       'effectiveShoot': 2,
#       'assist': 1,
#       'goal': 2,
#       'dribble': 562,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 16,
#       'passSuccess': 16,
#       'dribbleTry': 19,
#       'dribbleSuccess': 14,
#       'ballPossesionTry': 7,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.5}},
#     {'spId': 256001041,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 48,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 11,
#       'passSuccess': 9,
#       'dribbleTry': 6,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 7,
#       'ballPossesionSuccess': 5,
#       'aerialTry': 2,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.0}},
#     {'spId': 256214098,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256215914,
#      'spPosition': 10,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 214,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 19,
#       'passSuccess': 15,
#       'dribbleTry': 11,
#       'dribbleSuccess': 11,
#       'ballPossesionTry': 7,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 3,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.6}},
#     {'spId': 256140601,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 41,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 1,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.1}},
#     {'spId': 256001109,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 78,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 8,
#       'dribbleTry': 7,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.8}},
#     {'spId': 256242519,
#      'spPosition': 25,
#      'spGrade': 8,
#      'status': {'shoot': 3,
#       'effectiveShoot': 2,
#       'assist': 2,
#       'goal': 2,
#       'dribble': 279,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 20,
#       'passSuccess': 19,
#       'dribbleTry': 17,
#       'dribbleSuccess': 14,
#       'ballPossesionTry': 8,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.7}},
#     {'spId': 256051539,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 4,
#       'passTry': 5,
#       'passSuccess': 4,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.4}},
#     {'spId': 256007289,
#      'spPosition': 4,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 3,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 6,
#       'dribbleTry': 1,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 4,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.6}},
#     {'spId': 274000250,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 251005099,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256004231,
#      'spPosition': 23,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 106,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 8,
#       'dribbleTry': 5,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.1}},
#     {'spId': 268192181,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 253188377,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]},
#   {'ouid': 'a43c45fffe3e49aa4f87172b4d63e2e5',
#    'nickname': '비오비오레츠고',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 1,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 67,
#     'cornerKick': 2,
#     'possession': 45,
#     'offsideCount': 0,
#     'averageRating': 4.0,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 9,
#     'effectiveShootTotal': 6,
#     'shootOutScore': 0,
#     'goalTotal': 3,
#     'goalTotalDisplay': 3,
#     'ownGoal': 0,
#     'shootHeading': 1,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 4,
#     'goalInPenalty': 2,
#     'shootOutPenalty': 5,
#     'goalOutPenalty': 1,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 2667,
#      'x': 0.8317966461181641,
#      'y': 0.5064969658851624,
#      'type': 2,
#      'result': 3,
#      'spId': 287206517,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 807239085,
#      'assistX': 0.7141530513763428,
#      'assistY': 0.6397299170494,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16778764,
#      'x': 0.8873984813690186,
#      'y': 0.6881434917449951,
#      'type': 12,
#      'result': 2,
#      'spId': 810246420,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 260188377,
#      'assistX': 0.7438971996307373,
#      'assistY': 0.5704554915428162,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 995,
#      'x': 0.7899543046951294,
#      'y': 0.4861537516117096,
#      'type': 2,
#      'result': 2,
#      'spId': 287206517,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 807192985,
#      'assistX': 0.6288203597068787,
#      'assistY': 0.6331889629364014,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 1824,
#      'x': 0.8691216111183167,
#      'y': 0.4811601638793945,
#      'type': 2,
#      'result': 3,
#      'spId': 807192985,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 807239085,
#      'assistX': 0.5436972975730896,
#      'assistY': 0.3966963291168213,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778072,
#      'x': 0.916608452796936,
#      'y': 0.4606017768383026,
#      'type': 3,
#      'result': 2,
#      'spId': 825229237,
#      'spGrade': 6,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 820237692,
#      'assistX': 0.9928386211395264,
#      'assistY': 0.01673047430813313,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 278,
#      'x': 0.78613793849945,
#      'y': 0.4407189190387726,
#      'type': 2,
#      'result': 1,
#      'spId': 810246420,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 807239085,
#      'assistX': 0.6893253922462463,
#      'assistY': 0.38685718178749,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16778254,
#      'x': 0.8418965339660645,
#      'y': 0.5249405503273,
#      'type': 2,
#      'result': 1,
#      'spId': 287206517,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 825207410,
#      'assistX': 0.7609254717826843,
#      'assistY': 0.6222952604293823,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 357,
#      'x': 0.856403112411499,
#      'y': 0.4772765636444092,
#      'type': 6,
#      'result': 3,
#      'spId': 807239085,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 810246420,
#      'assistX': 0.7698848247528076,
#      'assistY': 0.5263121128082275,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778005,
#      'x': 0.7976365685462952,
#      'y': 0.6786943674087524,
#      'type': 1,
#      'result': 1,
#      'spId': 825207410,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 807239085,
#      'assistX': 0.6857039928436279,
#      'assistY': 0.560060441493988,
#      'hitPost': False,
#      'inPenalty': False}],
#    'pass': {'passTry': 79,
#     'passSuccess': 66,
#     'shortPassTry': 22,
#     'shortPassSuccess': 21,
#     'longPassTry': 6,
#     'longPassSuccess': 2,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 0,
#     'drivenGroundPassSuccess': 0,
#     'throughPassTry': 51,
#     'throughPassSuccess': 43,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 4,
#     'blockSuccess': 0,
#     'tackleTry': 20,
#     'tackleSuccess': 10},
#    'player': [{'spId': 826218667,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 807239818,
#      'spPosition': 6,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 77,
#       'intercept': 4,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'dribbleTry': 5,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 8,
#       'tackle': 4,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.1}},
#     {'spId': 804264349,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 280208920,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 118,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 7,
#       'dribbleTry': 6,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 2,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.3}},
#     {'spId': 807239085,
#      'spPosition': 25,
#      'spGrade': 5,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 2,
#       'goal': 1,
#       'dribble': 188,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 9,
#       'dribbleTry': 6,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 9,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.6}},
#     {'spId': 832256675,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 810246420,
#      'spPosition': 12,
#      'spGrade': 7,
#      'status': {'shoot': 2,
#       'effectiveShoot': 1,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 295,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 11,
#       'passSuccess': 11,
#       'dribbleTry': 12,
#       'dribbleSuccess': 10,
#       'ballPossesionTry': 9,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.6}},
#     {'spId': 820246191,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 820237692,
#      'spPosition': 19,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 197,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 6,
#       'dribbleTry': 7,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.1}},
#     {'spId': 287206517,
#      'spPosition': 18,
#      'spGrade': 7,
#      'status': {'shoot': 3,
#       'effectiveShoot': 2,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 148,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 8,
#       'dribbleTry': 8,
#       'dribbleSuccess': 7,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.8}},
#     {'spId': 820231866,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 825229237,
#      'spPosition': 4,
#      'spGrade': 6,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 176,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 4,
#       'passSuccess': 2,
#       'dribbleTry': 4,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 4,
#       'aerialSuccess': 3,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 6,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 825207410,
#      'spPosition': 10,
#      'spGrade': 7,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 238,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 6,
#       'dribbleTry': 8,
#       'dribbleSuccess': 8,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.6}},
#     {'spId': 807192985,
#      'spPosition': 17,
#      'spGrade': 5,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 372,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 3,
#       'dribbleTry': 7,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.8}},
#     {'spId': 820186942,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 260188377,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 133,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 5,
#       'dribbleTry': 4,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 3,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 280210257,
#      'spPosition': 0,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 2,
#       'passTry': 2,
#       'passSuccess': 2,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.7}},
#     {'spId': 820270409,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
import pandas as pd

# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/2290921625.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67e11d51d56b0f431020a326  2025-03-24T09:03:10        50
# 1  67e11d51d56b0f431020a326  2025-03-24T09:03:10        50
# 2  67e11d51d56b0f431020a326  2025-03-24T09:03:10        50
# 3  67e11d51d56b0f431020a326  2025-03-24T09:03:10        50
# 4  67e11d51d56b0f431020a326  2025-03-24T09:03:10        50
#
#                                ouid nickname matchResult possession  \
# 0  56f931578b228109e8e44599da41ea64    Ithas           승         55
# 1  56f931578b228109e8e44599da41ea64    Ithas           승         55
# 2  56f931578b228109e8e44599da41ea64    Ithas           승         55
# 3  56f931578b228109e8e44599da41ea64    Ithas           승         55
# 4  56f931578b228109e8e44599da41ea64    Ithas           승         55
#
#    averageRating dribble cornerKick  ...  goalTime         x         y type  \
# 0        4.32778      87          0  ...      2839  0.883352  0.491088    6
# 1        4.32778      87          0  ...  16777580  0.912681  0.471519    6
# 2        4.32778      87          0  ...  16777421  0.856249  0.596153    2
# 3        4.32778      87          0  ...  16777822  0.889175  0.396074    6
# 4        4.32778      87          0  ...      2525  0.827230  0.499516    2
#
#   result       spId assist assistSpId hitPost inPenalty
# 0      1  256215914   True  256192985   False      True
# 1      3  256001075   True  256242519   False      True
# 2      2  256242519   True  256192985   False      True
# 3      3  256242519   True  256192985   False      True
# 4      3  256001075   True  256242519   False     False
#
# [5 rows x 38 columns]

# %%
match_df.T
# Out:
#                                                   0    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                         2839
# x                                            0.883352
# y                                            0.491088
# type                                                6
# result                                              1
# spId                                        256215914
# assist                                           True
# assistSpId                                  256192985
# hitPost                                         False
# inPenalty                                        True
#
#                                                   1    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                     16777580
# x                                            0.912681
# y                                            0.471519
# type                                                6
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256242519
# hitPost                                         False
# inPenalty                                        True
#
#                                                   2    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                     16777421
# x                                            0.856249
# y                                            0.596153
# type                                                2
# result                                              2
# spId                                        256242519
# assist                                           True
# assistSpId                                  256192985
# hitPost                                         False
# inPenalty                                        True
#
#                                                   3    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                     16777822
# x                                            0.889175
# y                                            0.396074
# type                                                6
# result                                              3
# spId                                        256242519
# assist                                           True
# assistSpId                                  256192985
# hitPost                                         False
# inPenalty                                        True
#
#                                                   4    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                         2525
# x                                             0.82723
# y                                            0.499516
# type                                                2
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256242519
# hitPost                                         False
# inPenalty                                       False
#
#                                                   5    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                         2255
# x                                            0.889826
# y                                            0.526481
# type                                                2
# result                                              3
# spId                                        256242519
# assist                                           True
# assistSpId                                  256001075
# hitPost                                         False
# inPenalty                                        True
#
#                                                   6    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                         1646
# x                                            0.838745
# y                                            0.392861
# type                                                2
# result                                              2
# spId                                        256004833
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                       False
#
#                                                   7    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# possession                                         55
# averageRating                                 4.32778
# dribble                                            87
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          8
# effectiveShootTotal                                 6
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           128
# passSuccess                                       119
# shortPassTry                                      102
# shortPassSuccess                                   97
# longPassTry                                         0
# longPassSuccess                                     0
# throughPassTry                                     23
# throughPassSuccess                                 21
# tackleTry                                           9
# tackleSuccess                                       5
# blockTry                                            9
# blockSuccess                                        1
# goalTime                                         1600
# x                                            0.861654
# y                                            0.661372
# type                                                2
# result                                              1
# spId                                        256004231
# assist                                           True
# assistSpId                                  256242519
# hitPost                                         False
# inPenalty                                        True
#
#                                                   8    \
# matchId                      67e11d51d56b0f431020a326
# matchDate                         2025-03-24T09:03:10
# matchType                                          50
# ouid                 a43c45fffe3e49aa4f87172b4d63e2e5
# nickname                                      비오비오레츠고
# matchResult                                         패
# possession                                         45
# averageRating                                     4.0
# dribble                                            67
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 6
# goalTotal                                           3
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            79
# passSuccess                                        66
# shortPassTry                                       22
# shortPassSuccess                                   21
# longPassTry                                         6
# longPassSuccess                                     2
# throughPassTry                                     51
# throughPassSuccess                                 43
# tackleTry                                          20
# tackleSuccess                                      10
# blockTry                                            4
# blockSuccess                                        0
# goalTime                                         2667
# x                                            0.831797
# y                                            0.506497
# type                                                2
# result                                              3
# spId                                        287206517
# assist                                           True
# assistSpId                                  807239085
# hitPost                                         False
# inPenalty                                       False
#
#                                                   9    ...  \
# matchId                      67e11d51d56b0f431020a326  ...
# matchDate                         2025-03-24T09:03:10  ...
# matchType                                          50  ...
# ouid                 a43c45fffe3e49aa4f87172b4d63e2e5  ...
# nickname                                      비오비오레츠고  ...
# matchResult                                         패  ...
# possession                                         45  ...
# averageRating                                     4.0  ...
# dribble                                            67  ...
# cornerKick                                          2  ...
# offsideCount                                        0  ...
# shootTotal                                          9  ...
# effectiveShootTotal                                 6  ...
# goalTotal                                           3  ...
# shootPenaltyKick                                    0  ...
# goalPenaltyKick                                     0  ...
# passTry                                            79  ...
# passSuccess                                        66  ...
# shortPassTry                                       22  ...
# shortPassSuccess                                   21  ...
# longPassTry                                         6  ...
# longPassSuccess                                     2  ...
# throughPassTry                                     51  ...
# throughPassSuccess                                 43  ...
# tackleTry                                          20  ...
# tackleSuccess                                      10  ...
# blockTry                                            4  ...
# blockSuccess                                        0  ...
# goalTime                                     16778764  ...
# x                                            0.887398  ...
# y                                            0.688143  ...
# type                                               12  ...
# result                                              2  ...
# spId                                        810246420  ...
# assist                                           True  ...
# assistSpId                                  260188377  ...
# hitPost                                         False  ...
# inPenalty                                        True  ...
#
#                                                   286  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                         1375
# x                                            0.862332
# y                                            0.464629
# type                                                2
# result                                              3
# spId                                        825158023
# assist                                           True
# assistSpId                                  284189332
# hitPost                                         False
# inPenalty                                        True
#
#                                                   287  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                     16780055
# x                                            0.801025
# y                                            0.376337
# type                                                2
# result                                              2
# spId                                        832188545
# assist                                           True
# assistSpId                                  832194765
# hitPost                                         False
# inPenalty                                       False
#
#                                                   288  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                     16779431
# x                                            0.890541
# y                                            0.678913
# type                                                2
# result                                              2
# spId                                        284189332
# assist                                           True
# assistSpId                                  825158023
# hitPost                                         False
# inPenalty                                        True
#
#                                                   289  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 7f7fb0bb8810496a4af41b4724912a1d
# nickname                                        루드교리트
# matchResult                                         승
# possession                                         45
# averageRating                                 4.61111
# dribble                                            74
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 6
# goalTotal                                           5
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            92
# passSuccess                                        85
# shortPassTry                                       72
# shortPassSuccess                                   70
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     15
# throughPassSuccess                                 13
# tackleTry                                          16
# tackleSuccess                                       9
# blockTry                                            3
# blockSuccess                                        0
# goalTime                                          332
# x                                             0.80485
# y                                            0.499665
# type                                                2
# result                                              2
# spId                                        832188545
# assist                                           True
# assistSpId                                  825190045
# hitPost                                         False
# inPenalty                                       False
#
#                                                   290  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# possession                                         55
# averageRating                                 3.28889
# dribble                                            86
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           118
# passSuccess                                       110
# shortPassTry                                       95
# shortPassSuccess                                   91
# longPassTry                                         5
# longPassSuccess                                     4
# throughPassTry                                     13
# throughPassSuccess                                 12
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                         1211
# x                                            0.830459
# y                                            0.502408
# type                                                1
# result                                              1
# spId                                        256242519
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                       False
#
#                                                   291  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# possession                                         55
# averageRating                                 3.28889
# dribble                                            86
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           118
# passSuccess                                       110
# shortPassTry                                       95
# shortPassSuccess                                   91
# longPassTry                                         5
# longPassSuccess                                     4
# throughPassTry                                     13
# throughPassSuccess                                 12
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16778062
# x                                             0.92192
# y                                            0.417734
# type                                                6
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256214098
# hitPost                                         False
# inPenalty                                        True
#
#                                                   292  \
# matchId                      67bddc42b13d371b1b6b8499
# matchDate                         2025-02-25T15:16:16
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# possession                                         55
# averageRating                                 3.28889
# dribble                                            86
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          3
# effectiveShootTotal                                 3
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           118
# passSuccess                                       110
# shortPassTry                                       95
# shortPassSuccess                                   91
# longPassTry                                         5
# longPassSuccess                                     4
# throughPassTry                                     13
# throughPassSuccess                                 12
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16778926
# x                                            0.932863
# y                                            0.453695
# type                                                2
# result                                              1
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   293  \
# matchId                      67bdd9e2b4a4bc70f6b06af4
# matchDate                         2025-02-25T15:05:26
# matchType                                          50
# ouid                 182bd52c7e7300b878962c93242b5255
# nickname                                     내가만든구역이야
# matchResult                                         무
# possession                                         45
# averageRating                                 3.92778
# dribble                                            75
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          2
# effectiveShootTotal                                 2
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           120
# passSuccess                                       109
# shortPassTry                                      102
# shortPassSuccess                                   96
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     13
# throughPassSuccess                                 10
# tackleTry                                          15
# tackleSuccess                                      10
# blockTry                                            6
# blockSuccess                                        0
# goalTime                                     16777402
# x                                            0.776818
# y                                            0.421705
# type                                               12
# result                                              3
# spId                                        810210514
# assist                                           True
# assistSpId                                  820236499
# hitPost                                         False
# inPenalty                                       False
#
#                                                   294  \
# matchId                      67bdd9e2b4a4bc70f6b06af4
# matchDate                         2025-02-25T15:05:26
# matchType                                          50
# ouid                 182bd52c7e7300b878962c93242b5255
# nickname                                     내가만든구역이야
# matchResult                                         무
# possession                                         45
# averageRating                                 3.92778
# dribble                                            75
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          2
# effectiveShootTotal                                 2
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           120
# passSuccess                                       109
# shortPassTry                                      102
# shortPassSuccess                                   96
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     13
# throughPassSuccess                                 10
# tackleTry                                          15
# tackleSuccess                                      10
# blockTry                                            6
# blockSuccess                                        0
# goalTime                                     16779042
# x                                            0.809854
# y                                            0.513962
# type                                                2
# result                                              1
# spId                                        825247703
# assist                                           True
# assistSpId                                  801001397
# hitPost                                         False
# inPenalty                                       False
#
#                                                   295
# matchId                      67bdd9e2b4a4bc70f6b06af4
# matchDate                         2025-02-25T15:05:26
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# possession                                         55
# averageRating                                 3.98889
# dribble                                            96
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          1
# effectiveShootTotal                                 1
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           143
# passSuccess                                       131
# shortPassTry                                      117
# shortPassSuccess                                  112
# longPassTry                                         2
# longPassSuccess                                     1
# throughPassTry                                     20
# throughPassSuccess                                 15
# tackleTry                                           5
# tackleSuccess                                       2
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                     16778384
# x                                            0.915684
# y                                            0.442534
# type                                                6
# result                                              3
# spId                                        256215914
# assist                                           True
# assistSpId                                  256001075
# hitPost                                         False
# inPenalty                                        True
#
# [38 rows x 296 columns]

# %% [markdown]
# ### 2) 최근 100경기 매치 기록(전체 유저)
# - 내 기록과 비교 분석할 전체 유저의 최근 100경기 매치 기록 불러오기
# - 공식경기 기준 100경기

# %% [markdown]
# #### ㄴ 최근 100경기 매치 ID 불러오기

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/fconline/v1/match?matchtype=50&offset=0&limit=100&orderby=desc"
response = requests.get(urlString, headers = headers)

all_match_list = response.json()
all_match_list
# Out:
# ['67e12cda1441531e24fe0673',
#  '67e12cb4fe960d992ea95e3d',
#  '67e12cae8110ff59ceab18fc',
#  '67e12ca084aa860b4925003f',
#  '67e12c9354b64d3471d867a9',
#  '67e12c89498ffe01b8d87c77',
#  '67e12c882348937bb2be3e03',
#  '67e12c8373e52d5126c74ef8',
#  '67e12c75a60dcf58baaa3564',
#  '67e12c7143c05e10cffad85f',
#  '67e12c59c71dee46381d1579',
#  '67e12c573a9a0448e4cae047',
#  '67e12c515fa454fbbc9f80b8',
#  '67e12c5045753b6ab1c456a8',
#  '67e12c4c3c2bc810f05b8f5f',
#  '67e12c49c18e8116560e7580',
#  '67e12c456052dd3be7d45d69',
#  '67e12c44b3f707764d4287fe',
#  '67e12c3c8233f047695189a7',
#  '67e12c3c2a6adf28d56ebac4',
#  '67e12c37f417741caad4ce5c',
#  '67e12c344f42dc679603ba19',
#  '67e12c32d0f961115bd1c9d0',
#  '67e12c2ea92522ba15ba195b',
#  '67e12c2b166754a5e591762f',
#  '67e12c2946bf685ebffe411b',
#  '67e12c27609b6549b5dcf23b',
#  '67e12c25a36e9d0f2e79ca3d',
#  '67e12c258f4ef360634566b1',
#  '67e12c1b68f3e77e2342653c',
#  '67e12c19ff176da184fb0a57',
#  '67e12c1977fc52f011edf4e5',
#  '67e12c182d832734da75aeb7',
#  '67e12c16c29d7adf4363ad6c',
#  '67e12c0bd7d927be49c42f28',
#  '67e12c07a1eb23c47dccbe84',
#  '67e12c05edee2f32876d4342',
#  '67e12c0131c84343469aa2ea',
#  '67e12bffd6ca3973b523c474',
#  '67e12bf7e4ceb8989881031a',
#  '67e12bf67f99212a8781640f',
#  '67e12bf1ede443846797690c',
#  '67e12beda61a9a83653ad5da',
#  '67e12beda1de39528c9e49f8',
#  '67e12be950e90ce9b62a4338',
#  '67e12be8ed08638507cf738c',
#  '67e12be8ec8f4609bedd6ca3',
#  '67e12be733585b3a32045130',
#  '67e12be65fe37135d9acec10',
#  '67e12be5e9f5d8f128bc7723',
#  '67e12be4ccd8f265f4e67b96',
#  '67e12be42bbb4600728fbf1b',
#  '67e12be3cc825b032c555224',
#  '67e12be144854d539dc168d7',
#  '67e12bdb2c87ea72e0bd5b03',
#  '67e12bd999f5539f9a6ae49c',
#  '67e12bd5a9181952d2c933b2',
#  '67e12bd412fde827ca51972d',
#  '67e12bd2e4d0d6538677ad54',
#  '67e12bd02d055e77bfeb7f22',
#  '67e12bc8fcdf7f486ddfc1e2',
#  '67e12bc115564bd2822bbde1',
#  '67e12bbfbbc30e5cc5623dab',
#  '67e12bbf3ef9fa5f2b35431b',
#  '67e12bbd182f581a11bd52dd',
#  '67e12bbc38767803e676a042',
#  '67e12bb938bb5dcfcdfb8a0a',
#  '67e12bb7c66290f68b496f29',
#  '67e12bb5b8a14e4865094b7e',
#  '67e12bb36973607e57e09a37',
#  '67e12bb368c8a1cbfbe94eac',
#  '67e12bae658eed52a965e1c3',
#  '67e12bab3952a53bd3956c46',
#  '67e12ba9c05faf0f5af48f91',
#  '67e12ba9478622d733b0c30d',
#  '67e12ba62c5490528ff9a9ab',
#  '67e12ba511286cd92df8686b',
#  '67e12ba1819d3e1f7aa906b3',
#  '67e12ba11226745bdb383b60',
#  '67e12b9dc17f8b5ee394da87',
#  '67e12b9d6afeb7eb4fbb2e8f',
#  '67e12b98a1be5b117b1c2071',
#  '67e12b96028278251d0cbc69',
#  '67e12b95492dd404cba1ef5d',
#  '67e12b94a8eb113c4af9bef8',
#  '67e12b940bc44616dbbb6269',
#  '67e12b92f92dbce899a51667',
#  '67e12b9051b5ca43f3aae6a2',
#  '67e12b905163b176438411bb',
#  '67e12b8ebac9d2df5a7a2862',
#  '67e12b8d528cfe4d53a81edf',
#  '67e12b8d0f1386c5de0c2056',
#  '67e12b8cd5eb9b16be35f46e',
#  '67e12b89c85e6146e9d7bc26',
#  '67e12b88707cad2330245f10',
#  '67e12b8767733a60817afd97',
#  '67e12b7f19839528f6a51c4c',
#  '67e12b7e35f94d67d8bfe4f4',
#  '67e12b7e278704353e4d00bf',
#  '67e12b7cdf66d0ecaa812382']

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
all_match_info_list = []
for match_id in all_match_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    all_match_info_list.append(res.json())

# 예시) 매치ID별 정보
all_match_info_list[0]
# Out:
# {'matchId': '67e12cda1441531e24fe0673',
#  'matchDate': '2025-03-24T09:59:26',
#  'matchType': 50,
#  'matchInfo': [{'ouid': 'ca6649a7e2c0072696f21f4a90ff209b',
#    'nickname': '기찬이',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 2,
#     'systemPause': None,
#     'foul': None,
#     'injury': None,
#     'redCards': None,
#     'yellowCards': None,
#     'dribble': None,
#     'cornerKick': None,
#     'possession': None,
#     'offsideCount': None,
#     'averageRating': None,
#     'controller': None},
#    'shoot': {'shootTotal': None,
#     'effectiveShootTotal': None,
#     'shootOutScore': None,
#     'goalTotal': None,
#     'goalTotalDisplay': 0,
#     'ownGoal': None,
#     'shootHeading': None,
#     'goalHeading': None,
#     'shootFreekick': None,
#     'goalFreekick': None,
#     'shootInPenalty': None,
#     'goalInPenalty': None,
#     'shootOutPenalty': None,
#     'goalOutPenalty': None,
#     'shootPenaltyKick': None,
#     'goalPenaltyKick': None},
#    'shootDetail': [],
#    'pass': {'passTry': None,
#     'passSuccess': None,
#     'shortPassTry': None,
#     'shortPassSuccess': None,
#     'longPassTry': None,
#     'longPassSuccess': None,
#     'bouncingLobPassTry': None,
#     'bouncingLobPassSuccess': None,
#     'drivenGroundPassTry': None,
#     'drivenGroundPassSuccess': None,
#     'throughPassTry': None,
#     'throughPassSuccess': None,
#     'lobbedThroughPassTry': None,
#     'lobbedThroughPassSuccess': None},
#    'defence': {'blockTry': None,
#     'blockSuccess': None,
#     'tackleTry': None,
#     'tackleSuccess': None},
#    'player': []}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

all_match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in all_match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
all_match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_55518/3966322483.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67e12c9354b64d3471d867a9  2025-03-24T09:59:04        50
# 1  67e12c5045753b6ab1c456a8  2025-03-24T09:58:13        50
# 2  67e12c5045753b6ab1c456a8  2025-03-24T09:58:13        50
# 3  67e12c4c3c2bc810f05b8f5f  2025-03-24T09:59:36        50
# 4  67e12c4c3c2bc810f05b8f5f  2025-03-24T09:59:36        50
#
#                                ouid  nickname matchResult possession  \
# 0  a328c04014159b2f7e6a7b0b22951bbb   김민재어벤져스           패         35
# 1  eb24fa73d41cf2dad9b88514f074a5d7     웃음의미학           승         65
# 2  eb24fa73d41cf2dad9b88514f074a5d7     웃음의미학           승         65
# 3  9893f797d02da13d8fb89c355f74a4d7  트럼트트렁크팬티           승         43
# 4  9893f797d02da13d8fb89c355f74a4d7  트럼트트렁크팬티           승         43
#
#    averageRating dribble cornerKick  ... goalTime         x         y type  \
# 0        3.89444       4          0  ...      260  0.807309  0.424718    1
# 1        4.60556       6          0  ...      219  0.920094  0.615675    6
# 2        4.60556       6          0  ...      231  0.965155  0.506534    3
# 3        3.92222      13          1  ...     1080  0.770629  0.576073    2
# 4        3.92222      13          1  ...     1402  0.814691  0.399428    2
#
#   result       spId assist assistSpId hitPost inPenalty
# 0      2  101007826  False         -1   False     False
# 1      1  834247679   True  826210324   False      True
# 2      3  826229906  False         -1   False      True
# 3      2  829004000   True  829001419   False     False
# 4      3  825001625   True  829202652   False     False
#
# [5 rows x 38 columns]

# %%
# 파일로 저장
all_match_df.to_csv("250324_recent_matches.csv", index=False, encoding='utf-8-sig')
