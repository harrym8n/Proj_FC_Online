# %% [markdown]
# # FC온라인 API 연결

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. 데이터 설명

# %% [markdown]
# #### 매치 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **matchId**                | string     | 64f0000c00007210005f0000  | 매치 고유 식별자                                   |
# | **matchDate**              | string     | 2023-10-29T12:22:48       | 매치 일자 (UTC0)                                 |
# | **matchType**              | integer    | 52                        | 매치 종류 (/metadata/matchtype API 참고)          |
#
#
# #### matchDetails : 매치 참여 플레이어별 매치 상세
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **ouid**       | string     |                           | 계정 식별자                                        |
# | **nickname**   | string     | 닉네임                    | 유저 닉네임                                        |
#
# #### matchDetail : 매치 결과 상세 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **seasonId**          | integer  | 202311               | 시즌 ID                                            |
# | **matchResult**       | string   | 승                  | 매치 결과 (“승”, “무”, “패”)                      |
# | **matchEndType**      | integer  | 0                   | 매치 종료 타입 (0 정상종료, 1 몰수승, 2 몰수패)   |
# | **systemPause**       | integer  | 0                   | 게임 일시정지 수                                   |
# | **foul**              | integer  | 0                   | 파울 수                                            |
# | **injury**            | integer  | 1                   | 부상 수                                            |
# | **redCards**          | integer  | 0                   | 받은 레드카드 수                                   |
# | **yellowCards**       | integer  | 0                   | 받은 옐로카드 수                                   |
# | **dribble**           | integer  | 78                  | 드리블 거리(야드)                                  |
# | **cornerKick**        | integer  | 0                   | 코너킥 수                                          |
# | **possession**        | integer  | 46                  | 점유율                                             |
# | **offsideCount**      | integer  | 1                   | 오프사이드 수                                      |
# | **averageRating**     | number   | 1.18889             | 경기 평점                                          |
# | **controller**        | string   | keyboard            | 사용한 컨트롤러 타입 (keyboard / pad / etc 중 1)  |
#
#
# #### shoot : 슈팅 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **shoot**                 | object      |                           | 슈팅 정보                                          |
# | **shootTotal**                 | integer  | 3                   | 총 슛 수                                           |
# | **effectiveShootTotal**         | integer  | 3                   | 총 유효슛 수                                       |
# | **shootOutScore**              | integer  | 0                   | 승부차기 슛 수                                     |
# | **goalTotal**                  | integer  | 2                   | 총 골 수                                           |
# | **goalTotalDisplay**           | integer  | 2                   | 게임 종료 후 유저에게 노출되는 골 수              |
# | **ownGoal**                    | integer  | 0                   | 자책 골 수                                         |
# | **shootHeading**               | integer  | 2                   | 헤딩 슛 수                                         |
# | **goalHeading**                | integer  | 1                   | 헤딩 골 수                                         |
# | **shootFreekick**              | integer  | 0                   | 프리킥 슛 수                                       |
# | **goalFreekick**               | integer  | 0                   | 프리킥 골 수                                       |
# | **shootInPenalty**             | integer  | 3                   | 인패널티 슛 수                                     |
# | **goalInPenalty**              | integer  | 2                   | 인패널티 골 수                                     |
# | **shootOutPenalty**            | integer  | 0                   | 아웃패널티 슛 수                                   |
# | **goalOutPenalty**             | integer  | 0                   | 아웃패널티 골 수                                   |
# | **shootPenaltyKick**           | integer  | 0                   | 패널티킥 슛 수                                     |
# | **goalPenaltyKick**            | integer  | 0                   | 패널티킥 골 수                                     |
#
# #### pass : 패스 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **passTry**                    | integer  | 92                  | 패스 시도 수                                       |
# | **passSuccess**                | integer  | 83                  | 패스 성공 수                                       |
# | **shortPassTry**               | integer  | 55                  | 숏 패스 시도 수                                    |
# | **shortPassSuccess**           | integer  | 55                  | 숏 패스 성공 수                                    |
# | **longPassTry**                | integer  | 3                   | 롱 패스 시도 수                                    |
# | **longPassSuccess**            | integer  | 3                   | 롱 패스 성공 수                                    |
# | **bouncingLobPassTry**         | integer  | 1                   | 바운싱 롭 패스 시도 수                             |
# | **bouncingLobPassSuccess**     | integer  | 0                   | 바운싱 롭 패스 성공 수                             |
# | **drivenGroundPassTry**        | integer  | 10                  | 드리븐 땅볼 패스 시도 수                           |
# | **drivenGroundPassSuccess**    | integer  | 10                  | 드리븐 땅볼 패스 성공 수                           |
# | **throughPassTry**             | integer  | 19                  | 스루 패스 시도 수                                  |
# | **throughPassSuccess**         | integer  | 14                  | 스루 패스 성공 수                                  |
# | **lobbedThroughPassTry**       | integer  | 4                   | 로빙 스루 패스 시도 수                             |
# | **lobbedThroughPassSuccess**   | integer  | 1                   | 로빙 스루 패스 성공 수                             |
#
# #### defence : 수비 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **blockTry**                  | integer  | 3                   | 블락 시도 수                                       |
# | **blockSuccess**              | integer  | 0                   | 블락 성공 수                                       |
# | **tackleTry**                 | integer  | 11                  | 태클 시도 수                                       |
# | **tackleSuccess**             | integer  | 9                   | 태클 성공 수                                       |

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 데이터 분석 환경 조성

# %% [markdown]
# ### 라이브러리 호출

# %%
import requests
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### 매치 메타데이터 확인
# - 매치 타입 확인

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/static/fconline/meta/matchtype.json"
response = requests.get(urlString, headers = headers)

match_type = response.json()
match_type
# Out:
# [{'matchtype': 30, 'desc': '리그 친선'},
#  {'matchtype': 40, 'desc': '클래식 1on1'},
#  {'matchtype': 50, 'desc': '공식경기'},
#  {'matchtype': 52, 'desc': '감독모드'},
#  {'matchtype': 60, 'desc': '공식 친선'},
#  {'matchtype': 204, 'desc': '볼타 친선'},
#  {'matchtype': 214, 'desc': '볼타 공식'},
#  {'matchtype': 224, 'desc': '볼타 AI대전'},
#  {'matchtype': 234, 'desc': '볼타 커스텀'}]

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 데이터 프레임 생성

# %% [markdown]
# ### 1) 내 매치 기록

# %% [markdown]
# - 계정 식별자 정보 저장
#     - 추후 다른 데이터와의 연결 고리 역할 수행
#     - ouid = `56f931578b228109e8e44599da41ea64`

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}
  
characterName = "Ithas"
urlString = "https://open.api.nexon.com/fconline/v1/id?nickname=" + characterName
response = requests.get(urlString, headers = headers)

ouid = response.json()['ouid']
ouid
# Out:
# '56f931578b228109e8e44599da41ea64'

# %% [markdown]
# #### ㄴ 매치 ID 리스트 생성
# - 매치 상세 정보를 조회하는 API에 연동하기 위해 매치 ID 리스트 생성

# %%
# 매치 기록 조회(최근 매치 ID 리스트 생성)
urlString = "https://open.api.nexon.com/fconline/v1/user/match?ouid=56f931578b228109e8e44599da41ea64&matchtype=50&offset=0&limit=100"
response = requests.get(urlString, headers = headers)

# 매치 ID 리스트 생성
match_id_list = response.json()
match_id_list
# Out:
# ['67e6a4b2bed0c5400a3eca05',
#  '67e6a20ceb51ca6c5a24a2a2',
#  '67e69f2a2d3f2dc84a25c94e',
#  '67e69c788475bf3a404ed8af',
#  '67e699c8273a0b35c112786c',
#  '67e67b5fd3f3a361664f605c',
#  '67e3f253c1b497470d9cd1bb',
#  '67e3ef640655e14cb4e9d0f5',
#  '67e3ec99b6507c4202201a8a',
#  '67e3ea10175f93134fa05d18',
#  '67e2bcb4e500faa9061aa7e4',
#  '67e2b9c26abb4d343d209538',
#  '67e2b73c50ccfd375480ac37',
#  '67e2b465cdcccb1fb7ae1b28',
#  '67e2b1da9b8f6affd996c84c',
#  '67e141ab64bc4aadd4478f83',
#  '67e13eb6178c8e338ece2279',
#  '67e13c081041581f21b29426',
#  '67e13959aa13375901b07450',
#  '67e11d51d56b0f431020a326',
#  '67e115e2d31f25263ab3e538',
#  '67e11349b6764f2767dbbd64',
#  '67e110769c505b95184aa6e8',
#  '67e10dd5556da0916f3eb359',
#  '67dfedbd5315c6036c5ffb04',
#  '67dfecd36f1f400054c67cc7',
#  '67dfe8820d8347e2847e0e76',
#  '67dfe4e05b2baccd90a79566',
#  '67dfe1f9b5f1228c927f8d7b',
#  '67dfde8d027d0a782967f2dd',
#  '67dfdbd7c3b20515db2b2aaa',
#  '67dfd91e6950fe6c38f73dbd',
#  '67dfd655a90c32a27f4a1e0f',
#  '67dd8645ec70212298a55f7b',
#  '67dd8231dda981e2e4199dc0',
#  '67dd7e67c75c081c46ba90c3',
#  '67dd7b7c4f01878ae65bd76c',
#  '67dd78c9c3d42c6d9d886176',
#  '67dd7510b36edd0a5199b8de',
#  '67dd721c8afaaf18c7574daa',
#  '67dd6f48b23c74d8fd8b11d7',
#  '67dd6cc0632b415e80a9d58d',
#  '67dd6a476fb2bd6b95c4b63d',
#  '67dd67a24be0a1e397cec6dd',
#  '67dd650053e5e88154781b92',
#  '67dd625e1c27c154b533a0aa']

# %%
# 내 경기 수
len(match_id_list)
# Out:
# 46

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
match_info_list = []
for match_id in match_id_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    match_info_list.append(res.json())

# 예시) 매치ID별 정보
match_info_list[0]
# Out:
# {'matchId': '67e6a4b2bed0c5400a3eca05',
#  'matchDate': '2025-03-28T13:41:45',
#  'matchType': 50,
#  'matchInfo': [{'ouid': 'a4900289956e2a6022bc5f03dd10e717',
#    'nickname': '서진원이',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 1,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 50,
#     'cornerKick': 0,
#     'possession': 39,
#     'offsideCount': 0,
#     'averageRating': 3.75556,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 4,
#     'effectiveShootTotal': 4,
#     'shootOutScore': 0,
#     'goalTotal': 2,
#     'goalTotalDisplay': 3,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 2,
#     'goalInPenalty': 1,
#     'shootOutPenalty': 2,
#     'goalOutPenalty': 1,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 1757,
#      'x': 0.9503786563873292,
#      'y': 0.5425764322280884,
#      'type': 3,
#      'result': 1,
#      'spId': 825252371,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1386,
#      'x': 0.8115199208259583,
#      'y': 0.41259828209877,
#      'type': 2,
#      'result': 1,
#      'spId': 278231747,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 274001040,
#      'assistX': 0.4004442095756531,
#      'assistY': 0.1379397958517075,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16779624,
#      'x': 0.8376187682151794,
#      'y': 0.4184912443161011,
#      'type': 2,
#      'result': 3,
#      'spId': 278231747,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 825252371,
#      'assistX': 0.7077145576477051,
#      'assistY': 0.2660371959209442,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 1203,
#      'x': 0.968987226486206,
#      'y': 0.4516517221927643,
#      'type': 3,
#      'result': 3,
#      'spId': 825238794,
#      'spGrade': 5,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 827138449,
#      'assistX': 0.95113468170166,
#      'assistY': 0.8026637434959412,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 69,
#     'passSuccess': 60,
#     'shortPassTry': 41,
#     'shortPassSuccess': 38,
#     'longPassTry': 4,
#     'longPassSuccess': 2,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 0,
#     'drivenGroundPassSuccess': 0,
#     'throughPassTry': 19,
#     'throughPassSuccess': 18,
#     'lobbedThroughPassTry': 4,
#     'lobbedThroughPassSuccess': 2},
#    'defence': {'blockTry': 8,
#     'blockSuccess': 2,
#     'tackleTry': 14,
#     'tackleSuccess': 6},
#    'player': [{'spId': 300221845,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 827138449,
#      'spPosition': 17,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 232,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 5,
#       'dribbleTry': 7,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.7}},
#     {'spId': 274001040,
#      'spPosition': 7,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 35,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 1,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.6}},
#     {'spId': 825252371,
#      'spPosition': 18,
#      'spGrade': 5,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 272,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 19,
#       'passSuccess': 16,
#       'dribbleTry': 8,
#       'dribbleSuccess': 8,
#       'ballPossesionTry': 8,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 3,
#       'aerialSuccess': 1,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.5}},
#     {'spId': 256204963,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 2,
#       'passSuccess': 1,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 3.6}},
#     {'spId': 825240130,
#      'spPosition': 4,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 45,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 6,
#       'dribbleTry': 5,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 3,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.1}},
#     {'spId': 278231747,
#      'spPosition': 25,
#      'spGrade': 5,
#      'status': {'shoot': 2,
#       'effectiveShoot': 2,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 373,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 8,
#       'dribbleTry': 10,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 8,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.8}},
#     {'spId': 300220829,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 270205452,
#      'spPosition': 6,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 26,
#       'intercept': 3,
#       'defending': 0,
#       'passTry': 1,
#       'passSuccess': 1,
#       'dribbleTry': 3,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 1,
#       'tackleTry': 3,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.9}},
#     {'spId': 300242000,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 300190491,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 810248243,
#      'spPosition': 9,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 182,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 6,
#       'dribbleTry': 9,
#       'dribbleSuccess': 8,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.3}},
#     {'spId': 287239053,
#      'spPosition': 11,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 108,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 5,
#       'passSuccess': 5,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.7}},
#     {'spId': 300274105,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 825238794,
#      'spPosition': 19,
#      'spGrade': 5,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 146,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 6,
#       'dribbleTry': 4,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 3,
#       'aerialSuccess': 1,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.5}},
#     {'spId': 300192119,
#      'spPosition': 0,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 6,
#       'passTry': 5,
#       'passSuccess': 3,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.9}},
#     {'spId': 300251025,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 300244680,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]},
#   {'ouid': '56f931578b228109e8e44599da41ea64',
#    'nickname': 'Ithas',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '승',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 92,
#     'cornerKick': 3,
#     'possession': 61,
#     'offsideCount': 0,
#     'averageRating': 4.48889,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 13,
#     'effectiveShootTotal': 9,
#     'shootOutScore': 0,
#     'goalTotal': 4,
#     'goalTotalDisplay': 4,
#     'ownGoal': 1,
#     'shootHeading': 1,
#     'goalHeading': 1,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 11,
#     'goalInPenalty': 4,
#     'shootOutPenalty': 2,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 2470,
#      'x': 0.916851043701172,
#      'y': 0.5177618861198425,
#      'type': 3,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2615,
#      'x': 0.90458196401596,
#      'y': 0.596013605594635,
#      'type': 6,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.7895100116729736,
#      'assistY': 0.4823338687419891,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1977,
#      'x': 0.9852265119552612,
#      'y': 0.6324434876441956,
#      'type': 6,
#      'result': 3,
#      'spId': 256192985,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': True,
#      'inPenalty': True},
#     {'goalTime': 1023,
#      'x': 0.9261093139648438,
#      'y': 0.36150512099266,
#      'type': 6,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.7837963700294495,
#      'assistY': 0.3754402697086334,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 576,
#      'x': 0.8367319703102112,
#      'y': 0.4982626438140869,
#      'type': 2,
#      'result': 2,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.6301060914993286,
#      'assistY': 0.7059091329574585,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16779975,
#      'x': 0.930897891521454,
#      'y': 0.4475841224193573,
#      'type': 6,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.8920491933822632,
#      'assistY': 0.5401839017868042,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778080,
#      'x': 0.8838391304016113,
#      'y': 0.5089022517204285,
#      'type': 2,
#      'result': 1,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.8171653747558594,
#      'assistY': 0.4147112369537354,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778339,
#      'x': 0.8662030696868896,
#      'y': 0.5042906999588013,
#      'type': 2,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256214098,
#      'assistX': 0.8063093423843384,
#      'assistY': 0.5963864326477051,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1955,
#      'x': 0.88223123550415,
#      'y': 0.42396941781044,
#      'type': 2,
#      'result': 1,
#      'spId': 256004833,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001109,
#      'assistX': 0.8581412434577942,
#      'assistY': 0.1732369810342789,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1081,
#      'x': 0.9222592115402222,
#      'y': 0.5698856115341187,
#      'type': 3,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.7837963700294495,
#      'assistY': 0.3754402697086334,
#      'hitPost': True,
#      'inPenalty': True},
#     {'goalTime': 226,
#      'x': 0.8906824588775635,
#      'y': 0.4684011936187744,
#      'type': 2,
#      'result': 2,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.8613903522491455,
#      'assistY': 0.3570836186408997,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778865,
#      'x': 0.8660162091255188,
#      'y': 0.5037207007408142,
#      'type': 6,
#      'result': 1,
#      'spId': 256192985,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.70459359884262,
#      'assistY': 0.3813149034976959,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2381,
#      'x': 0.8375300765037537,
#      'y': 0.5365825891494751,
#      'type': 1,
#      'result': 2,
#      'spId': 256214098,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256215914,
#      'assistX': 0.6872134208679199,
#      'assistY': 0.4215485155582428,
#      'hitPost': False,
#      'inPenalty': False}],
#    'pass': {'passTry': 150,
#     'passSuccess': 140,
#     'shortPassTry': 125,
#     'shortPassSuccess': 119,
#     'longPassTry': 3,
#     'longPassSuccess': 2,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 1,
#     'drivenGroundPassSuccess': 1,
#     'throughPassTry': 21,
#     'throughPassSuccess': 18,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 6,
#     'blockSuccess': 1,
#     'tackleTry': 6,
#     'tackleSuccess': 5},
#    'player': [{'spId': 289261593,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256140601,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 54,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 9,
#       'passSuccess': 8,
#       'dribbleTry': 5,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 1,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.0}},
#     {'spId': 251005099,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256051539,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 1,
#       'passTry': 1,
#       'passSuccess': 1,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 256007289,
#      'spPosition': 4,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 90,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 3,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.4}},
#     {'spId': 234192119,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256214098,
#      'spPosition': 9,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 272,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 19,
#       'passSuccess': 17,
#       'dribbleTry': 12,
#       'dribbleSuccess': 12,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 6,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.0}},
#     {'spId': 253188377,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256004833,
#      'spPosition': 27,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 280,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 17,
#       'passSuccess': 17,
#       'dribbleTry': 9,
#       'dribbleSuccess': 9,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.1}},
#     {'spId': 256004231,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256215914,
#      'spPosition': 11,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 314,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 21,
#       'passSuccess': 21,
#       'dribbleTry': 10,
#       'dribbleSuccess': 9,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 2,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.9}},
#     {'spId': 268192181,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256192985,
#      'spPosition': 23,
#      'spGrade': 8,
#      'status': {'shoot': 2,
#       'effectiveShoot': 2,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 257,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 16,
#       'passSuccess': 14,
#       'dribbleTry': 11,
#       'dribbleSuccess': 9,
#       'ballPossesionTry': 8,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 3,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.1}},
#     {'spId': 256001075,
#      'spPosition': 18,
#      'spGrade': 8,
#      'status': {'shoot': 3,
#       'effectiveShoot': 2,
#       'assist': 1,
#       'goal': 1,
#       'dribble': 423,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 23,
#       'passSuccess': 20,
#       'dribbleTry': 19,
#       'dribbleSuccess': 17,
#       'ballPossesionTry': 6,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.0}},
#     {'spId': 256242519,
#      'spPosition': 25,
#      'spGrade': 8,
#      'status': {'shoot': 6,
#       'effectiveShoot': 4,
#       'assist': 1,
#       'goal': 2,
#       'dribble': 291,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 23,
#       'passSuccess': 22,
#       'dribbleTry': 17,
#       'dribbleSuccess': 14,
#       'ballPossesionTry': 9,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 4,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 2,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.6}},
#     {'spId': 256001041,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 13,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 8,
#       'dribbleTry': 1,
#       'dribbleSuccess': 1,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 2,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.7}},
#     {'spId': 256001109,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 81,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 9,
#       'dribbleTry': 5,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 11,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.6}},
#     {'spId': 274000250,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "matchEndType","foul", "injury", 
    "redCards", "yellowCards","possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "matchEndType": match_detail['matchEndType'],
                    "foul": match_detail['foul'],
                    "injury": match_detail['injury'],
                    "redCards": match_detail['redCards'],
                    "yellowCards": match_detail['yellowCards'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_11353/3420171123.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67e6a4b2bed0c5400a3eca05  2025-03-28T13:41:45        50
# 1  67e6a4b2bed0c5400a3eca05  2025-03-28T13:41:45        50
# 2  67e6a4b2bed0c5400a3eca05  2025-03-28T13:41:45        50
# 3  67e6a4b2bed0c5400a3eca05  2025-03-28T13:41:45        50
# 4  67e6a4b2bed0c5400a3eca05  2025-03-28T13:41:45        50
#
#                                ouid nickname matchResult matchEndType foul  \
# 0  a4900289956e2a6022bc5f03dd10e717     서진원이           패            0    1
# 1  a4900289956e2a6022bc5f03dd10e717     서진원이           패            0    1
# 2  a4900289956e2a6022bc5f03dd10e717     서진원이           패            0    1
# 3  a4900289956e2a6022bc5f03dd10e717     서진원이           패            0    1
# 4  56f931578b228109e8e44599da41ea64    Ithas           승            0    0
#
#   injury redCards  ...  goalTime         x         y type result       spId  \
# 0      0        0  ...      1757  0.950379  0.542576    3      1  825252371
# 1      0        0  ...      1386  0.811520  0.412598    2      1  278231747
# 2      0        0  ...  16779624  0.837619  0.418491    2      3  278231747
# 3      0        0  ...      1203  0.968987  0.451652    3      3  825238794
# 4      0        0  ...      2470  0.916851  0.517762    3      1  256242519
#
#   assist assistSpId hitPost inPenalty
# 0  False         -1   False      True
# 1   True  274001040   False     False
# 2   True  825252371   False     False
# 3   True  827138449   False      True
# 4  False         -1   False      True
#
# [5 rows x 43 columns]

# %%
match_df.T
# Out:
#                                                   0    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 a4900289956e2a6022bc5f03dd10e717
# nickname                                         서진원이
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         39
# averageRating                                 3.75556
# dribble                                            50
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          4
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            69
# passSuccess                                        60
# shortPassTry                                       41
# shortPassSuccess                                   38
# longPassTry                                         4
# longPassSuccess                                     2
# throughPassTry                                     19
# throughPassSuccess                                 18
# tackleTry                                          14
# tackleSuccess                                       6
# blockTry                                            8
# blockSuccess                                        2
# goalTime                                         1757
# x                                            0.950379
# y                                            0.542576
# type                                                3
# result                                              1
# spId                                        825252371
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   1    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 a4900289956e2a6022bc5f03dd10e717
# nickname                                         서진원이
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         39
# averageRating                                 3.75556
# dribble                                            50
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          4
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            69
# passSuccess                                        60
# shortPassTry                                       41
# shortPassSuccess                                   38
# longPassTry                                         4
# longPassSuccess                                     2
# throughPassTry                                     19
# throughPassSuccess                                 18
# tackleTry                                          14
# tackleSuccess                                       6
# blockTry                                            8
# blockSuccess                                        2
# goalTime                                         1386
# x                                             0.81152
# y                                            0.412598
# type                                                2
# result                                              1
# spId                                        278231747
# assist                                           True
# assistSpId                                  274001040
# hitPost                                         False
# inPenalty                                       False
#
#                                                   2    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 a4900289956e2a6022bc5f03dd10e717
# nickname                                         서진원이
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         39
# averageRating                                 3.75556
# dribble                                            50
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          4
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            69
# passSuccess                                        60
# shortPassTry                                       41
# shortPassSuccess                                   38
# longPassTry                                         4
# longPassSuccess                                     2
# throughPassTry                                     19
# throughPassSuccess                                 18
# tackleTry                                          14
# tackleSuccess                                       6
# blockTry                                            8
# blockSuccess                                        2
# goalTime                                     16779624
# x                                            0.837619
# y                                            0.418491
# type                                                2
# result                                              3
# spId                                        278231747
# assist                                           True
# assistSpId                                  825252371
# hitPost                                         False
# inPenalty                                       False
#
#                                                   3    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 a4900289956e2a6022bc5f03dd10e717
# nickname                                         서진원이
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         39
# averageRating                                 3.75556
# dribble                                            50
# cornerKick                                          0
# offsideCount                                        0
# shootTotal                                          4
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            69
# passSuccess                                        60
# shortPassTry                                       41
# shortPassSuccess                                   38
# longPassTry                                         4
# longPassSuccess                                     2
# throughPassTry                                     19
# throughPassSuccess                                 18
# tackleTry                                          14
# tackleSuccess                                       6
# blockTry                                            8
# blockSuccess                                        2
# goalTime                                         1203
# x                                            0.968987
# y                                            0.451652
# type                                                3
# result                                              3
# spId                                        825238794
# assist                                           True
# assistSpId                                  827138449
# hitPost                                         False
# inPenalty                                        True
#
#                                                   4    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         61
# averageRating                                 4.48889
# dribble                                            92
# cornerKick                                          3
# offsideCount                                        0
# shootTotal                                         13
# effectiveShootTotal                                 9
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           150
# passSuccess                                       140
# shortPassTry                                      125
# shortPassSuccess                                  119
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     21
# throughPassSuccess                                 18
# tackleTry                                           6
# tackleSuccess                                       5
# blockTry                                            6
# blockSuccess                                        1
# goalTime                                         2470
# x                                            0.916851
# y                                            0.517762
# type                                                3
# result                                              1
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   5    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         61
# averageRating                                 4.48889
# dribble                                            92
# cornerKick                                          3
# offsideCount                                        0
# shootTotal                                         13
# effectiveShootTotal                                 9
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           150
# passSuccess                                       140
# shortPassTry                                      125
# shortPassSuccess                                  119
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     21
# throughPassSuccess                                 18
# tackleTry                                           6
# tackleSuccess                                       5
# blockTry                                            6
# blockSuccess                                        1
# goalTime                                         2615
# x                                            0.904582
# y                                            0.596014
# type                                                6
# result                                              3
# spId                                        256242519
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                        True
#
#                                                   6    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         61
# averageRating                                 4.48889
# dribble                                            92
# cornerKick                                          3
# offsideCount                                        0
# shootTotal                                         13
# effectiveShootTotal                                 9
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           150
# passSuccess                                       140
# shortPassTry                                      125
# shortPassSuccess                                  119
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     21
# throughPassSuccess                                 18
# tackleTry                                           6
# tackleSuccess                                       5
# blockTry                                            6
# blockSuccess                                        1
# goalTime                                         1977
# x                                            0.985227
# y                                            0.632443
# type                                                6
# result                                              3
# spId                                        256192985
# assist                                          False
# assistSpId                                         -1
# hitPost                                          True
# inPenalty                                        True
#
#                                                   7    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         61
# averageRating                                 4.48889
# dribble                                            92
# cornerKick                                          3
# offsideCount                                        0
# shootTotal                                         13
# effectiveShootTotal                                 9
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           150
# passSuccess                                       140
# shortPassTry                                      125
# shortPassSuccess                                  119
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     21
# throughPassSuccess                                 18
# tackleTry                                           6
# tackleSuccess                                       5
# blockTry                                            6
# blockSuccess                                        1
# goalTime                                         1023
# x                                            0.926109
# y                                            0.361505
# type                                                6
# result                                              1
# spId                                        256242519
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                        True
#
#                                                   8    \
# matchId                      67e6a4b2bed0c5400a3eca05
# matchDate                         2025-03-28T13:41:45
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                0
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         61
# averageRating                                 4.48889
# dribble                                            92
# cornerKick                                          3
# offsideCount                                        0
# shootTotal                                         13
# effectiveShootTotal                                 9
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           150
# passSuccess                                       140
# shortPassTry                                      125
# shortPassSuccess                                  119
# longPassTry                                         3
# longPassSuccess                                     2
# throughPassTry                                     21
# throughPassSuccess                                 18
# tackleTry                                           6
# tackleSuccess                                       5
# blockTry                                            6
# blockSuccess                                        1
# goalTime                                          576
# x                                            0.836732
# y                                            0.498263
# type                                                2
# result                                              2
# spId                                        256001075
# assist                                           True
# assistSpId                                  256192985
# hitPost                                         False
# inPenalty                                       False
#
#                                                   9    ...  \
# matchId                      67e6a4b2bed0c5400a3eca05  ...
# matchDate                         2025-03-28T13:41:45  ...
# matchType                                          50  ...
# ouid                 56f931578b228109e8e44599da41ea64  ...
# nickname                                        Ithas  ...
# matchResult                                         승  ...
# matchEndType                                        0  ...
# foul                                                0  ...
# injury                                              0  ...
# redCards                                            0  ...
# yellowCards                                         0  ...
# possession                                         61  ...
# averageRating                                 4.48889  ...
# dribble                                            92  ...
# cornerKick                                          3  ...
# offsideCount                                        0  ...
# shootTotal                                         13  ...
# effectiveShootTotal                                 9  ...
# goalTotal                                           4  ...
# shootPenaltyKick                                    0  ...
# goalPenaltyKick                                     0  ...
# passTry                                           150  ...
# passSuccess                                       140  ...
# shortPassTry                                      125  ...
# shortPassSuccess                                  119  ...
# longPassTry                                         3  ...
# longPassSuccess                                     2  ...
# throughPassTry                                     21  ...
# throughPassSuccess                                 18  ...
# tackleTry                                           6  ...
# tackleSuccess                                       5  ...
# blockTry                                            6  ...
# blockSuccess                                        1  ...
# goalTime                                     16779975  ...
# x                                            0.930898  ...
# y                                            0.447584  ...
# type                                                6  ...
# result                                              3  ...
# spId                                        256001075  ...
# assist                                           True  ...
# assistSpId                                  256242519  ...
# hitPost                                         False  ...
# inPenalty                                        True  ...
#
#                                                   439  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 462fc65306a363f4bb8d476d428c3637
# nickname                                        메시더풋볼
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         43
# averageRating                                 4.08889
# dribble                                            59
# cornerKick                                          3
# offsideCount                                        1
# shootTotal                                         10
# effectiveShootTotal                                 9
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           126
# passSuccess                                       115
# shortPassTry                                      103
# shortPassSuccess                                  100
# longPassTry                                         3
# longPassSuccess                                     3
# throughPassTry                                     18
# throughPassSuccess                                 10
# tackleTry                                          16
# tackleSuccess                                       8
# blockTry                                            9
# blockSuccess                                        0
# goalTime                                         1866
# x                                            0.774217
# y                                            0.470212
# type                                                2
# result                                              3
# spId                                        820265695
# assist                                           True
# assistSpId                                  289180930
# hitPost                                         False
# inPenalty                                       False
#
#                                                   440  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         2248
# x                                            0.839312
# y                                            0.627562
# type                                                2
# result                                              1
# spId                                        256001075
# assist                                           True
# assistSpId                                  256215914
# hitPost                                         False
# inPenalty                                       False
#
#                                                   441  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16779413
# x                                            0.825106
# y                                             0.50894
# type                                                2
# result                                              2
# spId                                        256004231
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                       False
#
#                                                   442  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16779481
# x                                            0.918926
# y                                            0.477989
# type                                                3
# result                                              2
# spId                                        256001109
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   443  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         2436
# x                                             0.88588
# y                                            0.457237
# type                                                7
# result                                              2
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   444  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16780139
# x                                            0.753972
# y                                             0.67202
# type                                                2
# result                                              2
# spId                                        256004833
# assist                                           True
# assistSpId                                  256214098
# hitPost                                         False
# inPenalty                                       False
#
#                                                   445  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         1318
# x                                            0.955235
# y                                            0.456421
# type                                                3
# result                                              2
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   446  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16777812
# x                                            0.894049
# y                                            0.581159
# type                                                6
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256242519
# hitPost                                         False
# inPenalty                                        True
#
#                                                   447  \
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                         2324
# x                                            0.868979
# y                                            0.539869
# type                                                1
# result                                              1
# spId                                        256242519
# assist                                           True
# assistSpId                                  256215914
# hitPost                                         False
# inPenalty                                        True
#
#                                                   448
# matchId                      67dd625e1c27c154b533a0aa
# matchDate                         2025-03-21T13:08:27
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         무
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         57
# averageRating                                 4.20556
# dribble                                            82
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          9
# effectiveShootTotal                                 4
# goalTotal                                           1
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                           110
# passSuccess                                        99
# shortPassTry                                       81
# shortPassSuccess                                   75
# longPassTry                                         8
# longPassSuccess                                     5
# throughPassTry                                     18
# throughPassSuccess                                 16
# tackleTry                                           3
# tackleSuccess                                       1
# blockTry                                           11
# blockSuccess                                        2
# goalTime                                     16779004
# x                                            0.940907
# y                                            0.392542
# type                                                2
# result                                              1
# spId                                        256242519
# assist                                           True
# assistSpId                                  256215914
# hitPost                                         False
# inPenalty                                        True
#
# [43 rows x 449 columns]

# %% [markdown]
# ### 2) 최근 100경기 매치 기록(전체 유저)
# - 내 기록과 비교 분석할 전체 유저의 최근 100경기 매치 기록 불러오기
# - 공식경기 기준 100경기

# %% [markdown]
# #### ㄴ 최근 100경기 매치 ID 불러오기

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/fconline/v1/match?matchtype=50&offset=0&limit=100&orderby=desc"
response = requests.get(urlString, headers = headers)

all_match_list = response.json()
print(len(all_match_list))
all_match_list
# Out:
# 100
# ['67ea4b388b645c442cb79ebf',
#  '67ea4b27d5451f3b73f813c2',
#  '67ea4b262ebec069ffe7ff82',
#  '67ea4aed71b587c1b0ff595c',
#  '67ea4ae4b27e70cc98e27ea0',
#  '67ea4ad9bf884cc617cd57c2',
#  '67ea4acfa67c4e29bdfe79b7',
#  '67ea4ace7ae3fc7e590bdbfa',
#  '67ea4aca37085736ab2b3f59',
#  '67ea4ac9690385336c5cc888',
#  '67ea4ab4b7bb3cc5b25aeab1',
#  '67ea4ab27824726e156c8d98',
#  '67ea4aad6442470c80fda8b1',
#  '67ea4aa88aed664ed6e154f7',
#  '67ea4a91c9f6a0708353f9a0',
#  '67ea4a8ed242cf92d1135393',
#  '67ea4a8e385f756cfdf8ad40',
#  '67ea4a8c3783d6593772be4f',
#  '67ea4a85d016e86b9d1ee9ed',
#  '67ea4a85410e0ab1503bb8ea',
#  '67ea4a7aaf41a877343a042b',
#  '67ea4a69ec775b42d82dbc1e',
#  '67ea4a67321aa5767cec579a',
#  '67ea4a663e9abf258b322635',
#  '67ea4a6541dad2346372fd66',
#  '67ea4a5e04924293a970dc0d',
#  '67ea4a5dc8e258b70de44390',
#  '67ea4a5879709b1647fec45d',
#  '67ea4a5760f5bb767f315409',
#  '67ea4a4a9bce8f8515edb372',
#  '67ea4a4a22bb7312785b445e',
#  '67ea4a49b0ee73000cbbce47',
#  '67ea4a48d6a56d9d6645d3d9',
#  '67ea4a47c3f4204563d21e76',
#  '67ea4a3a2576e1cade9a9a9a',
#  '67ea4a3786bb5d7d22d95a9b',
#  '67ea4a367656495d4d412552',
#  '67ea4a3653b888cbb262d908',
#  '67ea4a3648603700e1fefd75',
#  '67ea4a326e80d0037a194702',
#  '67ea4a301c84db31ae2489db',
#  '67ea4a2f2ce63d166518489d',
#  '67ea4a2970721c4476f029b2',
#  '67ea4a27e1e0696066139a8b',
#  '67ea4a266ffbb012809758d4',
#  '67ea4a251caedee4437834ba',
#  '67ea4a248b1dbf1869e3ebb2',
#  '67ea4a22f2bb1782119e8f8e',
#  '67ea4a1fc631b41f5c7968dd',
#  '67ea4a1dd637de32a6dcd21d',
#  '67ea4a1d23784803d0681313',
#  '67ea4a179a64f2b27cd0f390',
#  '67ea4a1570bed41e26be5f28',
#  '67ea4a11f2ae46e94dced91b',
#  '67ea4a107cd91c60674ce7f7',
#  '67ea4a0bcb83e77ff2f5fefc',
#  '67ea4a0a840ec36dbd52dd8a',
#  '67ea4a0a67b6d0a84b322bdd',
#  '67ea4a07debff9fe0ff85451',
#  '67ea4a07af20152a122590ab',
#  '67ea4a06244cfd30406e4d31',
#  '67ea4a0209b39213f4d39ebd',
#  '67ea49ffbc4b706aaad5f3a4',
#  '67ea49fe3fced02c4ffe3e08',
#  '67ea49fdf9abd78698ab108d',
#  '67ea49fdd81146b7bf1d9c7c',
#  '67ea49fcc1a7bda0ae9686c2',
#  '67ea49f97f7e3b491664ec2a',
#  '67ea49f8a063fd5de5f57375',
#  '67ea49f5ffe97d45d26e72af',
#  '67ea49f50ee004dbe89ae0b6',
#  '67ea49f368384b03411bea8f',
#  '67ea49f1b939b294084a989d',
#  '67ea49ef7f4ec85cbec55ea0',
#  '67ea49edd4c41dad4ab078d7',
#  '67ea49ec5187dd604105c551',
#  '67ea49e216d285340233095b',
#  '67ea49e175ce7fcecfcd06c1',
#  '67ea49e06a946f807ec0aaa5',
#  '67ea49e01a9a8dcac26a7170',
#  '67ea49de5927569fe06b9955',
#  '67ea49dd98d38ad955269ed0',
#  '67ea49dca20baddc3122627c',
#  '67ea49dad35f4305fb424928',
#  '67ea49d8cb8cb6112948b27a',
#  '67ea49d7690385eb285cc3fa',
#  '67ea49d4f139ca1051026289',
#  '67ea49d4806132402179bd6f',
#  '67ea49d3d3cdc15ca8af372c',
#  '67ea49d3b2ac446c861784ee',
#  '67ea49ced88bee5a223b4f73',
#  '67ea49cde5359e1e3758fcaa',
#  '67ea49cc296450574e82d92c',
#  '67ea49c6a0492253ca51f1d5',
#  '67ea49c5189db29ac2988125',
#  '67ea49c2b460280421d8eb38',
#  '67ea49c2416aa225b3e3b554',
#  '67ea49c1370e3c6fafd2b118',
#  '67ea49c0ea6c70de30ab672e',
#  '67ea49c03cdcbd4cb2d22914']

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
all_match_info_list = []
for match_id in all_match_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    all_match_info_list.append(res.json())

# 예시) 매치ID별 정보
all_match_info_list[0]
# Out:
# {'matchId': '67ea4b388b645c442cb79ebf',
#  'matchDate': '2025-03-31T07:59:49',
#  'matchType': 50,
#  'matchInfo': [{'ouid': '34479eade0aeb2223d6520d818362703',
#    'nickname': 'MRNICE',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 2,
#     'systemPause': None,
#     'foul': None,
#     'injury': None,
#     'redCards': None,
#     'yellowCards': None,
#     'dribble': None,
#     'cornerKick': None,
#     'possession': None,
#     'offsideCount': None,
#     'averageRating': None,
#     'controller': None},
#    'shoot': {'shootTotal': None,
#     'effectiveShootTotal': None,
#     'shootOutScore': None,
#     'goalTotal': None,
#     'goalTotalDisplay': 0,
#     'ownGoal': None,
#     'shootHeading': None,
#     'goalHeading': None,
#     'shootFreekick': None,
#     'goalFreekick': None,
#     'shootInPenalty': None,
#     'goalInPenalty': None,
#     'shootOutPenalty': None,
#     'goalOutPenalty': None,
#     'shootPenaltyKick': None,
#     'goalPenaltyKick': None},
#    'shootDetail': [],
#    'pass': {'passTry': None,
#     'passSuccess': None,
#     'shortPassTry': None,
#     'shortPassSuccess': None,
#     'longPassTry': None,
#     'longPassSuccess': None,
#     'bouncingLobPassTry': None,
#     'bouncingLobPassSuccess': None,
#     'drivenGroundPassTry': None,
#     'drivenGroundPassSuccess': None,
#     'throughPassTry': None,
#     'throughPassSuccess': None,
#     'lobbedThroughPassTry': None,
#     'lobbedThroughPassSuccess': None},
#    'defence': {'blockTry': None,
#     'blockSuccess': None,
#     'tackleTry': None,
#     'tackleSuccess': None},
#    'player': []}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "matchEndType","foul", "injury", 
    "redCards", "yellowCards","possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

all_match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in all_match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "matchEndType": match_detail['matchEndType'],
                    "foul": match_detail['foul'],
                    "injury": match_detail['injury'],
                    "redCards": match_detail['redCards'],
                    "yellowCards": match_detail['yellowCards'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
all_match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_23177/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67ea4a8ed242cf92d1135393  2025-03-31T07:59:52        50
# 1  67ea4a8ed242cf92d1135393  2025-03-31T07:59:52        50
# 2  67ea4a8ed242cf92d1135393  2025-03-31T07:59:52        50
# 3  67ea4a8ed242cf92d1135393  2025-03-31T07:59:52        50
# 4  67ea4a8ed242cf92d1135393  2025-03-31T07:59:52        50
#
#                                ouid nickname matchResult matchEndType foul  \
# 0  9c559c67a72cd8212b3d44fd6b0b63f2    천하토트넘           승            1    0
# 1  9c559c67a72cd8212b3d44fd6b0b63f2    천하토트넘           승            1    0
# 2  9c559c67a72cd8212b3d44fd6b0b63f2    천하토트넘           승            1    0
# 3  9c559c67a72cd8212b3d44fd6b0b63f2    천하토트넘           승            1    0
# 4  9c559c67a72cd8212b3d44fd6b0b63f2    천하토트넘           승            1    0
#
#   injury redCards  ... goalTime         x         y type result       spId  \
# 0      0        0  ...     1695  0.837765  0.408735    2      3  826210514
# 1      0        0  ...     1149  0.932077  0.438712    3      2  283240679
# 2      0        0  ...     1098  0.924210  0.357942    1      1  826210514
# 3      0        0  ...      867  0.890103  0.638607    1      3  825001075
# 4      0        0  ...      130  0.837673  0.541231    1      1  821143001
#
#   assist assistSpId hitPost inPenalty
# 0   True  291241629   False     False
# 1  False         -1   False      True
# 2   True  821143001   False      True
# 3   True  821143001   False      True
# 4   True  826210514   False     False
#
# [5 rows x 43 columns]

# %%
all_match_df['matchEndType'].value_counts()
# Out:
# matchEndType
# 1    95
# 2    25
# Name: count, dtype: int64

# %%
# 파일로 저장
today = str(datetime.today().strftime('%Y%m%d'))[2:]
all_match_df.to_csv(f"data/{today}_recent_matches.csv", index=False, encoding='utf-8-sig')
