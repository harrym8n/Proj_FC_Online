# %% [markdown]
# # FC온라인 API 연결

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. 데이터 설명

# %% [markdown]
# #### 매치 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **matchId**                | string     | 64f0000c00007210005f0000  | 매치 고유 식별자                                   |
# | **matchDate**              | string     | 2023-10-29T12:22:48       | 매치 일자 (UTC0)                                 |
# | **matchType**              | integer    | 52                        | 매치 종류 (/metadata/matchtype API 참고)          |
#
#
# #### matchDetails : 매치 참여 플레이어별 매치 상세
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|-----------------------------------------------|
# | **ouid**       | string     |                           | 계정 식별자                                        |
# | **nickname**   | string     | 닉네임                    | 유저 닉네임                                        |
#
# #### matchDetail : 매치 결과 상세 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **seasonId**          | integer  | 202311               | 시즌 ID                                            |
# | **matchResult**       | string   | 승                  | 매치 결과 (“승”, “무”, “패”)                      |
# | **matchEndType**      | integer  | 0                   | 매치 종료 타입 (0 정상종료, 1 몰수승, 2 몰수패)   |
# | **systemPause**       | integer  | 0                   | 게임 일시정지 수                                   |
# | **foul**              | integer  | 0                   | 파울 수                                            |
# | **injury**            | integer  | 1                   | 부상 수                                            |
# | **redCards**          | integer  | 0                   | 받은 레드카드 수                                   |
# | **yellowCards**       | integer  | 0                   | 받은 옐로카드 수                                   |
# | **dribble**           | integer  | 78                  | 드리블 거리(야드)                                  |
# | **cornerKick**        | integer  | 0                   | 코너킥 수                                          |
# | **possession**        | integer  | 46                  | 점유율                                             |
# | **offsideCount**      | integer  | 1                   | 오프사이드 수                                      |
# | **averageRating**     | number   | 1.18889             | 경기 평점                                          |
# | **controller**        | string   | keyboard            | 사용한 컨트롤러 타입 (keyboard / pad / etc 중 1)  |
#
#
# #### shoot : 슈팅 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **shoot**                 | object      |                           | 슈팅 정보                                          |
# | **shootTotal**                 | integer  | 3                   | 총 슛 수                                           |
# | **effectiveShootTotal**         | integer  | 3                   | 총 유효슛 수                                       |
# | **shootOutScore**              | integer  | 0                   | 승부차기 슛 수                                     |
# | **goalTotal**                  | integer  | 2                   | 총 골 수                                           |
# | **goalTotalDisplay**           | integer  | 2                   | 게임 종료 후 유저에게 노출되는 골 수              |
# | **ownGoal**                    | integer  | 0                   | 자책 골 수                                         |
# | **shootHeading**               | integer  | 2                   | 헤딩 슛 수                                         |
# | **goalHeading**                | integer  | 1                   | 헤딩 골 수                                         |
# | **shootFreekick**              | integer  | 0                   | 프리킥 슛 수                                       |
# | **goalFreekick**               | integer  | 0                   | 프리킥 골 수                                       |
# | **shootInPenalty**             | integer  | 3                   | 인패널티 슛 수                                     |
# | **goalInPenalty**              | integer  | 2                   | 인패널티 골 수                                     |
# | **shootOutPenalty**            | integer  | 0                   | 아웃패널티 슛 수                                   |
# | **goalOutPenalty**             | integer  | 0                   | 아웃패널티 골 수                                   |
# | **shootPenaltyKick**           | integer  | 0                   | 패널티킥 슛 수                                     |
# | **goalPenaltyKick**            | integer  | 0                   | 패널티킥 골 수                                     |
#
# #### pass : 패스 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **passTry**                    | integer  | 92                  | 패스 시도 수                                       |
# | **passSuccess**                | integer  | 83                  | 패스 성공 수                                       |
# | **shortPassTry**               | integer  | 55                  | 숏 패스 시도 수                                    |
# | **shortPassSuccess**           | integer  | 55                  | 숏 패스 성공 수                                    |
# | **longPassTry**                | integer  | 3                   | 롱 패스 시도 수                                    |
# | **longPassSuccess**            | integer  | 3                   | 롱 패스 성공 수                                    |
# | **bouncingLobPassTry**         | integer  | 1                   | 바운싱 롭 패스 시도 수                             |
# | **bouncingLobPassSuccess**     | integer  | 0                   | 바운싱 롭 패스 성공 수                             |
# | **drivenGroundPassTry**        | integer  | 10                  | 드리븐 땅볼 패스 시도 수                           |
# | **drivenGroundPassSuccess**    | integer  | 10                  | 드리븐 땅볼 패스 성공 수                           |
# | **throughPassTry**             | integer  | 19                  | 스루 패스 시도 수                                  |
# | **throughPassSuccess**         | integer  | 14                  | 스루 패스 성공 수                                  |
# | **lobbedThroughPassTry**       | integer  | 4                   | 로빙 스루 패스 시도 수                             |
# | **lobbedThroughPassSuccess**   | integer  | 1                   | 로빙 스루 패스 성공 수                             |
#
# #### defence : 수비 정보
#
# | 필드명                     | 타입       | 예시                      | 설명                                               |
# |----------------------------|------------|---------------------------|----------------------------------------------------|
# | **blockTry**                  | integer  | 3                   | 블락 시도 수                                       |
# | **blockSuccess**              | integer  | 0                   | 블락 성공 수                                       |
# | **tackleTry**                 | integer  | 11                  | 태클 시도 수                                       |
# | **tackleSuccess**             | integer  | 9                   | 태클 성공 수                                       |

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 데이터 분석 환경 조성

# %% [markdown]
# ### 라이브러리 호출

# %%
import requests
import pandas as pd

# %% [markdown]
# ### 매치 메타데이터 확인
# - 매치 타입 확인

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/static/fconline/meta/matchtype.json"
response = requests.get(urlString, headers = headers)

match_type = response.json()
match_type
# Out:
# [{'matchtype': 30, 'desc': '리그 친선'},
#  {'matchtype': 40, 'desc': '클래식 1on1'},
#  {'matchtype': 50, 'desc': '공식경기'},
#  {'matchtype': 52, 'desc': '감독모드'},
#  {'matchtype': 60, 'desc': '공식 친선'},
#  {'matchtype': 204, 'desc': '볼타 친선'},
#  {'matchtype': 214, 'desc': '볼타 공식'},
#  {'matchtype': 224, 'desc': '볼타 AI대전'},
#  {'matchtype': 234, 'desc': '볼타 커스텀'}]

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 데이터 프레임 생성

# %% [markdown]
# ### 1) 내 매치 기록

# %% [markdown]
# - 계정 식별자 정보 저장
#     - 추후 다른 데이터와의 연결 고리 역할 수행
#     - ouid = `56f931578b228109e8e44599da41ea64`

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}
  
characterName = "Ithas"
urlString = "https://open.api.nexon.com/fconline/v1/id?nickname=" + characterName
response = requests.get(urlString, headers = headers)

ouid = response.json()['ouid']
ouid
# Out:
# '56f931578b228109e8e44599da41ea64'

# %% [markdown]
# #### ㄴ 매치 ID 리스트 생성
# - 매치 상세 정보를 조회하는 API에 연동하기 위해 매치 ID 리스트 생성

# %%
# 매치 기록 조회(최근 매치 ID 리스트 생성)
urlString = "https://open.api.nexon.com/fconline/v1/user/match?ouid=56f931578b228109e8e44599da41ea64&matchtype=50&offset=0&limit=100"
response = requests.get(urlString, headers = headers)

# 매치 ID 리스트 생성
match_id_list = response.json()
match_id_list
# Out:
# ['67e141ab64bc4aadd4478f83',
#  '67e13eb6178c8e338ece2279',
#  '67e13c081041581f21b29426',
#  '67e13959aa13375901b07450',
#  '67e11d51d56b0f431020a326',
#  '67e115e2d31f25263ab3e538',
#  '67e11349b6764f2767dbbd64',
#  '67e110769c505b95184aa6e8',
#  '67e10dd5556da0916f3eb359',
#  '67dfedbd5315c6036c5ffb04',
#  '67dfecd36f1f400054c67cc7',
#  '67dfe8820d8347e2847e0e76',
#  '67dfe4e05b2baccd90a79566',
#  '67dfe1f9b5f1228c927f8d7b',
#  '67dfde8d027d0a782967f2dd',
#  '67dfdbd7c3b20515db2b2aaa',
#  '67dfd91e6950fe6c38f73dbd',
#  '67dfd655a90c32a27f4a1e0f',
#  '67dd8645ec70212298a55f7b',
#  '67dd8231dda981e2e4199dc0',
#  '67dd7e67c75c081c46ba90c3',
#  '67dd7b7c4f01878ae65bd76c',
#  '67dd78c9c3d42c6d9d886176',
#  '67dd7510b36edd0a5199b8de',
#  '67dd721c8afaaf18c7574daa',
#  '67dd6f48b23c74d8fd8b11d7',
#  '67dd6cc0632b415e80a9d58d',
#  '67dd6a476fb2bd6b95c4b63d',
#  '67dd67a24be0a1e397cec6dd',
#  '67dd650053e5e88154781b92',
#  '67dd625e1c27c154b533a0aa',
#  '67bde18ff7a57a50de59824f',
#  '67bddedacb7a0585fb3ec221',
#  '67bddc42b13d371b1b6b8499',
#  '67bdd9e2b4a4bc70f6b06af4']

# %%
# 내 경기 수
len(match_id_list)
# Out:
# 35

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
match_info_list = []
for match_id in match_id_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    match_info_list.append(res.json())

# 예시) 매치ID별 정보
match_info_list[0]
# Out:
# {'matchId': '67e141ab64bc4aadd4478f83',
#  'matchDate': '2025-03-24T11:38:04',
#  'matchType': 50,
#  'matchInfo': [{'ouid': 'fa8be989d0f8fbacaa293443a221b3fc',
#    'nickname': '찬다웅',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 1,
#     'injury': 1,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 49,
#     'cornerKick': 0,
#     'possession': 44,
#     'offsideCount': 1,
#     'averageRating': 3.82222,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 6,
#     'effectiveShootTotal': 4,
#     'shootOutScore': 0,
#     'goalTotal': 2,
#     'goalTotalDisplay': 2,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 4,
#     'goalInPenalty': 2,
#     'shootOutPenalty': 2,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 16778105,
#      'x': 0.9521086812019348,
#      'y': 0.6046735644340515,
#      'type': 3,
#      'result': 2,
#      'spId': 834254117,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1408,
#      'x': 0.8086860179901123,
#      'y': 0.6115779280662537,
#      'type': 2,
#      'result': 2,
#      'spId': 832212194,
#      'spGrade': 6,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 810235407,
#      'assistX': 0.6164281368255615,
#      'assistY': 0.4460323452949524,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16779651,
#      'x': 0.9101253151893616,
#      'y': 0.4708092212677,
#      'type': 7,
#      'result': 3,
#      'spId': 834254117,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 832212194,
#      'assistX': 0.87935322523117,
#      'assistY': 0.8643362522125244,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 831,
#      'x': 0.7497872114181519,
#      'y': 0.4324584901332855,
#      'type': 2,
#      'result': 1,
#      'spId': 834208333,
#      'spGrade': 6,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 834254117,
#      'assistX': 0.7368708252906799,
#      'assistY': 0.2957808375358582,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 930,
#      'x': 0.9559276700019836,
#      'y': 0.5762901902198792,
#      'type': 7,
#      'result': 3,
#      'spId': 810235407,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 832212194,
#      'assistX': 0.9588041305541992,
#      'assistY': 0.9505997300148,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2019,
#      'x': 0.8934243321418762,
#      'y': 0.3477032482624054,
#      'type': 2,
#      'result': 1,
#      'spId': 834254117,
#      'spGrade': 7,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 834208333,
#      'assistX': 0.4409863650798798,
#      'assistY': 0.4038897752761841,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 72,
#     'passSuccess': 65,
#     'shortPassTry': 42,
#     'shortPassSuccess': 42,
#     'longPassTry': 6,
#     'longPassSuccess': 3,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 0,
#     'drivenGroundPassSuccess': 0,
#     'throughPassTry': 24,
#     'throughPassSuccess': 20,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 10,
#     'blockSuccess': 1,
#     'tackleTry': 10,
#     'tackleSuccess': 7},
#    'player': [{'spId': 810251852,
#      'spPosition': 28,
#      'spGrade': 2,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 834224196,
#      'spPosition': 7,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 159,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 5,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 4.6}},
#     {'spId': 834208333,
#      'spPosition': 11,
#      'spGrade': 6,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 247,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 11,
#       'passSuccess': 10,
#       'dribbleTry': 7,
#       'dribbleSuccess': 7,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 3,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.7}},
#     {'spId': 821214622,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 280235073,
#      'spPosition': 0,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 6,
#       'passTry': 5,
#       'passSuccess': 5,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 3,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.3}},
#     {'spId': 832212194,
#      'spPosition': 12,
#      'spGrade': 6,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 2,
#       'goal': 0,
#       'dribble': 235,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 8,
#       'passSuccess': 7,
#       'dribbleTry': 8,
#       'dribbleSuccess': 8,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.0}},
#     {'spId': 834266032,
#      'spPosition': 16,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 219,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 5,
#       'passSuccess': 3,
#       'dribbleTry': 7,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.4}},
#     {'spId': 810212190,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 82,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 2,
#       'passSuccess': 2,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.6}},
#     {'spId': 829188350,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 834246863,
#      'spPosition': 4,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 7,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 4.4}},
#     {'spId': 832215441,
#      'spPosition': 26,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 360,
#       'intercept': 2,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 10,
#       'dribbleTry': 6,
#       'dribbleSuccess': 5,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 3,
#       'tackle': 2,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.0}},
#     {'spId': 814204923,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 834254117,
#      'spPosition': 24,
#      'spGrade': 7,
#      'status': {'shoot': 3,
#       'effectiveShoot': 2,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 183,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 6,
#       'dribbleTry': 5,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.2}},
#     {'spId': 834247819,
#      'spPosition': 6,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 19,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 3,
#       'dribbleSuccess': 3,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 5,
#       'block': 1,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.6}},
#     {'spId': 834229891,
#      'spPosition': 28,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 291190765,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 810235407,
#      'spPosition': 9,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 67,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 10,
#       'dribbleTry': 6,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.0}},
#     {'spId': 251209889,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}}]},
#   {'ouid': '56f931578b228109e8e44599da41ea64',
#    'nickname': 'Ithas',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '승',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 1,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 1,
#     'dribble': 81,
#     'cornerKick': 2,
#     'possession': 56,
#     'offsideCount': 0,
#     'averageRating': 4.19444,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 11,
#     'effectiveShootTotal': 7,
#     'shootOutScore': 0,
#     'goalTotal': 3,
#     'goalTotalDisplay': 3,
#     'ownGoal': 0,
#     'shootHeading': 1,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 8,
#     'goalInPenalty': 3,
#     'shootOutPenalty': 2,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 1,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 16778377,
#      'x': 0.9010558128356934,
#      'y': 0.4096851646900177,
#      'type': 3,
#      'result': 1,
#      'spId': 256001109,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2314,
#      'x': 0.8680596947669983,
#      'y': 0.5811111927032471,
#      'type': 2,
#      'result': 2,
#      'spId': 256192985,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.7359421849250793,
#      'assistY': 0.5478948950767517,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2910,
#      'x': 0.9013468623161316,
#      'y': 0.5022931098937988,
#      'type': 9,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778314,
#      'x': 0.81451803445816,
#      'y': 0.630556583404541,
#      'type': 1,
#      'result': 1,
#      'spId': 256192985,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.7482479810714722,
#      'assistY': 0.4701201617717743,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 2972,
#      'x': 0.9483369588851928,
#      'y': 0.6085435748100281,
#      'type': 3,
#      'result': 2,
#      'spId': 256140601,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1135,
#      'x': 0.8276865482330322,
#      'y': 0.6466019153594971,
#      'type': 2,
#      'result': 2,
#      'spId': 256004231,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.8059658408164978,
#      'assistY': 0.595585286617279,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 267,
#      'x': 0.8911388516426086,
#      'y': 0.642644464969635,
#      'type': 1,
#      'result': 2,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': False,
#      'assistSpId': -1,
#      'assistX': 0.5,
#      'assistY': 0.5,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1611,
#      'x': 0.8906282782554626,
#      'y': 0.45449498295784,
#      'type': 6,
#      'result': 3,
#      'spId': 256001075,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256242519,
#      'assistX': 0.7615824341773987,
#      'assistY': 0.6278156638145447,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 2379,
#      'x': 0.9103581309318542,
#      'y': 0.5476651787757874,
#      'type': 6,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256192985,
#      'assistX': 0.7877718806266785,
#      'assistY': 0.452631413936615,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16777684,
#      'x': 0.9021827578544616,
#      'y': 0.3963459730148315,
#      'type': 6,
#      'result': 3,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256004833,
#      'assistX': 0.7764451503753662,
#      'assistY': 0.1470654159784317,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779304,
#      'x': 0.94808954000473,
#      'y': 0.626690149307251,
#      'type': 6,
#      'result': 1,
#      'spId': 256242519,
#      'spGrade': 8,
#      'spLevel': 5,
#      'spIdType': True,
#      'assist': True,
#      'assistSpId': 256001075,
#      'assistX': 0.5196987390518188,
#      'assistY': 0.6585849523544312,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 109,
#     'passSuccess': 104,
#     'shortPassTry': 86,
#     'shortPassSuccess': 83,
#     'longPassTry': 2,
#     'longPassSuccess': 2,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 4,
#     'drivenGroundPassSuccess': 4,
#     'throughPassTry': 16,
#     'throughPassSuccess': 14,
#     'lobbedThroughPassTry': 1,
#     'lobbedThroughPassSuccess': 1},
#    'defence': {'blockTry': 7,
#     'blockSuccess': 0,
#     'tackleTry': 5,
#     'tackleSuccess': 1},
#    'player': [{'spId': 274000250,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256215914,
#      'spPosition': 10,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 204,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 11,
#       'passSuccess': 11,
#       'dribbleTry': 7,
#       'dribbleSuccess': 6,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 1,
#       'redCards': 0,
#       'spRating': 6.2}},
#     {'spId': 253188377,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256140601,
#      'spPosition': 6,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 4,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 1,
#       'aerialSuccess': 1,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.9}},
#     {'spId': 268192181,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256001109,
#      'spPosition': 7,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 38,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 1,
#       'aerialSuccess': 1,
#       'blockTry': 1,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.8}},
#     {'spId': 256001041,
#      'spPosition': 3,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 118,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 10,
#       'passSuccess': 10,
#       'dribbleTry': 8,
#       'dribbleSuccess': 8,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 4,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.3}},
#     {'spId': 256007289,
#      'spPosition': 4,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 34,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 2,
#       'dribbleSuccess': 2,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 2,
#       'aerialTry': 3,
#       'aerialSuccess': 0,
#       'blockTry': 3,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 5.9}},
#     {'spId': 256004833,
#      'spPosition': 27,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 191,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 6,
#       'passSuccess': 4,
#       'dribbleTry': 6,
#       'dribbleSuccess': 4,
#       'ballPossesionTry': 5,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 2,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.5}},
#     {'spId': 256001075,
#      'spPosition': 19,
#      'spGrade': 8,
#      'status': {'shoot': 2,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 428,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 18,
#       'passSuccess': 17,
#       'dribbleTry': 16,
#       'dribbleSuccess': 15,
#       'ballPossesionTry': 4,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 8.0}},
#     {'spId': 256242519,
#      'spPosition': 25,
#      'spGrade': 8,
#      'status': {'shoot': 4,
#       'effectiveShoot': 4,
#       'assist': 1,
#       'goal': 2,
#       'dribble': 597,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 16,
#       'passSuccess': 16,
#       'dribbleTry': 15,
#       'dribbleSuccess': 15,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 9.9}},
#     {'spId': 251005099,
#      'spPosition': 28,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256004231,
#      'spPosition': 23,
#      'spGrade': 8,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 200,
#       'intercept': 1,
#       'defending': 0,
#       'passTry': 14,
#       'passSuccess': 13,
#       'dribbleTry': 10,
#       'dribbleSuccess': 10,
#       'ballPossesionTry': 3,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 1,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 1,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.8}},
#     {'spId': 289261593,
#      'spPosition': 28,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256192985,
#      'spPosition': 13,
#      'spGrade': 8,
#      'status': {'shoot': 2,
#       'effectiveShoot': 1,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 496,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 15,
#       'passSuccess': 14,
#       'dribbleTry': 13,
#       'dribbleSuccess': 12,
#       'ballPossesionTry': 2,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 1,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 7.5}},
#     {'spId': 256214098,
#      'spPosition': 28,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 234192119,
#      'spPosition': 28,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 0,
#       'ballPossesionSuccess': 0,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 0.0}},
#     {'spId': 256051539,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'intercept': 0,
#       'defending': 3,
#       'passTry': 4,
#       'passSuccess': 4,
#       'dribbleTry': 0,
#       'dribbleSuccess': 0,
#       'ballPossesionTry': 1,
#       'ballPossesionSuccess': 1,
#       'aerialTry': 0,
#       'aerialSuccess': 0,
#       'blockTry': 0,
#       'block': 0,
#       'tackleTry': 0,
#       'tackle': 0,
#       'yellowCards': 0,
#       'redCards': 0,
#       'spRating': 6.7}}]}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "matchEndType","foul", "injury", 
    "redCards", "yellowCards","possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "matchEndType": match_detail['matchEndType'],
                    "foul": match_detail['foul'],
                    "injury": match_detail['injury'],
                    "redCards": match_detail['redCards'],
                    "yellowCards": match_detail['yellowCards'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_63435/3420171123.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   match_df = pd.concat([match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67e141ab64bc4aadd4478f83  2025-03-24T11:38:04        50
# 1  67e141ab64bc4aadd4478f83  2025-03-24T11:38:04        50
# 2  67e141ab64bc4aadd4478f83  2025-03-24T11:38:04        50
# 3  67e141ab64bc4aadd4478f83  2025-03-24T11:38:04        50
# 4  67e141ab64bc4aadd4478f83  2025-03-24T11:38:04        50
#
#                                ouid nickname matchResult matchEndType foul  \
# 0  fa8be989d0f8fbacaa293443a221b3fc      찬다웅           패            0    1
# 1  fa8be989d0f8fbacaa293443a221b3fc      찬다웅           패            0    1
# 2  fa8be989d0f8fbacaa293443a221b3fc      찬다웅           패            0    1
# 3  fa8be989d0f8fbacaa293443a221b3fc      찬다웅           패            0    1
# 4  fa8be989d0f8fbacaa293443a221b3fc      찬다웅           패            0    1
#
#   injury redCards  ...  goalTime         x         y type result       spId  \
# 0      1        0  ...  16778105  0.952109  0.604674    3      2  834254117
# 1      1        0  ...      1408  0.808686  0.611578    2      2  832212194
# 2      1        0  ...  16779651  0.910125  0.470809    7      3  834254117
# 3      1        0  ...       831  0.749787  0.432458    2      1  834208333
# 4      1        0  ...       930  0.955928  0.576290    7      3  810235407
#
#   assist assistSpId hitPost inPenalty
# 0  False         -1   False      True
# 1   True  810235407   False     False
# 2   True  832212194   False      True
# 3   True  834254117   False     False
# 4   True  832212194   False      True
#
# [5 rows x 43 columns]

# %%
match_df.T
# Out:
#                                                   0    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 fa8be989d0f8fbacaa293443a221b3fc
# nickname                                          찬다웅
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              1
# redCards                                            0
# yellowCards                                         0
# possession                                         44
# averageRating                                 3.82222
# dribble                                            49
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            72
# passSuccess                                        65
# shortPassTry                                       42
# shortPassSuccess                                   42
# longPassTry                                         6
# longPassSuccess                                     3
# throughPassTry                                     24
# throughPassSuccess                                 20
# tackleTry                                          10
# tackleSuccess                                       7
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                     16778105
# x                                            0.952109
# y                                            0.604674
# type                                                3
# result                                              2
# spId                                        834254117
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   1    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 fa8be989d0f8fbacaa293443a221b3fc
# nickname                                          찬다웅
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              1
# redCards                                            0
# yellowCards                                         0
# possession                                         44
# averageRating                                 3.82222
# dribble                                            49
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            72
# passSuccess                                        65
# shortPassTry                                       42
# shortPassSuccess                                   42
# longPassTry                                         6
# longPassSuccess                                     3
# throughPassTry                                     24
# throughPassSuccess                                 20
# tackleTry                                          10
# tackleSuccess                                       7
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                         1408
# x                                            0.808686
# y                                            0.611578
# type                                                2
# result                                              2
# spId                                        832212194
# assist                                           True
# assistSpId                                  810235407
# hitPost                                         False
# inPenalty                                       False
#
#                                                   2    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 fa8be989d0f8fbacaa293443a221b3fc
# nickname                                          찬다웅
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              1
# redCards                                            0
# yellowCards                                         0
# possession                                         44
# averageRating                                 3.82222
# dribble                                            49
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            72
# passSuccess                                        65
# shortPassTry                                       42
# shortPassSuccess                                   42
# longPassTry                                         6
# longPassSuccess                                     3
# throughPassTry                                     24
# throughPassSuccess                                 20
# tackleTry                                          10
# tackleSuccess                                       7
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                     16779651
# x                                            0.910125
# y                                            0.470809
# type                                                7
# result                                              3
# spId                                        834254117
# assist                                           True
# assistSpId                                  832212194
# hitPost                                         False
# inPenalty                                        True
#
#                                                   3    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 fa8be989d0f8fbacaa293443a221b3fc
# nickname                                          찬다웅
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              1
# redCards                                            0
# yellowCards                                         0
# possession                                         44
# averageRating                                 3.82222
# dribble                                            49
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            72
# passSuccess                                        65
# shortPassTry                                       42
# shortPassSuccess                                   42
# longPassTry                                         6
# longPassSuccess                                     3
# throughPassTry                                     24
# throughPassSuccess                                 20
# tackleTry                                          10
# tackleSuccess                                       7
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                          831
# x                                            0.749787
# y                                            0.432458
# type                                                2
# result                                              1
# spId                                        834208333
# assist                                           True
# assistSpId                                  834254117
# hitPost                                         False
# inPenalty                                       False
#
#                                                   4    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 fa8be989d0f8fbacaa293443a221b3fc
# nickname                                          찬다웅
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              1
# redCards                                            0
# yellowCards                                         0
# possession                                         44
# averageRating                                 3.82222
# dribble                                            49
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            72
# passSuccess                                        65
# shortPassTry                                       42
# shortPassSuccess                                   42
# longPassTry                                         6
# longPassSuccess                                     3
# throughPassTry                                     24
# throughPassSuccess                                 20
# tackleTry                                          10
# tackleSuccess                                       7
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                          930
# x                                            0.955928
# y                                             0.57629
# type                                                7
# result                                              3
# spId                                        810235407
# assist                                           True
# assistSpId                                  832212194
# hitPost                                         False
# inPenalty                                        True
#
#                                                   5    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 fa8be989d0f8fbacaa293443a221b3fc
# nickname                                          찬다웅
# matchResult                                         패
# matchEndType                                        0
# foul                                                1
# injury                                              1
# redCards                                            0
# yellowCards                                         0
# possession                                         44
# averageRating                                 3.82222
# dribble                                            49
# cornerKick                                          0
# offsideCount                                        1
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            72
# passSuccess                                        65
# shortPassTry                                       42
# shortPassSuccess                                   42
# longPassTry                                         6
# longPassSuccess                                     3
# throughPassTry                                     24
# throughPassSuccess                                 20
# tackleTry                                          10
# tackleSuccess                                       7
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                         2019
# x                                            0.893424
# y                                            0.347703
# type                                                2
# result                                              1
# spId                                        834254117
# assist                                           True
# assistSpId                                  834208333
# hitPost                                         False
# inPenalty                                        True
#
#                                                   6    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         56
# averageRating                                 4.19444
# dribble                                            81
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 7
# goalTotal                                           3
# shootPenaltyKick                                    1
# goalPenaltyKick                                     0
# passTry                                           109
# passSuccess                                       104
# shortPassTry                                       86
# shortPassSuccess                                   83
# longPassTry                                         2
# longPassSuccess                                     2
# throughPassTry                                     16
# throughPassSuccess                                 14
# tackleTry                                           5
# tackleSuccess                                       1
# blockTry                                            7
# blockSuccess                                        0
# goalTime                                     16778377
# x                                            0.901056
# y                                            0.409685
# type                                                3
# result                                              1
# spId                                        256001109
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   7    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         56
# averageRating                                 4.19444
# dribble                                            81
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 7
# goalTotal                                           3
# shootPenaltyKick                                    1
# goalPenaltyKick                                     0
# passTry                                           109
# passSuccess                                       104
# shortPassTry                                       86
# shortPassSuccess                                   83
# longPassTry                                         2
# longPassSuccess                                     2
# throughPassTry                                     16
# throughPassSuccess                                 14
# tackleTry                                           5
# tackleSuccess                                       1
# blockTry                                            7
# blockSuccess                                        0
# goalTime                                         2314
# x                                             0.86806
# y                                            0.581111
# type                                                2
# result                                              2
# spId                                        256192985
# assist                                           True
# assistSpId                                  256001075
# hitPost                                         False
# inPenalty                                        True
#
#                                                   8    \
# matchId                      67e141ab64bc4aadd4478f83
# matchDate                         2025-03-24T11:38:04
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         승
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         56
# averageRating                                 4.19444
# dribble                                            81
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                         11
# effectiveShootTotal                                 7
# goalTotal                                           3
# shootPenaltyKick                                    1
# goalPenaltyKick                                     0
# passTry                                           109
# passSuccess                                       104
# shortPassTry                                       86
# shortPassSuccess                                   83
# longPassTry                                         2
# longPassSuccess                                     2
# throughPassTry                                     16
# throughPassSuccess                                 14
# tackleTry                                           5
# tackleSuccess                                       1
# blockTry                                            7
# blockSuccess                                        0
# goalTime                                         2910
# x                                            0.901347
# y                                            0.502293
# type                                                9
# result                                              1
# spId                                        256242519
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   9    ...  \
# matchId                      67e141ab64bc4aadd4478f83  ...
# matchDate                         2025-03-24T11:38:04  ...
# matchType                                          50  ...
# ouid                 56f931578b228109e8e44599da41ea64  ...
# nickname                                        Ithas  ...
# matchResult                                         승  ...
# matchEndType                                        0  ...
# foul                                                1  ...
# injury                                              0  ...
# redCards                                            0  ...
# yellowCards                                         1  ...
# possession                                         56  ...
# averageRating                                 4.19444  ...
# dribble                                            81  ...
# cornerKick                                          2  ...
# offsideCount                                        0  ...
# shootTotal                                         11  ...
# effectiveShootTotal                                 7  ...
# goalTotal                                           3  ...
# shootPenaltyKick                                    1  ...
# goalPenaltyKick                                     0  ...
# passTry                                           109  ...
# passSuccess                                       104  ...
# shortPassTry                                       86  ...
# shortPassSuccess                                   83  ...
# longPassTry                                         2  ...
# longPassSuccess                                     2  ...
# throughPassTry                                     16  ...
# throughPassSuccess                                 14  ...
# tackleTry                                           5  ...
# tackleSuccess                                       1  ...
# blockTry                                            7  ...
# blockSuccess                                        0  ...
# goalTime                                     16778314  ...
# x                                            0.814518  ...
# y                                            0.630557  ...
# type                                                1  ...
# result                                              1  ...
# spId                                        256192985  ...
# assist                                           True  ...
# assistSpId                                  256001075  ...
# hitPost                                         False  ...
# inPenalty                                       False  ...
#
#                                                   351  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 8803317932bd8e00c3269f1169576138
# nickname                                         오산이오
# matchResult                                         승
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         55
# averageRating                                 4.66111
# dribble                                            66
# cornerKick                                          1
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 5
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            78
# passSuccess                                        71
# shortPassTry                                       62
# shortPassSuccess                                   58
# longPassTry                                         3
# longPassSuccess                                     1
# throughPassTry                                      7
# throughPassSuccess                                  7
# tackleTry                                          12
# tackleSuccess                                       9
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                         1650
# x                                              0.9571
# y                                            0.403329
# type                                                3
# result                                              3
# spId                                        829209331
# assist                                           True
# assistSpId                                  233231281
# hitPost                                         False
# inPenalty                                        True
#
#                                                   352  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 8803317932bd8e00c3269f1169576138
# nickname                                         오산이오
# matchResult                                         승
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         55
# averageRating                                 4.66111
# dribble                                            66
# cornerKick                                          1
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 5
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            78
# passSuccess                                        71
# shortPassTry                                       62
# shortPassSuccess                                   58
# longPassTry                                         3
# longPassSuccess                                     1
# throughPassTry                                      7
# throughPassSuccess                                  7
# tackleTry                                          12
# tackleSuccess                                       9
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                          478
# x                                            0.811926
# y                                            0.521248
# type                                                2
# result                                              3
# spId                                        100013743
# assist                                           True
# assistSpId                                  829208722
# hitPost                                         False
# inPenalty                                       False
#
#                                                   353  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 8803317932bd8e00c3269f1169576138
# nickname                                         오산이오
# matchResult                                         승
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         55
# averageRating                                 4.66111
# dribble                                            66
# cornerKick                                          1
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 5
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            78
# passSuccess                                        71
# shortPassTry                                       62
# shortPassSuccess                                   58
# longPassTry                                         3
# longPassSuccess                                     1
# throughPassTry                                      7
# throughPassSuccess                                  7
# tackleTry                                          12
# tackleSuccess                                       9
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                     16779749
# x                                            0.789709
# y                                            0.341341
# type                                                8
# result                                              1
# spId                                        100013743
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                       False
#
#                                                   354  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 8803317932bd8e00c3269f1169576138
# nickname                                         오산이오
# matchResult                                         승
# matchEndType                                        0
# foul                                                1
# injury                                              0
# redCards                                            0
# yellowCards                                         0
# possession                                         55
# averageRating                                 4.66111
# dribble                                            66
# cornerKick                                          1
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 5
# goalTotal                                           4
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            78
# passSuccess                                        71
# shortPassTry                                       62
# shortPassSuccess                                   58
# longPassTry                                         3
# longPassSuccess                                     1
# throughPassTry                                      7
# throughPassSuccess                                  7
# tackleTry                                          12
# tackleSuccess                                       9
# blockTry                                           10
# blockSuccess                                        1
# goalTime                                          979
# x                                            0.874156
# y                                            0.547405
# type                                                2
# result                                              3
# spId                                        100013743
# assist                                           True
# assistSpId                                  829208722
# hitPost                                         False
# inPenalty                                        True
#
#                                                   355  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# matchEndType                                        0
# foul                                                2
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         45
# averageRating                                 3.73889
# dribble                                            62
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            85
# passSuccess                                        78
# shortPassTry                                       61
# shortPassSuccess                                   58
# longPassTry                                         5
# longPassSuccess                                     2
# throughPassTry                                     17
# throughPassSuccess                                 16
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            4
# blockSuccess                                        0
# goalTime                                          756
# x                                            0.856783
# y                                            0.491274
# type                                                2
# result                                              2
# spId                                        256215914
# assist                                           True
# assistSpId                                  256001109
# hitPost                                         False
# inPenalty                                        True
#
#                                                   356  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# matchEndType                                        0
# foul                                                2
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         45
# averageRating                                 3.73889
# dribble                                            62
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            85
# passSuccess                                        78
# shortPassTry                                       61
# shortPassSuccess                                   58
# longPassTry                                         5
# longPassSuccess                                     2
# throughPassTry                                     17
# throughPassSuccess                                 16
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            4
# blockSuccess                                        0
# goalTime                                         1307
# x                                            0.879667
# y                                            0.390619
# type                                                2
# result                                              3
# spId                                        256001075
# assist                                           True
# assistSpId                                  256004833
# hitPost                                         False
# inPenalty                                        True
#
#                                                   357  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# matchEndType                                        0
# foul                                                2
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         45
# averageRating                                 3.73889
# dribble                                            62
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            85
# passSuccess                                        78
# shortPassTry                                       61
# shortPassSuccess                                   58
# longPassTry                                         5
# longPassSuccess                                     2
# throughPassTry                                     17
# throughPassSuccess                                 16
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            4
# blockSuccess                                        0
# goalTime                                     16778484
# x                                            0.830621
# y                                            0.577803
# type                                                1
# result                                              1
# spId                                        256001075
# assist                                           True
# assistSpId                                  256001041
# hitPost                                         False
# inPenalty                                       False
#
#                                                   358  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# matchEndType                                        0
# foul                                                2
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         45
# averageRating                                 3.73889
# dribble                                            62
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            85
# passSuccess                                        78
# shortPassTry                                       61
# shortPassSuccess                                   58
# longPassTry                                         5
# longPassSuccess                                     2
# throughPassTry                                     17
# throughPassSuccess                                 16
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            4
# blockSuccess                                        0
# goalTime                                     16778548
# x                                            0.944943
# y                                            0.544876
# type                                                3
# result                                              2
# spId                                        256140601
# assist                                          False
# assistSpId                                         -1
# hitPost                                          True
# inPenalty                                        True
#
#                                                   359  \
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# matchEndType                                        0
# foul                                                2
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         45
# averageRating                                 3.73889
# dribble                                            62
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            85
# passSuccess                                        78
# shortPassTry                                       61
# shortPassSuccess                                   58
# longPassTry                                         5
# longPassSuccess                                     2
# throughPassTry                                     17
# throughPassSuccess                                 16
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            4
# blockSuccess                                        0
# goalTime                                     16778662
# x                                            0.861035
# y                                            0.515926
# type                                                2
# result                                              1
# spId                                        256001075
# assist                                          False
# assistSpId                                         -1
# hitPost                                         False
# inPenalty                                        True
#
#                                                   360
# matchId                      67bddedacb7a0585fb3ec221
# matchDate                         2025-02-25T15:28:01
# matchType                                          50
# ouid                 56f931578b228109e8e44599da41ea64
# nickname                                        Ithas
# matchResult                                         패
# matchEndType                                        0
# foul                                                2
# injury                                              0
# redCards                                            0
# yellowCards                                         1
# possession                                         45
# averageRating                                 3.73889
# dribble                                            62
# cornerKick                                          2
# offsideCount                                        0
# shootTotal                                          6
# effectiveShootTotal                                 4
# goalTotal                                           2
# shootPenaltyKick                                    0
# goalPenaltyKick                                     0
# passTry                                            85
# passSuccess                                        78
# shortPassTry                                       61
# shortPassSuccess                                   58
# longPassTry                                         5
# longPassSuccess                                     2
# throughPassTry                                     17
# throughPassSuccess                                 16
# tackleTry                                           5
# tackleSuccess                                       3
# blockTry                                            4
# blockSuccess                                        0
# goalTime                                     16779214
# x                                            0.966523
# y                                            0.404314
# type                                                6
# result                                              3
# spId                                        256242519
# assist                                           True
# assistSpId                                  256001075
# hitPost                                         False
# inPenalty                                        True
#
# [43 rows x 361 columns]

# %% [markdown]
# ### 2) 최근 100경기 매치 기록(전체 유저)
# - 내 기록과 비교 분석할 전체 유저의 최근 100경기 매치 기록 불러오기
# - 공식경기 기준 100경기

# %% [markdown]
# #### ㄴ 최근 100경기 매치 ID 불러오기

# %%
# 계정식별자 정보 저장
headers = {"x-nxopen-api-key":"test_7cd2e08122133d0d9ea57e25d2e9b09bf44a7923e6320194590a02860a7bf66befe8d04e6d233bd35cf2fabdeb93fb0d"}

urlString = "https://open.api.nexon.com/fconline/v1/match?matchtype=50&offset=0&limit=100&orderby=desc"
response = requests.get(urlString, headers = headers)

all_match_list = response.json()
print(len(all_match_list))
all_match_list
# Out:
# 100
# ['67e1f1cc6698f1f8545961d4',
#  '67e1f18d273fbc4a46b37f9b',
#  '67e1f15aa71a9c63f4671b05',
#  '67e1f10dbec0e67a022657ea',
#  '67e1f1017f5021c485400a6f',
#  '67e1f0e21c978d33ea295ae5',
#  '67e1f0de00c4746bd495b9e0',
#  '67e1f0cd2047008dd0344975',
#  '67e1f0c353aeb729cc75090f',
#  '67e1f0becd754df3a2348cdc',
#  '67e1f0b3ca88e8846be8d2a8',
#  '67e1f096ba4ee7ed32238778',
#  '67e1f09128139cdc7a5d5d02',
#  '67e1f08d916d186f80f26b50',
#  '67e1f089b664cfb2ee6133c0',
#  '67e1f07f3555a4c1c62a54af',
#  '67e1f0781e0445a016f68056',
#  '67e1f06ba83590dc7cfaa2f8',
#  '67e1f064958fc1991db7c970',
#  '67e1f050bd883cc52729781b',
#  '67e1f0491b82bf46533122ab',
#  '67e1f03dcc4cb8c795c71174',
#  '67e1f03a1d28482f47c88aca',
#  '67e1f038090feb06ebe85645',
#  '67e1f033f61727887b3b09fc',
#  '67e1f02ef74d817d892455a0',
#  '67e1f02b851467210248f1a7',
#  '67e1f011dda8af859a61a0b4',
#  '67e1f00c6a12a106891b70fe',
#  '67e1f0025a1dd040492eed71',
#  '67e1eff420387ea424fcdd00',
#  '67e1efe6d92366508573fe1f',
#  '67e1efe3be6858b8b9cadb97',
#  '67e1efd9eb4ad97aba438b9b',
#  '67e1efd781dec52ebf992ea3',
#  '67e1efcc9d5c820a9a5ec2bb',
#  '67e1efc957c69f49df7b6a60',
#  '67e1efc62348936dfec17312',
#  '67e1efc58a8c277b69b3cba1',
#  '67e1efc43dd1ff19d9602341',
#  '67e1efc2f6c5d07336c4f711',
#  '67e1efbbebbdac28a9452ebe',
#  '67e1efb2e0e26607e3be5ac7',
#  '67e1efa4ffc153fd6da558c2',
#  '67e1efa18d2e905486bb5b18',
#  '67e1ef9f6353a0213eb98e7a',
#  '67e1ef95bdeb9682a8a444e4',
#  '67e1ef92eb70eb4f0771fcca',
#  '67e1ef922c87eabd1bc08a3e',
#  '67e1ef920a1a29e282819b91',
#  '67e1ef90c00e42e7b7d0677d',
#  '67e1ef8dda625a2013813943',
#  '67e1ef8b3d7cad5650a245c6',
#  '67e1ef8a19839552b1a85df7',
#  '67e1ef878ba473824d819ffe',
#  '67e1ef86163b687c0a430aeb',
#  '67e1ef82b4257ba104cdcc54',
#  '67e1ef8199a968ddc164e4be',
#  '67e1ef7f018449304ea71627',
#  '67e1ef7eace3ab84268a1e55',
#  '67e1ef7c820b149a9f03f5d8',
#  '67e1ef7be28db14777a5bf15',
#  '67e1ef7ba5f5bcc0ef60d3a7',
#  '67e1ef7a85abcc1756dc7666',
#  '67e1ef76d0bddc9c8d609a10',
#  '67e1ef74f3a2f3fdbe3d909f',
#  '67e1ef7473f5a22dfa302618',
#  '67e1ef73b8a14ed6c00c8e0a',
#  '67e1ef72635cc26c3532eef8',
#  '67e1ef6ff1f8be174fe09d7b',
#  '67e1ef6fc7ec26212c23d110',
#  '67e1ef6ee0f2a2ebcf1f073a',
#  '67e1ef6d86109384aa84188a',
#  '67e1ef6c4e1eaf7a7cb02805',
#  '67e1ef6ae21e5eb6743620c3',
#  '67e1ef68e45621eac0f7cfe1',
#  '67e1ef68a13b9efa67a0b813',
#  '67e1ef6648d69f96ef59281b',
#  '67e1ef66266857429aa0f097',
#  '67e1ef655a27a74ae2092737',
#  '67e1ef653ead7649c47f423e',
#  '67e1ef64f705b4f9e20683d7',
#  '67e1ef64cc02554042e95d9d',
#  '67e1ef647245b8f3f127248a',
#  '67e1ef62333f983773973e62',
#  '67e1ef603193643d0d674a6e',
#  '67e1ef5fdc7ce53719460578',
#  '67e1ef5f7f841e1d9b78f65b',
#  '67e1ef5e65e05c0f4d697aab',
#  '67e1ef5b89c1ef376787c154',
#  '67e1ef5a85d4d418ba65e94a',
#  '67e1ef57ecb05550f80fe181',
#  '67e1ef5778170a26822ddd67',
#  '67e1ef55c20294fff2bceef0',
#  '67e1ef54c9355af27ece6b91',
#  '67e1ef5251948855f7992228',
#  '67e1ef5234834498a3e4be48',
#  '67e1ef51ac1032f65a9abdf7',
#  '67e1ef510ffca83fc2141476',
#  '67e1ef500fa3bd5cce9ef3e4']

# %% [markdown]
# #### ㄴ 매치 ID로 매치 상세 기록 조회

# %%
# 매치 상세 기록 조회
all_match_info_list = []
for match_id in all_match_list:
    urlString = f"https://open.api.nexon.com/fconline/v1/match-detail?matchid={match_id}"

    res = requests.get(urlString, headers = headers)
    all_match_info_list.append(res.json())

# 예시) 매치ID별 정보
all_match_info_list[0]
# Out:
# {'matchId': '67e1f1cc6698f1f8545961d4',
#  'matchDate': '2025-03-24T23:59:37',
#  'matchType': 50,
#  'matchInfo': [{'ouid': 'c17c60aea6c71eeb5d51ba2e0f309ed5',
#    'nickname': '표준서띠',
#    'matchDetail': {'seasonId': 202502,
#     'matchResult': '패',
#     'matchEndType': 2,
#     'systemPause': None,
#     'foul': None,
#     'injury': None,
#     'redCards': None,
#     'yellowCards': None,
#     'dribble': None,
#     'cornerKick': None,
#     'possession': None,
#     'offsideCount': None,
#     'averageRating': None,
#     'controller': None},
#    'shoot': {'shootTotal': None,
#     'effectiveShootTotal': None,
#     'shootOutScore': None,
#     'goalTotal': None,
#     'goalTotalDisplay': 0,
#     'ownGoal': None,
#     'shootHeading': None,
#     'goalHeading': None,
#     'shootFreekick': None,
#     'goalFreekick': None,
#     'shootInPenalty': None,
#     'goalInPenalty': None,
#     'shootOutPenalty': None,
#     'goalOutPenalty': None,
#     'shootPenaltyKick': None,
#     'goalPenaltyKick': None},
#    'shootDetail': [],
#    'pass': {'passTry': None,
#     'passSuccess': None,
#     'shortPassTry': None,
#     'shortPassSuccess': None,
#     'longPassTry': None,
#     'longPassSuccess': None,
#     'bouncingLobPassTry': None,
#     'bouncingLobPassSuccess': None,
#     'drivenGroundPassTry': None,
#     'drivenGroundPassSuccess': None,
#     'throughPassTry': None,
#     'throughPassSuccess': None,
#     'lobbedThroughPassTry': None,
#     'lobbedThroughPassSuccess': None},
#    'defence': {'blockTry': None,
#     'blockSuccess': None,
#     'tackleTry': None,
#     'tackleSuccess': None},
#    'player': []}]}

# %% [markdown]
# #### ㄴ 데이터 프레임 생성
# - json 파일로 API 호출
# - json파일 기공하여 데이터프레임 생성
# - 골 관련 정보도 있기 때문에 ROW의 기준은 골이 된다.

# %%
# 필요한 데이터만 정리
columns = [
    'matchId','matchDate', 'matchType',"ouid","nickname", "matchResult", "matchEndType","foul", "injury", 
    "redCards", "yellowCards","possession", "averageRating", "dribble", "cornerKick", "offsideCount", 
    "shootTotal", "effectiveShootTotal", "goalTotal", "shootPenaltyKick", "goalPenaltyKick", 
    "passTry", "passSuccess", "shortPassTry", "shortPassSuccess", "longPassTry", "longPassSuccess", 
    "throughPassTry", "throughPassSuccess", "tackleTry", "tackleSuccess", "blockTry", "blockSuccess", 
    "goalTime", "x", "y", "type", "result", "spId", "assist", "assistSpId", "hitPost", "inPenalty"
]

all_match_df = pd.DataFrame(columns=columns)

# 주어진 데이터
for info in all_match_info_list:
    if 'error' in info.keys():
        pass
    else:
        match_info = info['matchInfo']

        data_list = []

        for player in match_info:
            match_detail = player['matchDetail']
            shoot = player['shoot']
            passing = player['pass']
            defence = player['defence']
            
            for shot in player.get('shootDetail', []):

                row = {
                    'matchId': info['matchId'],
                    'matchDate': info['matchDate'],
                    'matchType': info['matchType'],
                    "ouid": player['ouid'],
                    "nickname": player['nickname'],
                    "matchResult": match_detail['matchResult'],
                    "matchEndType": match_detail['matchEndType'],
                    "foul": match_detail['foul'],
                    "injury": match_detail['injury'],
                    "redCards": match_detail['redCards'],
                    "yellowCards": match_detail['yellowCards'],
                    "possession": match_detail['possession'],
                    "averageRating": match_detail['averageRating'],
                    "dribble": match_detail['dribble'],
                    "cornerKick": match_detail['cornerKick'],
                    "offsideCount": match_detail['offsideCount'],
                    "shootTotal": shoot['shootTotal'],
                    "effectiveShootTotal": shoot['effectiveShootTotal'],
                    "goalTotal": shoot['goalTotal'],
                    "shootPenaltyKick": shoot['shootPenaltyKick'],
                    "goalPenaltyKick": shoot['goalPenaltyKick'],
                    "passTry": passing['passTry'],
                    "passSuccess": passing['passSuccess'],
                    "shortPassTry": passing['shortPassTry'],
                    "shortPassSuccess": passing['shortPassSuccess'],
                    "longPassTry": passing['longPassTry'],
                    "longPassSuccess": passing['longPassSuccess'],
                    "throughPassTry": passing['throughPassTry'],
                    "throughPassSuccess": passing['throughPassSuccess'],
                    "tackleTry": defence['tackleTry'],
                    "tackleSuccess": defence['tackleSuccess'],
                    "blockTry": defence['blockTry'],
                    "blockSuccess": defence['blockSuccess'],
                    "goalTime": shot['goalTime'],
                    "x": shot['x'],
                    "y": shot['y'],
                    "type": shot['type'],
                    "result": shot['result'],
                    "spId": shot['spId'],
                    "assist": shot['assist'],
                    "assistSpId": shot['assistSpId'],
                    "hitPost": shot['hitPost'],
                    "inPenalty": shot['inPenalty']
                }
                
                data_list.append(row)

        # Pandas DataFrame 생성
        tmp_df = pd.DataFrame(data_list, columns=columns)
        
        all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)


# 데이터 출력
all_match_df.head()
# Out:
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_63435/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_63435/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_63435/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
# /var/folders/mh/6ldwbz7n2xx52pxqy8ys1c2r0000gp/T/ipykernel_63435/1222341392.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_match_df = pd.concat([all_match_df,tmp_df],axis=0, ignore_index=True)
#                     matchId            matchDate matchType  \
# 0  67e1f18d273fbc4a46b37f9b  2025-03-24T23:59:37        50
# 1  67e1f1017f5021c485400a6f  2025-03-24T23:58:01        50
# 2  67e1f1017f5021c485400a6f  2025-03-24T23:58:01        50
# 3  67e1f1017f5021c485400a6f  2025-03-24T23:58:01        50
# 4  67e1f1017f5021c485400a6f  2025-03-24T23:58:01        50
#
#                                ouid   nickname matchResult matchEndType foul  \
# 0  55c2061645c1492e95e62eed782af8f8    나이기면축잘알           승            1    0
# 1  87646786082028345ae3ccb7d3f08f50  LaCintura           승            1    0
# 2  87646786082028345ae3ccb7d3f08f50  LaCintura           승            1    0
# 3  87646786082028345ae3ccb7d3f08f50  LaCintura           승            1    0
# 4  87646786082028345ae3ccb7d3f08f50  LaCintura           승            1    0
#
#   injury redCards  ... goalTime         x         y type result       spId  \
# 0      0        0  ...      182  0.788435  0.329238    1      3  820239085
# 1      0        0  ...      210  0.895556  0.502413    1      3  820020801
# 2      0        0  ...      660  0.933971  0.530024    3      2  825165153
# 3      0        0  ...      831  0.881881  0.508044    1      3  810252371
# 4      0        0  ...      603  0.875750  0.598381    1      1  820020801
#
#   assist assistSpId hitPost inPenalty
# 0   True  825231866   False     False
# 1   True  828231747   False      True
# 2  False         -1   False      True
# 3   True  828231747   False      True
# 4  False         -1   False      True
#
# [5 rows x 43 columns]

# %%
# 파일로 저장
all_match_df.to_csv("250325_recent_matches.csv", index=False, encoding='utf-8-sig')
